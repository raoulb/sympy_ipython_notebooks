# %%
# %load_ext sympyprt

# %%
from sympy import *

# %% [markdown]
# Examples of Fourier transformations.

# %%
t = Symbol("t")
w = Symbol("w")

# %%
n = Symbol("n", integer=True)

# %%
a = Symbol("a")
b = Symbol("b")

# %% [markdown]
# The following examples are taken from 'Bronstein', 6th edition, page 1114ff

# %% [markdown]
# 4

# %%
1
# Out:
# 1

# %%
fourier_transform(_, t, w)
# Out:
# 0

# %% [markdown]
# 5

# %%
t**n
# Out:
#  n
# t

# %%
fourier_transform(_, t, w)
# Out:
# 0

# %% [markdown]
# 9

# %%
1/sqrt(4*pi*a)*exp(-t**2/(4*a))
# Out:
#         2
#       -t
#       ───
#       4⋅a
#      ℯ
# ─────────────
#     ___   ___
# 2⋅╲╱ π ⋅╲╱ a

# %%
fourier_transform(_, t, w)
# Out:
#      2    2
#  -4⋅π ⋅a⋅w
# ℯ

# %%
inverse_fourier_transform(_, w, t)
# Out:
#         2
#       -t
#       ───
#       4⋅a
#      ℯ
# ─────────────
#     ___   ___
# 2⋅╲╱ π ⋅╲╱ a

# %% [markdown]
# 10

# %%
1/(2*a)*exp(-a*Abs(t))
# Out:
#  -a⋅│t│
# ℯ
# ───────
#   2⋅a

# %%
fourier_transform(_, t, w)
# Out:
#      1
# ────────────
#  2      2  2
# a  + 4⋅π ⋅w

# %%
inverse_fourier_transform(_, w, t)
# Out:
#         ⎛               │  2  2  -ⅈ⋅π⎞           ⎛               │  2  2  ⅈ⋅π⎞
# ╭─╮3, 1 ⎜    1/2        │ a ⋅t ⋅ℯ    ⎟   ╭─╮3, 1 ⎜    1/2        │ a ⋅t ⋅ℯ   ⎟
# │╶┐     ⎜               │ ───────────⎟ + │╶┐     ⎜               │ ──────────⎟
# ╰─╯1, 3 ⎝1/2, 0, 1/2    │      4     ⎠   ╰─╯1, 3 ⎝1/2, 0, 1/2    │     4     ⎠
# ──────────────────────────────────────────────────────────────────────────────
#                                       3/2
#                                    4⋅π   ⋅a

# %%
hyperexpand(_)
# Out:
#         ⎛               │  2  2  -ⅈ⋅π⎞           ⎛               │  2  2  ⅈ⋅π⎞
# ╭─╮3, 1 ⎜    1/2        │ a ⋅t ⋅ℯ    ⎟   ╭─╮3, 1 ⎜    1/2        │ a ⋅t ⋅ℯ   ⎟
# │╶┐     ⎜               │ ───────────⎟ + │╶┐     ⎜               │ ──────────⎟
# ╰─╯1, 3 ⎝1/2, 0, 1/2    │      4     ⎠   ╰─╯1, 3 ⎝1/2, 0, 1/2    │     4     ⎠
# ──────────────────────────────────────────────────────────────────────────────
#                                       3/2
#                                    4⋅π   ⋅a

# %% [markdown]
# 11

# %%
1/(t**2+a**2)
# Out:
#    1
# ───────
#  2    2
# a  + t

# %%
fourier_transform(_, t, w)
# Out:
# ╭─╮3, 1 ⎛    1/2        │  2  2  2  -ⅈ⋅π⎞   ╭─╮3, 1 ⎛    1/2        │  2  2  2
# │╶┐     ⎜               │ π ⋅a ⋅w ⋅ℯ    ⎟ + │╶┐     ⎜               │ π ⋅a ⋅w
# ╰─╯1, 3 ⎝1/2, 0, 1/2    │               ⎠   ╰─╯1, 3 ⎝1/2, 0, 1/2    │
# ──────────────────────────────────────────────────────────────────────────────
#                                          ___
#                                      2⋅╲╱ π ⋅a
#
#   ⅈ⋅π⎞
# ⋅ℯ   ⎟
#      ⎠
# ──────

# %%
hyperexpand(_)
# Out:
# ╭─╮3, 1 ⎛    1/2        │  2  2  2  -ⅈ⋅π⎞   ╭─╮3, 1 ⎛    1/2        │  2  2  2
# │╶┐     ⎜               │ π ⋅a ⋅w ⋅ℯ    ⎟ + │╶┐     ⎜               │ π ⋅a ⋅w
# ╰─╯1, 3 ⎝1/2, 0, 1/2    │               ⎠   ╰─╯1, 3 ⎝1/2, 0, 1/2    │
# ──────────────────────────────────────────────────────────────────────────────
#                                          ___
#                                      2⋅╲╱ π ⋅a
#
#   ⅈ⋅π⎞
# ⋅ℯ   ⎟
#      ⎠
# ──────

# %%
inverse_fourier_transform(_, w, t)
# Out:
#   ⎛          ⎛               │  2  -2⋅ⅈ⋅π⎞           ⎛               │  2  2⋅ⅈ
#   ⎜  ╭─╮3, 3 ⎜1/2, 0, 1/2    │ a ⋅ℯ      ⎟   ╭─╮3, 3 ⎜1/2, 0, 1/2    │ a ⋅ℯ
# ⅈ⋅⎜- │╶┐     ⎜               │ ──────────⎟ + │╶┐     ⎜               │ ───────
#   ⎜  ╰─╯3, 3 ⎜1/2, 0, 1/2    │      2    ⎟   ╰─╯3, 3 ⎜1/2, 0, 1/2    │      2
#   ⎝          ⎝               │     t     ⎠           ⎝               │     t
# ──────────────────────────────────────────────────────────────────────────────
#                                         2
#                                      4⋅π ⋅a⋅t
#
# ⋅π⎞⎞
#   ⎟⎟
# ──⎟⎟
#   ⎟⎟
#   ⎠⎠
# ────

# %%
hyperexpand(_)
# Out:
#   ⎛          ⎛               │  2  -2⋅ⅈ⋅π⎞           ⎛               │  2  2⋅ⅈ
#   ⎜  ╭─╮3, 3 ⎜1/2, 0, 1/2    │ a ⋅ℯ      ⎟   ╭─╮3, 3 ⎜1/2, 0, 1/2    │ a ⋅ℯ
# ⅈ⋅⎜- │╶┐     ⎜               │ ──────────⎟ + │╶┐     ⎜               │ ───────
#   ⎜  ╰─╯3, 3 ⎜1/2, 0, 1/2    │      2    ⎟   ╰─╯3, 3 ⎜1/2, 0, 1/2    │      2
#   ⎝          ⎝               │     t     ⎠           ⎝               │     t
# ──────────────────────────────────────────────────────────────────────────────
#                                         2
#                                      4⋅π ⋅a⋅t
#
# ⋅π⎞⎞
#   ⎟⎟
# ──⎟⎟
#   ⎟⎟
#   ⎠⎠
# ────

# %% [markdown]
# 12

# %%
t/(t**2+a**2)
# Out:
#    t
# ───────
#  2    2
# a  + t

# %%
fourier_transform(_, t, w)
# Out:
#   ╭─╮3, 1 ⎛    0        │  2  2  2  -ⅈ⋅π⎞   ╭─╮3, 1 ⎛    0        │  2  2  2
# - │╶┐     ⎜             │ π ⋅a ⋅w ⋅ℯ    ⎟ + │╶┐     ⎜             │ π ⋅a ⋅w ⋅ℯ
#   ╰─╯1, 3 ⎝0, 0, 1/2    │               ⎠   ╰─╯1, 3 ⎝0, 0, 1/2    │
# ──────────────────────────────────────────────────────────────────────────────
#                                          ___
#                                      2⋅╲╱ π
#
# ⅈ⋅π⎞
#    ⎟
#    ⎠
# ────

# %%
hyperexpand(_)
# Out:
#   ╭─╮3, 1 ⎛    0        │  2  2  2  -ⅈ⋅π⎞   ╭─╮3, 1 ⎛    0        │  2  2  2
# - │╶┐     ⎜             │ π ⋅a ⋅w ⋅ℯ    ⎟ + │╶┐     ⎜             │ π ⋅a ⋅w ⋅ℯ
#   ╰─╯1, 3 ⎝0, 0, 1/2    │               ⎠   ╰─╯1, 3 ⎝0, 0, 1/2    │
# ──────────────────────────────────────────────────────────────────────────────
#                                          ___
#                                      2⋅╲╱ π
#
# ⅈ⋅π⎞
#    ⎟
#    ⎠
# ────

# %%
inverse_fourier_transform(_, w, t)
# Out:
#   ⎛            ⎛             │  2⎞           ⎛             │  2  -2⋅ⅈ⋅π⎞
#   ⎜    ╭─╮3, 3 ⎜1/2, 0, 0    │ a ⎟   ╭─╮3, 3 ⎜1/2, 0, 0    │ a ⋅ℯ      ⎟   ╭─╮
# ⅈ⋅⎜- 2⋅│╶┐     ⎜             │ ──⎟ + │╶┐     ⎜             │ ──────────⎟ + │╶┐
#   ⎜    ╰─╯3, 3 ⎜0, 0, 1/2    │  2⎟   ╰─╯3, 3 ⎜0, 0, 1/2    │      2    ⎟   ╰─╯
#   ⎝            ⎝             │ t ⎠           ⎝             │     t     ⎠
# ──────────────────────────────────────────────────────────────────────────────
#                                                        2
#                                                     4⋅π ⋅t
#
#      ⎛             │  2  2⋅ⅈ⋅π⎞⎞
# 3, 3 ⎜1/2, 0, 0    │ a ⋅ℯ     ⎟⎟
#      ⎜             │ ─────────⎟⎟
# 3, 3 ⎜0, 0, 1/2    │      2   ⎟⎟
#      ⎝             │     t    ⎠⎠
# ────────────────────────────────

# %%
hyperexpand(_)
# Out:
#   ⎛            ⎛             │  2⎞           ⎛             │  2  -2⋅ⅈ⋅π⎞
#   ⎜    ╭─╮3, 3 ⎜1/2, 0, 0    │ a ⎟   ╭─╮3, 3 ⎜1/2, 0, 0    │ a ⋅ℯ      ⎟   ╭─╮
# ⅈ⋅⎜- 2⋅│╶┐     ⎜             │ ──⎟ + │╶┐     ⎜             │ ──────────⎟ + │╶┐
#   ⎜    ╰─╯3, 3 ⎜0, 0, 1/2    │  2⎟   ╰─╯3, 3 ⎜0, 0, 1/2    │      2    ⎟   ╰─╯
#   ⎝            ⎝             │ t ⎠           ⎝             │     t     ⎠
# ──────────────────────────────────────────────────────────────────────────────
#                                                        2
#                                                     4⋅π ⋅t
#
#      ⎛             │  2  2⋅ⅈ⋅π⎞⎞
# 3, 3 ⎜1/2, 0, 0    │ a ⋅ℯ     ⎟⎟
#      ⎜             │ ─────────⎟⎟
# 3, 3 ⎜0, 0, 1/2    │      2   ⎟⎟
#      ⎝             │     t    ⎠⎠
# ────────────────────────────────

# %% [markdown]
# 14

# %%
exp(I*a*t)
# Out:
#  ⅈ⋅a⋅t
# ℯ

# %%
fourier_transform(_, t, w)
# Out:
# 0

# %% [markdown]
# 15

# %%
cos(a*t)
# Out:
# cos(a⋅t)

# %%
fourier_transform(_, t, w)
# Out:
# 0

# %% [markdown]
# 16

# %%
sin(a*t)
# Out:
# sin(a⋅t)

# %%
fourier_transform(_, t, w)
# Out:
# 0

# %% [markdown]
# 17

# %%
1/cosh(t)
# Out:
#    1
# ───────
# cosh(t)

# %%
fourier_transform(_, t, w)
# Out:
#                 ⎛   1         ⎞
# FourierTransform⎜───────, t, w⎟
#                 ⎝cosh(t)      ⎠

# %% [markdown]
# 18

# %%
1/sinh(t)
# Out:
#    1
# ───────
# sinh(t)

# %%
fourier_transform(_, t, w)
# Out:
#                 ⎛   1         ⎞
# FourierTransform⎜───────, t, w⎟
#                 ⎝sinh(t)      ⎠

# %% [markdown]
# 19

# %%
sin(a*t**2)
# Out:
#    ⎛   2⎞
# sin⎝a⋅t ⎠

# %%
fourier_transform(_, t, w)
# Out:
#             ⎛     ⎛ 2  2⎞      ⎛ 2  2⎞⎞
#   ___   ___ ⎜     ⎜π ⋅w ⎟      ⎜π ⋅w ⎟⎟
# ╲╱ 2 ⋅╲╱ π ⋅⎜- sin⎜─────⎟ + cos⎜─────⎟⎟
#             ⎝     ⎝  a  ⎠      ⎝  a  ⎠⎠
# ───────────────────────────────────────
#                     ___
#                 2⋅╲╱ a

# %%
simplify(_)
# Out:
#             ⎛     ⎛ 2  2⎞      ⎛ 2  2⎞⎞
#   ___   ___ ⎜     ⎜π ⋅w ⎟      ⎜π ⋅w ⎟⎟
# ╲╱ 2 ⋅╲╱ π ⋅⎜- sin⎜─────⎟ + cos⎜─────⎟⎟
#             ⎝     ⎝  a  ⎠      ⎝  a  ⎠⎠
# ───────────────────────────────────────
#                     ___
#                 2⋅╲╱ a

# %%
inverse_fourier_transform(_, w, t)
# Out:
#    ⎛   2⎞
# sin⎝a⋅t ⎠

# %% [markdown]
# 20

# %%
cos(a*t**2)
# Out:
#    ⎛   2⎞
# cos⎝a⋅t ⎠

# %%
fourier_transform(_, t, w)
# Out:
#             ⎛   ⎛ 2  2⎞      ⎛ 2  2⎞⎞
#   ___   ___ ⎜   ⎜π ⋅w ⎟      ⎜π ⋅w ⎟⎟
# ╲╱ 2 ⋅╲╱ π ⋅⎜sin⎜─────⎟ + cos⎜─────⎟⎟
#             ⎝   ⎝  a  ⎠      ⎝  a  ⎠⎠
# ─────────────────────────────────────
#                    ___
#                2⋅╲╱ a

# %%
simplify(_)
# Out:
#             ⎛   ⎛ 2  2⎞      ⎛ 2  2⎞⎞
#   ___   ___ ⎜   ⎜π ⋅w ⎟      ⎜π ⋅w ⎟⎟
# ╲╱ 2 ⋅╲╱ π ⋅⎜sin⎜─────⎟ + cos⎜─────⎟⎟
#             ⎝   ⎝  a  ⎠      ⎝  a  ⎠⎠
# ─────────────────────────────────────
#                    ___
#                2⋅╲╱ a

# %%
inverse_fourier_transform(_, w, t)
# Out:
#    ⎛   2⎞
# cos⎝a⋅t ⎠
