# %%
# %load_ext sympyprt

# %%
from sympy import *

# %% [markdown]
# Examples of Fourier transformations.

# %%
p = Symbol("p")
t = Symbol("t")

# %%
n = Symbol("n", integer=True)

# %%
a = Symbol("a")
b = Symbol("b")
c = Symbol("c")

# %% [markdown]
# The following examples are taken from 'Bronstein', 6th edition, page 1097ff

# %% [markdown]
# 1

# %%
0
# Out:
# 0

# %%
laplace_transform(_, t, p)
# Out:
# (0, -∞, True)

# %%
inverse_laplace_transform(_[0], p, t)
# Out:
# 0

# %% [markdown]
# 2

# %%
1
# Out:
# 1

# %%
laplace_transform(_, t, p)
# Out:
# ⎛1         ⎞
# ⎜─, 0, True⎟
# ⎝p         ⎠

# %%
inverse_laplace_transform(_[0], p, t)
# Out:
# Heaviside(t)

# %% [markdown]
# 3

# %%
t**(n-1)/factorial(n-1)
# Out:
#   n - 1
#  t
# ────────
# (n - 1)!

# %%
laplace_transform(_, t, p)
# Out:
# ⎛ -n               ⎞
# ⎝p  , 0, -n + 1 < 1⎠

# %%
inverse_laplace_transform(_[0], p, t)
# Out:
#  n - 1
# t     ⋅Heaviside(t)
# ───────────────────
#         Γ(n)

# %% [markdown]
# 4

# %%
t**(n-1)/factorial(n-1)*exp(a*t)
# Out:
#  n - 1  a⋅t
# t     ⋅ℯ
# ───────────
#   (n - 1)!

# %%
#laplace_transform(_, t, p)
# unsupported operand type(s) for *: 'NoneType' and 'Mul'

# %%
1/(p-a)**n
# Out:
#         -n
# (-a + p)

# %%
inverse_laplace_transform(_, p, t)
# Out:
#                        ⎛        -n            ⎞
# InverseLaplaceTransform⎝(-a + p)  , p, t, None⎠

# %% [markdown]
# 5

# %%
(exp(b*t)-exp(a*t))/(b-a)
# Out:
#    a⋅t    b⋅t
# - ℯ    + ℯ
# ─────────────
#     -a + b

# %%
laplace_transform(_, t, p)
# Out:
# (nan, -∞, True)

# %%
1/((p-a)*(p-b))
# Out:
#         1
# ─────────────────
# (-a + p)⋅(-b + p)

# %%
inverse_laplace_transform(_, p, t)
# Out:
# ⎛   t⋅re(a)                 t⋅re(a)                   t⋅re(b)
# ⎝ⅈ⋅ℯ       ⋅sin(t⋅im(a)) + ℯ       ⋅cos(t⋅im(a)) - ⅈ⋅ℯ       ⋅sin(t⋅im(b)) - ℯ
# ──────────────────────────────────────────────────────────────────────────────
#                                                      a - b
#
# t⋅re(b)             ⎞
#        ⋅cos(t⋅im(b))⎠⋅Heaviside(t)
# ──────────────────────────────────

# %% [markdown]
# 6

# %%
(b*exp(b*t)-a*exp(a*t))/(b-a)
# Out:
#      a⋅t      b⋅t
# - a⋅ℯ    + b⋅ℯ
# ─────────────────
#       -a + b

# %%
laplace_transform(_, t, p)
# Out:
# (nan, -∞, True)

# %%
p/((p-a)*(p-b))
# Out:
#         p
# ─────────────────
# (-a + p)⋅(-b + p)

# %%
inverse_laplace_transform(_, p, t)
# Out:
# ⎛     t⋅re(a)                   t⋅re(a)                     t⋅re(b)
# ⎝ⅈ⋅a⋅ℯ       ⋅sin(t⋅im(a)) + a⋅ℯ       ⋅cos(t⋅im(a)) - ⅈ⋅b⋅ℯ       ⋅sin(t⋅im(b
# ──────────────────────────────────────────────────────────────────────────────
#                                                          a - b
#
#         t⋅re(b)             ⎞
# )) - b⋅ℯ       ⋅cos(t⋅im(b))⎠⋅Heaviside(t)
# ──────────────────────────────────────────

# %% [markdown]
# 7

# %%
exp(-a*t)/sqrt(b**2-a**2)*sin(sqrt(b**2-a**2)*t)
# Out:
#          ⎛     ___________⎞
#  -a⋅t    ⎜    ╱    2    2 ⎟
# ℯ    ⋅sin⎝t⋅╲╱  - a  + b  ⎠
# ───────────────────────────
#           ___________
#          ╱    2    2
#        ╲╱  - a  + b

# %%
laplace_transform(_, t, p)
# Out:
#                 ⎛         ⎛     ___________⎞      ⎞
#                 ⎜ -a⋅t    ⎜    ╱    2    2 ⎟      ⎟
# LaplaceTransform⎝ℯ    ⋅sin⎝t⋅╲╱  - a  + b  ⎠, t, p⎠
# ───────────────────────────────────────────────────
#                       ___________
#                      ╱    2    2
#                    ╲╱  - a  + b

# %%
1/(p**2+2*a*p+b**2)
# Out:
#        1
# ───────────────
#          2    2
# 2⋅a⋅p + b  + p

# %%
inverse_laplace_transform(_, p, t)
# Out:
# ⎛           __________________________________________________________________
# ⎜          ╱
# ⎜       4 ╱    4          2      ⎛ 2⎞       2      2                      ⎛ 2⎞
# ⎜     t⋅╲╱   re (a) - 2⋅re (a)⋅re⎝b ⎠ + 2⋅re (a)⋅im (a) - 4⋅re(a)⋅im(a)⋅im⎝b ⎠
# ⎜
# ⎜- ⅈ⋅ℯ
# ⎝
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ________________________________________________
#      2                                    2         ⎛     ⎛                  ⎛
#       ⎛ 2⎞       ⎛ 2⎞   2        4         ⎛ 2⎞     ⎜atan2⎝2⋅re(a)⋅im(a) - im⎝
#  + re ⎝b ⎠ + 2⋅re⎝b ⎠⋅im (a) + im (a) + im ⎝b ⎠ ⋅cos⎜─────────────────────────
#                                                     ⎝
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                                                                            ___
#  2⎞    2        ⎛ 2⎞     2   ⎞⎞                                           ╱
# ...

# %% [markdown]
# 8

# %%
sin(a*t)
# Out:
# sin(a⋅t)

# %%
laplace_transform(_, t, p)
# Out:
# ⎛   a        │                 ⎛          2      ⎞│    ⎞
# ⎜───────, 0, │periodic_argument⎝polar_lift (a), ∞⎠│ = 0⎟
# ⎜ 2    2                                               ⎟
# ⎝a  + p                                                ⎠

# %%
inverse_laplace_transform(_[0], p, t)
# Out:
#    ⎛   2⋅t⋅im(a)                 2⋅t⋅im(a)
# -ⅈ⋅⎝ⅈ⋅ℯ         ⋅sin(t⋅re(a)) - ℯ         ⋅cos(t⋅re(a)) + ⅈ⋅sin(t⋅re(a)) + cos
# ──────────────────────────────────────────────────────────────────────────────
#                                                        2
#
#          ⎞  -t⋅im(a)
# (t⋅re(a))⎠⋅ℯ        ⋅Heaviside(t)
# ─────────────────────────────────

# %% [markdown]
# 9

# %%
sin(a*t+b)
# Out:
# sin(a⋅t + b)

# %%
laplace_transform(_, t, p)
# Out:
# ⎛a⋅cos(b) + p⋅sin(b)     │                 ⎛          2      ⎞│    ⎞
# ⎜───────────────────, 0, │periodic_argument⎝polar_lift (a), ∞⎠│ = 0⎟
# ⎜       2    2                                                     ⎟
# ⎝      a  + p                                                      ⎠

# %%
inverse_laplace_transform(_[0], p, t)
# Out:
#    ⎛ 2⋅t⋅im(a)                          2⋅t⋅im(a)                          2⋅t
# -ⅈ⋅⎝ℯ         ⋅sin(b)⋅sin(t⋅re(a)) + ⅈ⋅ℯ         ⋅sin(b)⋅cos(t⋅re(a)) + ⅈ⋅ℯ
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ⋅im(a)                        2⋅t⋅im(a)
#       ⋅sin(t⋅re(a))⋅cos(b) - ℯ         ⋅cos(b)⋅cos(t⋅re(a)) - sin(b)⋅sin(t⋅re(
# ──────────────────────────────────────────────────────────────────────────────
#                                                 2
#
#                                                                          ⎞  -t
# a)) + ⅈ⋅sin(b)⋅cos(t⋅re(a)) + ⅈ⋅sin(t⋅re(a))⋅cos(b) + cos(b)⋅cos(t⋅re(a))⎠⋅ℯ
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ⋅im(a)
#       ⋅Heaviside(t)
# ───────────────────

# %%
simplify(_)
# Out:
# ⎛     2⋅t⋅im(a)                        2⋅t⋅im(a)                        2⋅t⋅im
# ⎜  ⅈ⋅ℯ         ⋅sin(b)⋅sin(t⋅re(a))   ℯ         ⋅sin(b)⋅cos(t⋅re(a))   ℯ
# ⎜- ──────────────────────────────── + ────────────────────────────── + ───────
# ⎝                 2                                 2
#
# (a)                          2⋅t⋅im(a)
#    ⋅sin(t⋅re(a))⋅cos(b)   ⅈ⋅ℯ         ⋅cos(b)⋅cos(t⋅re(a))   ⅈ⋅sin(b)⋅sin(t⋅re
# ─────────────────────── + ──────────────────────────────── + ─────────────────
#        2                                 2                             2
#
#                                                                         ⎞
# (a))   sin(b)⋅cos(t⋅re(a))   sin(t⋅re(a))⋅cos(b)   ⅈ⋅cos(b)⋅cos(t⋅re(a))⎟  -t⋅
# ──── + ─────────────────── + ─────────────────── - ─────────────────────⎟⋅ℯ
#                 2                     2                      2          ⎠
#
#
# im(a)
#      ⋅Heaviside(t)

# %% [markdown]
# 10

# %%
(cos(sqrt(b**2-a**2)*t)-a/sqrt(b**2-a**2)*sin(sqrt(b**2-a**2)))*exp(-a*t)
# Out:
# ⎛       ⎛   ___________⎞                        ⎞
# ⎜       ⎜  ╱    2    2 ⎟      ⎛     ___________⎞⎟
# ⎜  a⋅sin⎝╲╱  - a  + b  ⎠      ⎜    ╱    2    2 ⎟⎟  -a⋅t
# ⎜- ───────────────────── + cos⎝t⋅╲╱  - a  + b  ⎠⎟⋅ℯ
# ⎜         ___________                           ⎟
# ⎜        ╱    2    2                            ⎟
# ⎝      ╲╱  - a  + b                             ⎠

# %%
laplace_transform(_, t, p)
# Out:
# ⎛      ⎛   ___________⎞
# ⎜      ⎜  ╱    2    2 ⎟                                       │
# ⎜   sin⎝╲╱  - a  + b  ⎠                   1                   │
# ⎜- ────────────────────── + ─────────────────────────────, 0, │periodic_argume
# ⎜             ___________             ⎛      ⎛   2    2⎞⎞     │
# ⎜  ⎛    p⎞   ╱    2    2              ⎜      ⎜  a    b ⎟⎟
# ⎜  ⎜1 + ─⎟⋅╲╱  - a  + b               ⎜    4⋅⎜- ── + ──⎟⎟
# ⎜  ⎝    a⎠                    ⎛    p⎞ ⎜      ⎝  4    4 ⎠⎟
# ⎜                           a⋅⎜1 + ─⎟⋅⎜1 + ─────────────⎟
# ⎜                             ⎝    a⎠ ⎜               2 ⎟
# ⎜                                     ⎜      2 ⎛    p⎞  ⎟
# ⎜                                     ⎜     a ⋅⎜1 + ─⎟  ⎟
# ⎝                                     ⎝        ⎝    a⎠  ⎠
#
#
#   ⎛                         2          ⎞│
#   ⎜          2               ⎛    p⎞   ⎟│       ⎛                            π
# nt⎜polar_lift (a)⋅polar_lift ⎜1 + ─⎟, ∞⎟│ < π ∧ ⎜│periodic_argument(a, ∞)│ < ─
# ...

# %%
p/(p**2+2*a*p+b**2)
# Out:
#        p
# ───────────────
#          2    2
# 2⋅a⋅p + b  + p

# %%
inverse_laplace_transform(_, p, t)
# Out:
# ⎛                    ⎛        ⎛    ___________________________________________
# ⎜                    ⎜        ⎜   ╱                         2
# ⎜                    ⎜        ⎜4 ╱  ⎛                  ⎛ 2⎞⎞    ⎛  2        ⎛
# ⎜⎛        _________⎞ ⎜     -t⋅⎜╲╱   ⎝2⋅re(a)⋅im(a) - im⎝b ⎠⎠  + ⎝re (a) - re⎝b
# ⎜⎜       ╱  2    2 ⎟ ⎜        ⎝
# ⎜⎝-a - ╲╱  a  - b  ⎠⋅⎜- ⅈ⋅ℯ
# ⎜                    ⎝
# ⎜─────────────────────────────────────────────────────────────────────────────
# ⎜
# ⎜
# ⎝
#
# ______________
#             2     ⎛     ⎛                  ⎛ 2⎞    2        ⎛ 2⎞     2   ⎞⎞
# 2⎞     2   ⎞      ⎜atan2⎝2⋅re(a)⋅im(a) - im⎝b ⎠, re (a) - re⎝b ⎠ - im (a)⎠⎟
#  ⎠ - im (a)⎠  ⋅cos⎜───────────────────────────────────────────────────────⎟ +
#                   ⎝                           2                           ⎠
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#      ⎞
#      ⎟
# ...

# %% [markdown]
# 11

# %%
cos(a*t)
# Out:
# cos(a⋅t)

# %%
laplace_transform(_, t, p)
# Out:
# ⎛   p        │                 ⎛          2      ⎞│    ⎞
# ⎜───────, 0, │periodic_argument⎝polar_lift (a), ∞⎠│ = 0⎟
# ⎜ 2    2                                               ⎟
# ⎝a  + p                                                ⎠

# %%
inverse_laplace_transform(_[0], p, t)
# Out:
#  ⎛   2⋅t⋅im(a)                 2⋅t⋅im(a)
# -⎝ⅈ⋅ℯ         ⋅sin(t⋅re(a)) - ℯ         ⋅cos(t⋅re(a)) - ⅈ⋅sin(t⋅re(a)) - cos(t
# ──────────────────────────────────────────────────────────────────────────────
#                                                       2
#
#        ⎞  -t⋅im(a)
# ⋅re(a))⎠⋅ℯ        ⋅Heaviside(t)
# ───────────────────────────────

# %% [markdown]
# 12

# %%
cos(a*t+b)
# Out:
# cos(a⋅t + b)

# %%
laplace_transform(_, t, p)
# Out:
# ⎛-a⋅sin(b) + p⋅cos(b)     │                 ⎛          2      ⎞│    ⎞
# ⎜────────────────────, 0, │periodic_argument⎝polar_lift (a), ∞⎠│ = 0⎟
# ⎜       2    2                                                      ⎟
# ⎝      a  + p                                                       ⎠

# %%
inverse_laplace_transform(_[0], p, t)
# Out:
#    ⎛     2⋅t⋅im(a)                        2⋅t⋅im(a)                        2⋅t
# -ⅈ⋅⎝- ⅈ⋅ℯ         ⋅sin(b)⋅sin(t⋅re(a)) + ℯ         ⋅sin(b)⋅cos(t⋅re(a)) + ℯ
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ⋅im(a)                          2⋅t⋅im(a)
#       ⋅sin(t⋅re(a))⋅cos(b) + ⅈ⋅ℯ         ⋅cos(b)⋅cos(t⋅re(a)) - ⅈ⋅sin(b)⋅sin(t
# ──────────────────────────────────────────────────────────────────────────────
#                                                  2
#
#                                                                            ⎞
# ⋅re(a)) - sin(b)⋅cos(t⋅re(a)) - sin(t⋅re(a))⋅cos(b) + ⅈ⋅cos(b)⋅cos(t⋅re(a))⎠⋅ℯ
# ──────────────────────────────────────────────────────────────────────────────
#
#
# -t⋅im(a)
#         ⋅Heaviside(t)
# ─────────────────────

# %% [markdown]
# 13

# %%
sinh(a*t)
# Out:
# sinh(a⋅t)

# %%
laplace_transform(_, t, p)
# Out:
# (nan, -∞, True)

# %%
a/(p**2-a**2)
# Out:
#     a
# ─────────
#    2    2
# - a  + p

# %%
inverse_laplace_transform(_, p, t)
# Out:
# ⎛   2⋅t⋅re(a)                 2⋅t⋅re(a)
# ⎝ⅈ⋅ℯ         ⋅sin(t⋅im(a)) + ℯ         ⋅cos(t⋅im(a)) + ⅈ⋅sin(t⋅im(a)) - cos(t⋅
# ──────────────────────────────────────────────────────────────────────────────
#                                                      2
#
#       ⎞  -t⋅re(a)
# im(a))⎠⋅ℯ        ⋅Heaviside(t)
# ──────────────────────────────

# %% [markdown]
# 14

# %%
cosh(a*t)
# Out:
# cosh(a⋅t)

# %%
laplace_transform(_, t, p)
# Out:
# ⎛⎧                      ⅈ⋅π                         │ 2│
# ⎜⎪                   p⋅ℯ                            │p │
# ⎜⎪                  ───────                     for │──│ < 1, Max(0, cos(Abs(p
# ⎜⎪                   2    2                         │ 2│
# ⎜⎪                  a  - p                          │a │
# ⎜⎪
# ⎜⎪                                                  │ 2│
# ⎜⎪                     p                            │a │
# ⎜⎪                 ─────────                    for │──│ < 1
# ⎜⎪                    2    2                        │ 2│
# ⎜⎪                 - a  + p                         │p │
# ⎜⎪
# ⎜⎪  ⎧                                 │ 2│
# ⎜⎪  ⎪            -p                   │p │
# ⎜⎪π⋅⎪       ────────────          for │──│ < 1
# ⎜⎪  ⎪           ⎛     2⎞              │ 2│
# ⎜⎪  ⎪           ⎜    p ⎟              │a │
# ⎜⎪  ⎪       π⋅a⋅⎜1 - ──⎟
# ⎜⎨  ⎪           ⎜     2⎟
# ⎜⎪  ⎪           ⎝    a ⎠
# ⎜⎪  ⎪
# ⎜⎪  ⎪                                 │ 2│
# ...

# %%
p/(p**2-a**2)
# Out:
#     p
# ─────────
#    2    2
# - a  + p

# %%
inverse_laplace_transform(_, p, t)
# Out:
# ⎛   2⋅t⋅re(a)                 2⋅t⋅re(a)
# ⎝ⅈ⋅ℯ         ⋅sin(t⋅im(a)) + ℯ         ⋅cos(t⋅im(a)) - ⅈ⋅sin(t⋅im(a)) + cos(t⋅
# ──────────────────────────────────────────────────────────────────────────────
#                                                      2
#
#       ⎞  -t⋅re(a)
# im(a))⎠⋅ℯ        ⋅Heaviside(t)
# ──────────────────────────────

# %% [markdown]
# 15

# %%
-((b-c)*exp(a*t)+(c-a)*exp(b*t)+(a-b)*exp(c*t))/((a-b)*(b-c)*(c-a))
# Out:
#             b⋅t            c⋅t            a⋅t
# - (-a + c)⋅ℯ    - (a - b)⋅ℯ    - (b - c)⋅ℯ
# ─────────────────────────────────────────────
#            (-a + c)⋅(a - b)⋅(b - c)

# %%
laplace_transform(_, t, p)
# Out:
# (nan, -∞, True)

# %%
1/((p-a)*(p-b)*(p-c))
# Out:
#             1
# ──────────────────────────
# (-a + p)⋅(-b + p)⋅(-c + p)

# %%
inverse_laplace_transform(_, p, t)
# Out:
#  ⎛     t⋅re(b)                   t⋅re(b)                     t⋅re(c)
# -⎝ⅈ⋅a⋅ℯ       ⋅sin(t⋅im(b)) + a⋅ℯ       ⋅cos(t⋅im(b)) - ⅈ⋅a⋅ℯ       ⋅sin(t⋅im(
# ──────────────────────────────────────────────────────────────────────────────
#
#
#          t⋅re(c)                     t⋅re(a)                   t⋅re(a)
# c)) - a⋅ℯ       ⋅cos(t⋅im(c)) - ⅈ⋅b⋅ℯ       ⋅sin(t⋅im(a)) - b⋅ℯ       ⋅cos(t⋅i
# ──────────────────────────────────────────────────────────────────────────────
#
#
#              t⋅re(c)                   t⋅re(c)                     t⋅re(a)
# m(a)) + ⅈ⋅b⋅ℯ       ⋅sin(t⋅im(c)) + b⋅ℯ       ⋅cos(t⋅im(c)) + ⅈ⋅c⋅ℯ       ⋅sin
# ──────────────────────────────────────────────────────────────────────────────
#  (a - b)⋅(a - c)⋅(b - c)
#
#                t⋅re(a)                     t⋅re(b)                   t⋅re(b)
# (t⋅im(a)) + c⋅ℯ       ⋅cos(t⋅im(a)) - ⅈ⋅c⋅ℯ       ⋅sin(t⋅im(b)) - c⋅ℯ       ⋅c
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ...

# %% [markdown]
# 16

# %%
(exp(a*t)-(1+(a-b)*t)*exp(b*t))/(a-b)**2
# Out:
#                    b⋅t    a⋅t
# - (t⋅(a - b) + 1)⋅ℯ    + ℯ
# ─────────────────────────────
#                   2
#            (a - b)

# %%
laplace_transform(_, t, p)
# Out:
# ⎛                     1                           ⎛│                 ⎛ ⅈ⋅π
# ⎜────────────────────────────────────────────, 0, ⎜│periodic_argument⎝ℯ   ⋅pol
# ⎜     2                2    2          2    3     ⎝
# ⎝- a⋅b  + 2⋅a⋅b⋅p - a⋅p  + b ⋅p - 2⋅b⋅p  + p
#
#              ⎞│   π   │                 ⎛ ⅈ⋅π                 ⎞│   π⎞   ⎛│
# ar_lift(b), ∞⎠│ < ─ ∨ │periodic_argument⎝ℯ   ⋅polar_lift(b), ∞⎠│ ≤ ─⎟ ∧ ⎜│peri
#                   2                                                2⎠   ⎝
#
#
#              ⎛ ⅈ⋅π                 ⎞│   π   │                 ⎛ ⅈ⋅π
# odic_argument⎝ℯ   ⋅polar_lift(a), ∞⎠│ ≤ ─ ∨ │periodic_argument⎝ℯ   ⋅polar_lift
#                                         2
#
#
#       ⎞│   π⎞⎞
# (a), ∞⎠│ < ─⎟⎟
#            2⎠⎟
#              ⎠

# %%
inverse_laplace_transform(_[0], p, t)
# Out:
#  ⎛       t⋅re(b)                     t⋅re(b)                       t⋅re(b)
# -⎝ⅈ⋅a⋅t⋅ℯ       ⋅sin(t⋅im(b)) + a⋅t⋅ℯ       ⋅cos(t⋅im(b)) - ⅈ⋅b⋅t⋅ℯ       ⋅sin
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                  t⋅re(b)                   t⋅re(a)                 t⋅re(a)
# (t⋅im(b)) - b⋅t⋅ℯ       ⋅cos(t⋅im(b)) - ⅈ⋅ℯ       ⋅sin(t⋅im(a)) - ℯ       ⋅cos
# ──────────────────────────────────────────────────────────────────────────────
#                                         2
#                                  (a - b)
#
#                t⋅re(b)                 t⋅re(b)             ⎞
# (t⋅im(a)) + ⅈ⋅ℯ       ⋅sin(t⋅im(b)) + ℯ       ⋅cos(t⋅im(b))⎠⋅Heaviside(t)
# ─────────────────────────────────────────────────────────────────────────

# %%
1/((p-a)*(p-b)**2)
# Out:
#         1
# ──────────────────
#                  2
# (-a + p)⋅(-b + p)

# %%
inverse_laplace_transform(_, p, t)
# Out:
#  ⎛       t⋅re(b)                     t⋅re(b)                       t⋅re(b)
# -⎝ⅈ⋅a⋅t⋅ℯ       ⋅sin(t⋅im(b)) + a⋅t⋅ℯ       ⋅cos(t⋅im(b)) - ⅈ⋅b⋅t⋅ℯ       ⋅sin
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                  t⋅re(b)                   t⋅re(a)                 t⋅re(a)
# (t⋅im(b)) - b⋅t⋅ℯ       ⋅cos(t⋅im(b)) - ⅈ⋅ℯ       ⋅sin(t⋅im(a)) - ℯ       ⋅cos
# ──────────────────────────────────────────────────────────────────────────────
#                                         2
#                                  (a - b)
#
#                t⋅re(b)                 t⋅re(b)             ⎞
# (t⋅im(a)) + ⅈ⋅ℯ       ⋅sin(t⋅im(b)) + ℯ       ⋅cos(t⋅im(b))⎠⋅Heaviside(t)
# ─────────────────────────────────────────────────────────────────────────

# %% [markdown]
# 17

# %%
(a*exp(a*t)-(a+b*(a-b)*t)*exp(b*t))/(a-b)**2
# Out:
#    a⋅t                      b⋅t
# a⋅ℯ    - (a + b⋅t⋅(a - b))⋅ℯ
# ───────────────────────────────
#                    2
#             (a - b)

# %%
laplace_transform(_, t, p)
# Out:
# ⎛                     p                           ⎛│                 ⎛ ⅈ⋅π
# ⎜────────────────────────────────────────────, 0, ⎜│periodic_argument⎝ℯ   ⋅pol
# ⎜     2                2    2          2    3     ⎝
# ⎝- a⋅b  + 2⋅a⋅b⋅p - a⋅p  + b ⋅p - 2⋅b⋅p  + p
#
#              ⎞│   π   │                 ⎛ ⅈ⋅π                 ⎞│   π⎞   ⎛│
# ar_lift(a), ∞⎠│ ≤ ─ ∨ │periodic_argument⎝ℯ   ⋅polar_lift(a), ∞⎠│ < ─⎟ ∧ ⎜│peri
#                   2                                                2⎠   ⎝
#
#
#              ⎛ ⅈ⋅π                 ⎞│   π   │                 ⎛ ⅈ⋅π
# odic_argument⎝ℯ   ⋅polar_lift(b), ∞⎠│ < ─ ∨ │periodic_argument⎝ℯ   ⋅polar_lift
#                                         2
#
#
#       ⎞│   π⎞⎞
# (b), ∞⎠│ ≤ ─⎟⎟
#            2⎠⎟
#              ⎠

# %%
inverse_laplace_transform(_[0], p, t)
# Out:
#  ⎛         t⋅re(b)                       t⋅re(b)                     t⋅re(a)
# -⎝ⅈ⋅a⋅b⋅t⋅ℯ       ⋅sin(t⋅im(b)) + a⋅b⋅t⋅ℯ       ⋅cos(t⋅im(b)) - ⅈ⋅a⋅ℯ       ⋅s
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                  t⋅re(a)                     t⋅re(b)                   t⋅re(b)
# in(t⋅im(a)) - a⋅ℯ       ⋅cos(t⋅im(a)) + ⅈ⋅a⋅ℯ       ⋅sin(t⋅im(b)) + a⋅ℯ
# ──────────────────────────────────────────────────────────────────────────────
#                                                2
#                                         (a - b)
#
#                    2    t⋅re(b)                 2    t⋅re(b)             ⎞
# ⋅cos(t⋅im(b)) - ⅈ⋅b ⋅t⋅ℯ       ⋅sin(t⋅im(b)) - b ⋅t⋅ℯ       ⋅cos(t⋅im(b))⎠⋅Hea
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
# viside(t)
# ─────────

# %%
p/((p-a)*(p-b)**2)
# Out:
#         p
# ──────────────────
#                  2
# (-a + p)⋅(-b + p)

# %%
inverse_laplace_transform(_, p, t)
# Out:
#  ⎛         t⋅re(b)                       t⋅re(b)                     t⋅re(a)
# -⎝ⅈ⋅a⋅b⋅t⋅ℯ       ⋅sin(t⋅im(b)) + a⋅b⋅t⋅ℯ       ⋅cos(t⋅im(b)) - ⅈ⋅a⋅ℯ       ⋅s
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                  t⋅re(a)                     t⋅re(b)                   t⋅re(b)
# in(t⋅im(a)) - a⋅ℯ       ⋅cos(t⋅im(a)) + ⅈ⋅a⋅ℯ       ⋅sin(t⋅im(b)) + a⋅ℯ
# ──────────────────────────────────────────────────────────────────────────────
#                                                2
#                                         (a - b)
#
#                    2    t⋅re(b)                 2    t⋅re(b)             ⎞
# ⋅cos(t⋅im(b)) - ⅈ⋅b ⋅t⋅ℯ       ⋅sin(t⋅im(b)) - b ⋅t⋅ℯ       ⋅cos(t⋅im(b))⎠⋅Hea
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
# viside(t)
# ─────────

# %% [markdown]
# 18

# %%
(a**2*exp(a*t)-(2*a-b+b*(a-b)*t)*b*exp(b*t))/(a-b)**2
# Out:
#  2  a⋅t                              b⋅t
# a ⋅ℯ    - b⋅(2⋅a + b⋅t⋅(a - b) - b)⋅ℯ
# ────────────────────────────────────────
#                        2
#                 (a - b)

# %%
laplace_transform(_, t, p)
# Out:
# ⎛                      2
# ⎜                     p                           ⎛│                 ⎛ ⅈ⋅π
# ⎜────────────────────────────────────────────, 0, ⎜│periodic_argument⎝ℯ   ⋅pol
# ⎜     2                2    2          2    3     ⎝
# ⎝- a⋅b  + 2⋅a⋅b⋅p - a⋅p  + b ⋅p - 2⋅b⋅p  + p
#
#
#              ⎞│   π   │                 ⎛ ⅈ⋅π                 ⎞│   π⎞   ⎛│
# ar_lift(a), ∞⎠│ ≤ ─ ∨ │periodic_argument⎝ℯ   ⋅polar_lift(a), ∞⎠│ < ─⎟ ∧ ⎜│peri
#                   2                                                2⎠   ⎝
#
#
#
#              ⎛ ⅈ⋅π                 ⎞│   π   │                 ⎛ ⅈ⋅π
# odic_argument⎝ℯ   ⋅polar_lift(b), ∞⎠│ < ─ ∨ │periodic_argument⎝ℯ   ⋅polar_lift
#                                         2
#
#
#              ⎞
#       ⎞│   π⎞⎟
# (b), ∞⎠│ ≤ ─⎟⎟
#            2⎠⎟
#              ⎠

# %%
inverse_laplace_transform(_[0], p, t)
# Out:
#  ⎛     4  t⋅re(a)                      2    4  t⋅re(a)                      2
# -⎝- ⅈ⋅a ⋅ℯ       ⋅sin(t⋅im(a))⋅Γ(a - b)  - a ⋅ℯ       ⋅cos(t⋅im(a))⋅Γ(a - b)
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#        3    t⋅re(a)                      2      3    t⋅re(a)
# + 2⋅ⅈ⋅a ⋅b⋅ℯ       ⋅sin(t⋅im(a))⋅Γ(a - b)  + 2⋅a ⋅b⋅ℯ       ⋅cos(t⋅im(a))⋅Γ(a
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#     2      2  2  t⋅re(a)                      2    2  2  t⋅re(a)
# - b)  - ⅈ⋅a ⋅b ⋅ℯ       ⋅sin(t⋅im(a))⋅Γ(a - b)  - a ⋅b ⋅ℯ       ⋅cos(t⋅im(a))⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#         2        2    t⋅re(b)                          2      2    t⋅re(b)
# Γ(a - b)  + ⅈ⋅a⋅b ⋅t⋅ℯ       ⋅sin(t⋅im(b))⋅Γ(a - b + 1)  + a⋅b ⋅t⋅ℯ       ⋅cos
# ──────────────────────────────────────────────────────────────────────────────
# ...

# %%
p**2/((p-a)*(p-b)**2)
# Out:
#          2
#         p
# ──────────────────
#                  2
# (-a + p)⋅(-b + p)

# %%
inverse_laplace_transform(_, p, t)
# Out:
#  ⎛     4  t⋅re(a)                      2    4  t⋅re(a)                      2
# -⎝- ⅈ⋅a ⋅ℯ       ⋅sin(t⋅im(a))⋅Γ(a - b)  - a ⋅ℯ       ⋅cos(t⋅im(a))⋅Γ(a - b)
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#        3    t⋅re(a)                      2      3    t⋅re(a)
# + 2⋅ⅈ⋅a ⋅b⋅ℯ       ⋅sin(t⋅im(a))⋅Γ(a - b)  + 2⋅a ⋅b⋅ℯ       ⋅cos(t⋅im(a))⋅Γ(a
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#     2      2  2  t⋅re(a)                      2    2  2  t⋅re(a)
# - b)  - ⅈ⋅a ⋅b ⋅ℯ       ⋅sin(t⋅im(a))⋅Γ(a - b)  - a ⋅b ⋅ℯ       ⋅cos(t⋅im(a))⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#         2        2    t⋅re(b)                          2      2    t⋅re(b)
# Γ(a - b)  + ⅈ⋅a⋅b ⋅t⋅ℯ       ⋅sin(t⋅im(b))⋅Γ(a - b + 1)  + a⋅b ⋅t⋅ℯ       ⋅cos
# ──────────────────────────────────────────────────────────────────────────────
# ...

# %% [markdown]
# 19

# %%
(a*sin(b*t)-b*sin(a*t))/(a*b*(a**2-b**2))
# Out:
# a⋅sin(b⋅t) - b⋅sin(a⋅t)
# ───────────────────────
#          ⎛ 2    2⎞
#      a⋅b⋅⎝a  - b ⎠

# %%
laplace_transform(_, t, p)
# Out:
# (nan, -∞, True)

# %%
1/((p**2+a**2)*(p**2+b**2))
# Out:
#          1
# ───────────────────
# ⎛ 2    2⎞ ⎛ 2    2⎞
# ⎝a  + p ⎠⋅⎝b  + p ⎠

# %%
inverse_laplace_transform(_, p, t)
# Out:
#    ⎛     t⋅im(a)                   t⋅im(a)                     t⋅im(a) + 2⋅t⋅i
# -ⅈ⋅⎝ⅈ⋅a⋅ℯ       ⋅sin(t⋅re(b)) + a⋅ℯ       ⋅cos(t⋅re(b)) + ⅈ⋅a⋅ℯ
# ──────────────────────────────────────────────────────────────────────────────
#
#
# m(b)                   t⋅im(a) + 2⋅t⋅im(b)                     t⋅im(b)
#     ⋅sin(t⋅re(b)) - a⋅ℯ                   ⋅cos(t⋅re(b)) - ⅈ⋅b⋅ℯ       ⋅sin(t⋅r
# ──────────────────────────────────────────────────────────────────────────────
#                                                              2⋅a⋅b⋅(a - b)⋅(a
#
#            t⋅im(b)                     2⋅t⋅im(a) + t⋅im(b)                   2
# e(a)) - b⋅ℯ       ⋅cos(t⋅re(a)) - ⅈ⋅b⋅ℯ                   ⋅sin(t⋅re(a)) + b⋅ℯ
# ──────────────────────────────────────────────────────────────────────────────
# + b)
#
# ⋅t⋅im(a) + t⋅im(b)             ⎞  -t⋅im(a) - t⋅im(b)
#                   ⋅cos(t⋅re(a))⎠⋅ℯ                  ⋅Heaviside(t)
# ─────────────────────────────────────────────────────────────────

# %% [markdown]
# 20

# %%
(cos(b*t)-cos(a*t))/(a**2-b**2)
# Out:
# -cos(a⋅t) + cos(b⋅t)
# ────────────────────
#        2    2
#       a  - b

# %%
laplace_transform(_, t, p)
# Out:
# (nan, -∞, True)

# %%
p/((p**2+a**2)*(p**2+b**2))
# Out:
#          p
# ───────────────────
# ⎛ 2    2⎞ ⎛ 2    2⎞
# ⎝a  + p ⎠⋅⎝b  + p ⎠

# %%
inverse_laplace_transform(_, p, t)
# Out:
# ⎛   t⋅im(a)                 t⋅im(a)                   t⋅im(b)
# ⎝ⅈ⋅ℯ       ⋅sin(t⋅re(b)) + ℯ       ⋅cos(t⋅re(b)) - ⅈ⋅ℯ       ⋅sin(t⋅re(a)) - ℯ
# ──────────────────────────────────────────────────────────────────────────────
#
#
# t⋅im(b)                   t⋅im(a) + 2⋅t⋅im(b)                 t⋅im(a) + 2⋅t⋅im
#        ⋅cos(t⋅re(a)) - ⅈ⋅ℯ                   ⋅sin(t⋅re(b)) + ℯ
# ──────────────────────────────────────────────────────────────────────────────
#                                                      2⋅(a - b)⋅(a + b)
#
# (b)                   2⋅t⋅im(a) + t⋅im(b)                 2⋅t⋅im(a) + t⋅im(b)
#    ⋅cos(t⋅re(b)) + ⅈ⋅ℯ                   ⋅sin(t⋅re(a)) - ℯ                   ⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#             ⎞  -t⋅im(a) - t⋅im(b)
# cos(t⋅re(a))⎠⋅ℯ                  ⋅Heaviside(t)
# ──────────────────────────────────────────────

# %% [markdown]
# 21

# %%
cos(a*t)**2
# Out:
#    2
# cos (a⋅t)

# %%
#laplace_transform(_, t, p)
# Python exception

# %%
(p**2+2*a**2)/(p*(p**2+4*a**2))
# Out:
#      2    2
#   2⋅a  + p
# ─────────────
#   ⎛   2    2⎞
# p⋅⎝4⋅a  + p ⎠

# %%
inverse_laplace_transform(_, p, t)
# Out:
#  ⎛   4⋅t⋅im(a)                   4⋅t⋅im(a)                     2⋅t⋅im(a)
# -⎝ⅈ⋅ℯ         ⋅sin(2⋅t⋅re(a)) - ℯ         ⋅cos(2⋅t⋅re(a)) - 2⋅ℯ          - ⅈ⋅s
# ──────────────────────────────────────────────────────────────────────────────
#                                                                   4
#
#                               ⎞  -2⋅t⋅im(a)
# in(2⋅t⋅re(a)) - cos(2⋅t⋅re(a))⎠⋅ℯ          ⋅Heaviside(t)
# ────────────────────────────────────────────────────────

# %% [markdown]
# 22

# %%
sin(a*t)**2
# Out:
#    2
# sin (a⋅t)

# %%
#laplace_transform(_, t, p)
# Python exception

# %%
2*a**2/(p*(p**2+4*a**2))
# Out:
#         2
#      2⋅a
# ─────────────
#   ⎛   2    2⎞
# p⋅⎝4⋅a  + p ⎠

# %%
inverse_laplace_transform(_, p, t)
# Out:
# ⎛   4⋅t⋅im(a)                   4⋅t⋅im(a)                     2⋅t⋅im(a)
# ⎝ⅈ⋅ℯ         ⋅sin(2⋅t⋅re(a)) - ℯ         ⋅cos(2⋅t⋅re(a)) + 2⋅ℯ          - ⅈ⋅si
# ──────────────────────────────────────────────────────────────────────────────
#                                                                   4
#
#                              ⎞  -2⋅t⋅im(a)
# n(2⋅t⋅re(a)) - cos(2⋅t⋅re(a))⎠⋅ℯ          ⋅Heaviside(t)
# ───────────────────────────────────────────────────────

# %% [markdown]
# 23

# %%
cosh(a*t)**2
# Out:
#     2
# cosh (a⋅t)

# %%
laplace_transform(_, t, p)
# Out:
# (nan, -∞, True)

# %%
(p**2-2*a**2)/(p*(p**2-4*a**2))
# Out:
#        2    2
#   - 2⋅a  + p
# ───────────────
#   ⎛     2    2⎞
# p⋅⎝- 4⋅a  + p ⎠

# %%
inverse_laplace_transform(_, p, t)
# Out:
# ⎛   4⋅t⋅re(a)                   4⋅t⋅re(a)                     2⋅t⋅re(a)
# ⎝ⅈ⋅ℯ         ⋅sin(2⋅t⋅im(a)) + ℯ         ⋅cos(2⋅t⋅im(a)) + 2⋅ℯ          - ⅈ⋅si
# ──────────────────────────────────────────────────────────────────────────────
#                                                                   4
#
#                              ⎞  -2⋅t⋅re(a)
# n(2⋅t⋅im(a)) + cos(2⋅t⋅im(a))⎠⋅ℯ          ⋅Heaviside(t)
# ───────────────────────────────────────────────────────

# %% [markdown]
# 24

# %%
sinh(a*t)**2
# Out:
#     2
# sinh (a⋅t)

# %%
laplace_transform(_, t, p)
# Out:
# (nan, -∞, True)

# %%
2*a**2/(p*(p**2-4*a**2))
# Out:
#          2
#       2⋅a
# ───────────────
#   ⎛     2    2⎞
# p⋅⎝- 4⋅a  + p ⎠

# %%
inverse_laplace_transform(_, p, t)
# Out:
# ⎛   4⋅t⋅re(a)                   4⋅t⋅re(a)                     2⋅t⋅re(a)
# ⎝ⅈ⋅ℯ         ⋅sin(2⋅t⋅im(a)) + ℯ         ⋅cos(2⋅t⋅im(a)) - 2⋅ℯ          - ⅈ⋅si
# ──────────────────────────────────────────────────────────────────────────────
#                                                                   4
#
#                              ⎞  -2⋅t⋅re(a)
# n(2⋅t⋅im(a)) + cos(2⋅t⋅im(a))⎠⋅ℯ          ⋅Heaviside(t)
# ───────────────────────────────────────────────────────

# %% [markdown]
# 25

# %%
sin(a*t)*sinh(a*t)
# Out:
# sin(a⋅t)⋅sinh(a⋅t)

# %%
#laplace_transform(_, t, p)
# Python exception

# %%
2*a**2*p/(p**2+4*a**2)
# Out:
#      2
#   2⋅a ⋅p
# ─────────
#    2    2
# 4⋅a  + p

# %%
inverse_laplace_transform(_, p, t)
# Out:
#   2 ⎛   4⋅t⋅im(a)                   4⋅t⋅im(a)
# -a ⋅⎝ⅈ⋅ℯ         ⋅sin(2⋅t⋅re(a)) - ℯ         ⋅cos(2⋅t⋅re(a)) - ⅈ⋅sin(2⋅t⋅re(a)
#
#                   ⎞  -2⋅t⋅im(a)
# ) - cos(2⋅t⋅re(a))⎠⋅ℯ          ⋅Heaviside(t)

# %% [markdown]
# 26

# %%
sin(a*t)*cosh(a*t)
# Out:
# sin(a⋅t)⋅cosh(a⋅t)

# %%
#laplace_transform(_, t, p)
# Python exception

# %%
a*(p**2+2*a**2)/(p**4+4*a**4)
# Out:
#   ⎛   2    2⎞
# a⋅⎝2⋅a  + p ⎠
# ─────────────
#      4    4
#   4⋅a  + p

# %%
inverse_laplace_transform(_, p, t)
# Out:
#   ⎛   -t⋅re(a) - t⋅im(a)                           -t⋅re(a) - t⋅im(a)
# ⅈ⋅⎝ⅈ⋅ℯ                  ⋅sin(t⋅re(a) - t⋅im(a)) + ℯ                  ⋅cos(t⋅re
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                     -t⋅re(a) + t⋅im(a)                           -t⋅re(a) + t⋅
# (a) - t⋅im(a)) + ⅈ⋅ℯ                  ⋅sin(t⋅re(a) + t⋅im(a)) - ℯ
# ──────────────────────────────────────────────────────────────────────────────
#
#
# im(a)                             t⋅re(a) - t⋅im(a)
#      ⋅cos(t⋅re(a) + t⋅im(a)) + ⅈ⋅ℯ                 ⋅sin(t⋅re(a) + t⋅im(a)) + ℯ
# ──────────────────────────────────────────────────────────────────────────────
#                         2⋅(-1 + ⅈ)⋅(1 + ⅈ)
#
# t⋅re(a) - t⋅im(a)                             t⋅re(a) + t⋅im(a)
#                  ⋅cos(t⋅re(a) + t⋅im(a)) + ⅈ⋅ℯ                 ⋅sin(t⋅re(a) -
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ...

# %% [markdown]
# 27

# %%
cos(a*t)*sinh(a*t)
# Out:
# cos(a⋅t)⋅sinh(a⋅t)

# %%
#laplace_transform(_, t, p)
# Python exception

# %%
a*(p**2-2*a**2)/(p**4+4*a**4)
# Out:
#   ⎛     2    2⎞
# a⋅⎝- 2⋅a  + p ⎠
# ───────────────
#       4    4
#    4⋅a  + p

# %%
inverse_laplace_transform(_, p, t)
# Out:
#    ⎛ -t⋅re(a) - t⋅im(a)                             -t⋅re(a) - t⋅im(a)
# -ⅈ⋅⎝ℯ                  ⋅sin(t⋅re(a) - t⋅im(a)) - ⅈ⋅ℯ                  ⋅cos(t⋅r
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                    -t⋅re(a) + t⋅im(a)                             -t⋅re(a) + t
# e(a) - t⋅im(a)) - ℯ                  ⋅sin(t⋅re(a) + t⋅im(a)) - ⅈ⋅ℯ
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ⋅im(a)                           t⋅re(a) - t⋅im(a)
#       ⋅cos(t⋅re(a) + t⋅im(a)) - ℯ                 ⋅sin(t⋅re(a) + t⋅im(a)) + ⅈ⋅
# ──────────────────────────────────────────────────────────────────────────────
#                                  2        2
#                          (-1 + ⅈ) ⋅(1 + ⅈ)
#
#  t⋅re(a) - t⋅im(a)                           t⋅re(a) + t⋅im(a)
# ℯ                 ⋅cos(t⋅re(a) + t⋅im(a)) + ℯ                 ⋅sin(t⋅re(a) - t
# ...

# %% [markdown]
# 28

# %%
cos(a*t)*cosh(a*t)
# Out:
# cos(a⋅t)⋅cosh(a⋅t)

# %%
#laplace_transform(_, t, p)
# Python exception

# %%
p**3/(p**4+4*a**4)
# Out:
#      3
#     p
# ─────────
#    4    4
# 4⋅a  + p

# %%
#inverse_laplace_transform(_, p, t)

# %% [markdown]
# 29

# %%
t/2*sin(a*t)
# Out:
# t⋅sin(a⋅t)
# ──────────
#     2

# %%
laplace_transform(_, t, p)
# Out:
# ⎛     a           │                 ⎛          2      ⎞│    ⎞
# ⎜────────────, 0, │periodic_argument⎝polar_lift (a), ∞⎠│ = 0⎟
# ⎜           2                                               ⎟
# ⎜   ⎛ 2    ⎞                                                ⎟
# ⎜ 3 ⎜a     ⎟                                                ⎟
# ⎜p ⋅⎜── + 1⎟                                                ⎟
# ⎜   ⎜ 2    ⎟                                                ⎟
# ⎝   ⎝p     ⎠                                                ⎠

# %%
ratsimp(_[0])
# Out:
#        a⋅p
# ─────────────────
#  4      2  2    4
# a  + 2⋅a ⋅p  + p

# %%
#inverse_laplace_transform(_, p, t)
# ValueError: too many values to unpack

# %%
a*p/(p**2+a**2)**2
# Out:
#    a⋅p
# ──────────
#          2
# ⎛ 2    2⎞
# ⎝a  + p ⎠

# %%
#inverse_laplace_transform(_, p, t)
# Same error here

# %% [markdown]
# 30

# %%
t/2*sinh(a*t)
# Out:
# t⋅sinh(a⋅t)
# ───────────
#      2

# %%
laplace_transform(_, t, p)
# Out:
# (nan, -∞, True)

# %%
a*p/(p**2-a**2)**2
# Out:
#     a⋅p
# ────────────
#            2
# ⎛   2    2⎞
# ⎝- a  + p ⎠

# %%
inverse_laplace_transform(_, p, t)
# Out:
#   ⎛   2⋅t⋅re(a)                 2⋅t⋅re(a)
# t⋅⎝ⅈ⋅ℯ         ⋅sin(t⋅im(a)) + ℯ         ⋅cos(t⋅im(a)) + ⅈ⋅sin(t⋅im(a)) - cos(
# ──────────────────────────────────────────────────────────────────────────────
#                                                       4
#
#         ⎞  -t⋅re(a)
# t⋅im(a))⎠⋅ℯ        ⋅Heaviside(t)
# ────────────────────────────────

# %% [markdown]
# 31

# %%
(b*sinh(a*t)-a*sinh(b*t))/(a**2-b**2)
# Out:
# -a⋅sinh(b⋅t) + b⋅sinh(a⋅t)
# ──────────────────────────
#           2    2
#          a  - b

# %%
laplace_transform(_, t, p)
# Out:
# (nan, -∞, True)

# %%
a*b/((p**2-a**2)*(p**2-b**2))
# Out:
#           a⋅b
# ───────────────────────
# ⎛   2    2⎞ ⎛   2    2⎞
# ⎝- a  + p ⎠⋅⎝- b  + p ⎠

# %%
inverse_laplace_transform(_, p, t)
# Out:
#  ⎛     t⋅re(a)                   t⋅re(a)                     t⋅re(a) + 2⋅t⋅re(
# -⎝ⅈ⋅a⋅ℯ       ⋅sin(t⋅im(b)) - a⋅ℯ       ⋅cos(t⋅im(b)) + ⅈ⋅a⋅ℯ
# ──────────────────────────────────────────────────────────────────────────────
#
#
# b)                   t⋅re(a) + 2⋅t⋅re(b)                     t⋅re(b)
#   ⋅sin(t⋅im(b)) + a⋅ℯ                   ⋅cos(t⋅im(b)) - ⅈ⋅b⋅ℯ       ⋅sin(t⋅im(
# ──────────────────────────────────────────────────────────────────────────────
#                                                               2⋅(a - b)⋅(a + b
#
#          t⋅re(b)                     2⋅t⋅re(a) + t⋅re(b)                   2⋅t
# a)) + b⋅ℯ       ⋅cos(t⋅im(a)) - ⅈ⋅b⋅ℯ                   ⋅sin(t⋅im(a)) - b⋅ℯ
# ──────────────────────────────────────────────────────────────────────────────
# )
#
# ⋅re(a) + t⋅re(b)             ⎞  -t⋅re(a) - t⋅re(b)
#                 ⋅cos(t⋅im(a))⎠⋅ℯ                  ⋅Heaviside(t)
# ───────────────────────────────────────────────────────────────

# %% [markdown]
# 32

# %%
(cosh(a*t)-cosh(b*t))/(a**2-b**2)
# Out:
# cosh(a⋅t) - cosh(b⋅t)
# ─────────────────────
#         2    2
#        a  - b

# %%
laplace_transform(_, t, p)
# Out:
# (nan, -∞, True)

# %%
p/((p**2-a**2)*(p**2-b**2))
# Out:
#            p
# ───────────────────────
# ⎛   2    2⎞ ⎛   2    2⎞
# ⎝- a  + p ⎠⋅⎝- b  + p ⎠

# %%
inverse_laplace_transform(_, p, t)
# Out:
# ⎛   t⋅re(a)                 t⋅re(a)                   t⋅re(b)
# ⎝ⅈ⋅ℯ       ⋅sin(t⋅im(b)) - ℯ       ⋅cos(t⋅im(b)) - ⅈ⋅ℯ       ⋅sin(t⋅im(a)) + ℯ
# ──────────────────────────────────────────────────────────────────────────────
#
#
# t⋅re(b)                   t⋅re(a) + 2⋅t⋅re(b)                 t⋅re(a) + 2⋅t⋅re
#        ⋅cos(t⋅im(a)) - ⅈ⋅ℯ                   ⋅sin(t⋅im(b)) - ℯ
# ──────────────────────────────────────────────────────────────────────────────
#                                                      2⋅(a - b)⋅(a + b)
#
# (b)                   2⋅t⋅re(a) + t⋅re(b)                 2⋅t⋅re(a) + t⋅re(b)
#    ⋅cos(t⋅im(b)) + ⅈ⋅ℯ                   ⋅sin(t⋅im(a)) + ℯ                   ⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#             ⎞  -t⋅re(a) - t⋅re(b)
# cos(t⋅im(a))⎠⋅ℯ                  ⋅Heaviside(t)
# ──────────────────────────────────────────────

# %% [markdown]
# 33

# %%
1/sqrt(pi*t)
# Out:
#      1
# ───────────
#   ___   ___
# ╲╱ π ⋅╲╱ t

# %%
laplace_transform(_, t, p)
# Out:
# ⎛  1           ⎞
# ⎜─────, 0, True⎟
# ⎜  ___         ⎟
# ⎝╲╱ p          ⎠

# %%
inverse_laplace_transform(_[0], p, t)
# Out:
#                        ⎛  1              ⎞
# InverseLaplaceTransform⎜─────, p, t, None⎟
#                        ⎜  ___            ⎟
#                        ⎝╲╱ p             ⎠

# %% [markdown]
# 34

# %%
2*sqrt(t/pi)
# Out:
#     ___
# 2⋅╲╱ t
# ───────
#    ___
#  ╲╱ π

# %%
laplace_transform(_, t, p)
# Out:
# ⎛ 1           ⎞
# ⎜────, 0, True⎟
# ⎜ 3/2         ⎟
# ⎝p            ⎠

# %%
inverse_laplace_transform(_[0], p, t)
# Out:
#     ___
# 2⋅╲╱ t ⋅Heaviside(t)
# ────────────────────
#          ___
#        ╲╱ π

# %% [markdown]
# 35

# %%
factorial(n)/factorial(2*n)*4**n/sqrt(pi)*t**(n-S(1)/2)
# Out:
#  n  n - 1/2
# 4 ⋅t       ⋅n!
# ──────────────
#    ___
#  ╲╱ π ⋅(2⋅n)!

# %%
laplace_transform(_, t, p)
# Out:
# ⎛ n  -n - 1/2                               ⎞
# ⎜4 ⋅p        ⋅n!⋅(n - 1/2)!                 ⎟
# ⎜──────────────────────────, 0, -n + 1/2 < 1⎟
# ⎜         ___                               ⎟
# ⎝       ╲╱ π ⋅(2⋅n)!                        ⎠

# %%
simplify(_[0])
# Out:
#  n  -n - 1/2
# 4 ⋅p        ⋅n!⋅(n - 1/2)!
# ──────────────────────────
#          ___
#        ╲╱ π ⋅(2⋅n)!

# %%
combsimp(_)
# Out:
#  n  -n - 1/2
# 4 ⋅p        ⋅n!⋅(n - 1/2)!
# ──────────────────────────
#          ___
#        ╲╱ π ⋅(2⋅n)!

# %%
inverse_laplace_transform(_, p, t)
# Out:
#  n  n - 1/2
# 4 ⋅t       ⋅Heaviside(t)⋅n!
# ───────────────────────────
#           ___
#         ╲╱ π ⋅(2⋅n)!

# %%
1/(p**n*sqrt(p))
# Out:
#   -n
#  p
# ─────
#   ___
# ╲╱ p

# %%
inverse_laplace_transform(_, p, t)
# Out:
#  n - 1/2
# t       ⋅Heaviside(t)
# ─────────────────────
#       Γ(n + 1/2)

# %% [markdown]
# 36

# %%
1/sqrt(pi*t)*exp(-a*t)
# Out:
#     -a⋅t
#    ℯ
# ───────────
#   ___   ___
# ╲╱ π ⋅╲╱ t

# %%
laplace_transform(_, t, p)
# Out:
# ⎛        1                                         π⎞
# ⎜─────────────────, 0, │periodic_argument(a, ∞)│ < ─⎟
# ⎜          _______                                 2⎟
# ⎜  ___    ╱ a + p                                   ⎟
# ⎜╲╱ a ⋅  ╱  ─────                                   ⎟
# ⎝      ╲╱     a                                     ⎠

# %%
#radsimp(_[0])
# Takes forever

# %%
inverse_laplace_transform(_[0], p, t)
# Out:
#                        ⎛     1                 ⎞
# InverseLaplaceTransform⎜───────────, p, t, None⎟
#                        ⎜    _______            ⎟
#                        ⎜   ╱     p             ⎟
#                        ⎜  ╱  1 + ─             ⎟
#                        ⎝╲╱       a             ⎠
# ────────────────────────────────────────────────
#                        ___
#                      ╲╱ a

# %%
1/sqrt(p+a)
# Out:
#     1
# ─────────
#   _______
# ╲╱ a + p

# %%
inverse_laplace_transform(_, p, t)
# Out:
#                        ⎛    1                ⎞
# InverseLaplaceTransform⎜─────────, p, t, None⎟
#                        ⎜  _______            ⎟
#                        ⎝╲╱ a + p             ⎠

# %% [markdown]
# 37

# %%
1/(2*t*sqrt(pi*t))*(exp(-b*t)-exp(-a*t))
# Out:
#  -b⋅t    -a⋅t
# ℯ     - ℯ
# ─────────────
#      ___  3/2
#  2⋅╲╱ π ⋅t

# %%
#laplace_transform(_, t, p)

# %%
sqrt(p+a)-sqrt(p+b)
# Out:
#   _______     _______
# ╲╱ a + p  - ╲╱ b + p

# %%
inverse_laplace_transform(_, p, t)
# Out:
#                        ⎛  _______            ⎞                          ⎛  ___
# InverseLaplaceTransform⎝╲╱ a + p , p, t, None⎠ - InverseLaplaceTransform⎝╲╱ b
#
# ____            ⎞
# + p , p, t, None⎠

# %% [markdown]
# 38

# %%
sin(a*t)/(t*sqrt(2*pi*t))
# Out:
#   ___
# ╲╱ 2 ⋅sin(a⋅t)
# ──────────────
#      ___  3/2
#  2⋅╲╱ π ⋅t

# %%
laplace_transform(_, t, p)
# Out:
# ⎛                a                     │                 ⎛          2      ⎞│
# ⎜─────────────────────────────────, 0, │periodic_argument⎝polar_lift (a), ∞⎠│
# ⎜             ____________________
# ⎜            ╱       ________
# ⎜           ╱       ╱  2
# ⎜  ___     ╱       ╱  a
# ⎜╲╱ p ⋅   ╱       ╱   ── + 1  + 1
# ⎜        ╱       ╱     2
# ⎝      ╲╱      ╲╱     p
#
#    ⎞
# = 0⎟
#    ⎟
#    ⎟
#    ⎟
#    ⎟
#    ⎟
#    ⎟
#    ⎠

# %%
inverse_laplace_transform(_[0], p, t)
# Out:
#                          ⎛                1                            ⎞
# a⋅InverseLaplaceTransform⎜─────────────────────────────────, p, t, None⎟
#                          ⎜             ____________________            ⎟
#                          ⎜            ╱       ________                 ⎟
#                          ⎜           ╱       ╱  2                      ⎟
#                          ⎜  ___     ╱       ╱  a                       ⎟
#                          ⎜╲╱ p ⋅   ╱       ╱   ── + 1  + 1             ⎟
#                          ⎜        ╱       ╱     2                      ⎟
#                          ⎝      ╲╱      ╲╱     p                       ⎠

# %%
sqrt(sqrt(p**2+a**2)-p)
# Out:
#     ___________________
#    ╱         _________
#   ╱         ╱  2    2
# ╲╱   -p + ╲╱  a  + p

# %%
inverse_laplace_transform(_, p, t)
# Out:
#                        ⎛    ___________________            ⎞
#                        ⎜   ╱         _________             ⎟
#                        ⎜  ╱         ╱  2    2              ⎟
# InverseLaplaceTransform⎝╲╱   -p + ╲╱  a  + p   , p, t, None⎠

# %% [markdown]
# 39

# %%
sqrt(2/(pi*t))*sin(a*t)
# Out:
#           ___
#   ___    ╱ 1
# ╲╱ 2 ⋅  ╱  ─ ⋅sin(a⋅t)
#       ╲╱   t
# ──────────────────────
#           ___
#         ╲╱ π

# %%
laplace_transform(_, t, p)
# Out:
# ⎛     ⎛              ________     ⎞
# ⎜     ⎜             ╱  2          ⎟
# ⎜     ⎜ 2    2     ╱  a          2⎟
# ⎜   a⋅⎜a  + p ⋅   ╱   ── + 1  + p ⎟
# ⎜     ⎜          ╱     2          ⎟
# ⎜     ⎝        ╲╱     p           ⎠         │                 ⎛          2
# ⎜──────────────────────────────────────, 0, │periodic_argument⎝polar_lift (a),
# ⎜                                   3/2
# ⎜               ⎛      ________    ⎞
# ⎜               ⎜     ╱  2         ⎟
# ⎜ 3/2 ⎛ 2    2⎞ ⎜    ╱  a          ⎟
# ⎜p   ⋅⎝a  + p ⎠⋅⎜   ╱   ── + 1  + 1⎟
# ⎜               ⎜  ╱     2         ⎟
# ⎝               ⎝╲╱     p          ⎠
#
#         ⎞
#         ⎟
#         ⎟
#         ⎟
#         ⎟
#   ⎞│    ⎟
#  ∞⎠│ = 0⎟
#         ⎟
#         ⎟
#         ⎟
#         ⎟
#         ⎟
#         ⎟
#         ⎠

# %%
inverse_laplace_transform(_[0], p, t)
# Out:
#
#
#
#
#
#  3                        ⎛                              1
# a ⋅InverseLaplaceTransform⎜───────────────────────────────────────────────────
#                           ⎜                            3/2
#                           ⎜        ⎛      ________    ⎞           ⎛      _____
#                           ⎜        ⎜     ╱  2         ⎟           ⎜     ╱  2
#                           ⎜ 2  3/2 ⎜    ╱  a          ⎟       7/2 ⎜    ╱  a
#                           ⎜a ⋅p   ⋅⎜   ╱   ── + 1  + 1⎟    + p   ⋅⎜   ╱   ── +
#                           ⎜        ⎜  ╱     2         ⎟           ⎜  ╱     2
#                           ⎝        ⎝╲╱     p          ⎠           ⎝╲╱     p
#
#
#
#
#
#                                                     ⎛
#                        ⎞                            ⎜
# ───────────, p, t, None⎟ + a⋅InverseLaplaceTransform⎜─────────────────────────
#         3/2            ⎟                            ⎜
# ...

# %%
sqrt((sqrt(p**2+a**2)-p)/(p**2+a**2))
# Out:
#        ___________________
#       ╱         _________
#      ╱         ╱  2    2
#     ╱   -p + ╲╱  a  + p
#    ╱    ─────────────────
#   ╱           2    2
# ╲╱           a  + p

# %%
inverse_laplace_transform(_, p, t)
# Out:
#                        ⎛      __________________________            ⎞
#                        ⎜     ╱      p           1                   ⎟
# InverseLaplaceTransform⎜    ╱  - ─────── + ──────────── , p, t, None⎟
#                        ⎜   ╱      2    2      _________             ⎟
#                        ⎜  ╱      a  + p      ╱  2    2              ⎟
#                        ⎝╲╱                 ╲╱  a  + p               ⎠

# %% [markdown]
# 40

# %%
sqrt(2/(pi*t))*cos(a*t)
# Out:
#           ___
#   ___    ╱ 1
# ╲╱ 2 ⋅  ╱  ─ ⋅cos(a⋅t)
#       ╲╱   t
# ──────────────────────
#           ___
#         ╲╱ π

# %%
laplace_transform(_, t, p)
# Out:
# ⎛          ⎛    ⎛a⎞⎞                                                ⎞
# ⎜          ⎜atan⎜─⎟⎟                                                ⎟
# ⎜   ___    ⎜    ⎝p⎠⎟                                                ⎟
# ⎜ ╲╱ 2 ⋅cos⎜───────⎟                                                ⎟
# ⎜          ⎝   2   ⎠      │                 ⎛          2      ⎞│    ⎟
# ⎜────────────────────, 0, │periodic_argument⎝polar_lift (a), ∞⎠│ = 0⎟
# ⎜            ________                                               ⎟
# ⎜           ╱  2                                                    ⎟
# ⎜  ___     ╱  a                                                     ⎟
# ⎜╲╱ p ⋅   ╱   ── + 1                                                ⎟
# ⎜      4 ╱     2                                                    ⎟
# ⎝      ╲╱     p                                                     ⎠

# %%
inverse_laplace_transform(_[0], p, t)
# Out:
#                              ⎛       ⎛    ⎛a⎞⎞                ⎞
#                              ⎜       ⎜atan⎜─⎟⎟                ⎟
#                              ⎜       ⎜    ⎝p⎠⎟                ⎟
#                              ⎜    cos⎜───────⎟                ⎟
#   ___                        ⎜       ⎝   2   ⎠                ⎟
# ╲╱ 2 ⋅InverseLaplaceTransform⎜────────────────────, p, t, None⎟
#                              ⎜            ________            ⎟
#                              ⎜           ╱  2                 ⎟
#                              ⎜  ___     ╱  a                  ⎟
#                              ⎜╲╱ p ⋅   ╱   ── + 1             ⎟
#                              ⎜      4 ╱     2                 ⎟
#                              ⎝      ╲╱     p                  ⎠

# %%
sqrt((sqrt(p**2+a**2)+p)/(p**2+a**2))
# Out:
#        __________________
#       ╱        _________
#      ╱        ╱  2    2
#     ╱   p + ╲╱  a  + p
#    ╱    ────────────────
#   ╱          2    2
# ╲╱          a  + p

# %%
inverse_laplace_transform(_, p, t)
# Out:
#                        ⎛      ________________________            ⎞
#                        ⎜     ╱    p           1                   ⎟
# InverseLaplaceTransform⎜    ╱  ─────── + ──────────── , p, t, None⎟
#                        ⎜   ╱    2    2      _________             ⎟
#                        ⎜  ╱    a  + p      ╱  2    2              ⎟
#                        ⎝╲╱               ╲╱  a  + p               ⎠

# %% [markdown]
# 41

# %%
sqrt(2/(pi*t))*sinh(a*t)
# Out:
#           ___
#   ___    ╱ 1
# ╲╱ 2 ⋅  ╱  ─ ⋅sinh(a⋅t)
#       ╲╱   t
# ───────────────────────
#            ___
#          ╲╱ π

# %%
#laplace_transform(_, t, p)
# Takes forever

# %%
sqrt((sqrt(p**2-a**2)-p)/(p**2-a**2))
# Out:
#        _____________________
#       ╱         ___________
#      ╱         ╱    2    2
#     ╱   -p + ╲╱  - a  + p
#    ╱    ───────────────────
#   ╱             2    2
# ╲╱           - a  + p

# %%
inverse_laplace_transform(_, p, t)
# Out:
#                        ⎛      ______________________________            ⎞
#                        ⎜     ╱       p             1                    ⎟
# InverseLaplaceTransform⎜    ╱  - ───────── + ────────────── , p, t, None⎟
#                        ⎜   ╱        2    2      ___________             ⎟
#                        ⎜  ╱      - a  + p      ╱    2    2              ⎟
#                        ⎝╲╱                   ╲╱  - a  + p               ⎠

# %% [markdown]
# 42

# %%
sqrt(2/(pi*t))*cosh(a*t)
# Out:
#           ___
#   ___    ╱ 1
# ╲╱ 2 ⋅  ╱  ─ ⋅cosh(a⋅t)
#       ╲╱   t
# ───────────────────────
#            ___
#          ╲╱ π

# %%
laplace_transform(_, t, p)
# Out:
# ⎛⎧      ⎛                                                  ⎛       ⎛
# ⎜⎪      ⎜                                                  ⎜   ___ ⎜         4
# ⎜⎪      ⎜                                                  ⎜ ╲╱ 2 ⋅⎜1 - ──────
# ⎜⎪      ⎜                                                  ⎜       ⎜       ⎛
# ⎜⎪      ⎜                                                  ⎜       ⎜     2 ⎜
# ⎜⎪      ⎜                                                  ⎜       ⎜    a ⋅⎜-4
# ⎜⎪      ⎜                                                  ⎜       ⎜       ⎜
# ⎜⎪      ⎜                                            ___   ⎜       ⎝       ⎝
# ⎜⎪      ⎜                                        2⋅╲╱ π ⋅p⋅⎜──────────────────
# ⎜⎪      ⎜                                                  ⎜       ___________
# ⎜⎪      ⎜  ___ ⎛      1               1      ⎞             ⎜      ╱       ____
# ⎜⎪      ⎜╲╱ π ⋅⎜───────────── + ─────────────⎟             ⎜     ╱       ╱
# ...

# %%
_[0]
# Out:
# ⎧      ⎛                                                  ⎛       ⎛
# ⎪      ⎜                                                  ⎜   ___ ⎜         4⋅
# ⎪      ⎜                                                  ⎜ ╲╱ 2 ⋅⎜1 - ───────
# ⎪      ⎜                                                  ⎜       ⎜       ⎛
# ⎪      ⎜                                                  ⎜       ⎜     2 ⎜
# ⎪      ⎜                                                  ⎜       ⎜    a ⋅⎜-4
# ⎪      ⎜                                                  ⎜       ⎜       ⎜
# ⎪      ⎜                                            ___   ⎜       ⎝       ⎝
# ⎪      ⎜                                        2⋅╲╱ π ⋅p⋅⎜───────────────────
# ⎪      ⎜                                                  ⎜       ____________
# ⎪      ⎜  ___ ⎛      1               1      ⎞             ⎜      ╱       _____
# ⎪      ⎜╲╱ π ⋅⎜───────────── + ─────────────⎟             ⎜     ╱       ╱
# ...

# %%
sqrt((sqrt(p**2-a**2)+p)/(p**2-a**2))
# Out:
#        ____________________
#       ╱        ___________
#      ╱        ╱    2    2
#     ╱   p + ╲╱  - a  + p
#    ╱    ──────────────────
#   ╱            2    2
# ╲╱          - a  + p

# %%
inverse_laplace_transform(_, p, t)
# Out:
#                        ⎛      ____________________________            ⎞
#                        ⎜     ╱     p             1                    ⎟
# InverseLaplaceTransform⎜    ╱  ───────── + ────────────── , p, t, None⎟
#                        ⎜   ╱      2    2      ___________             ⎟
#                        ⎜  ╱    - a  + p      ╱    2    2              ⎟
#                        ⎝╲╱                 ╲╱  - a  + p               ⎠

# %% [markdown]
# 43

# %%
tau = Symbol("tau")

# %%
2/sqrt(a*pi)*integrate(exp(-tau**2), (tau, 0, sqrt(a*t)))
# Out:
#    ⎛  _____⎞
# erf⎝╲╱ a⋅t ⎠
# ────────────
#      ___
#    ╲╱ a

# %%
laplace_transform(_, t, p)
# Out:
# ⎛         1                                          π⎞
# ⎜───────────────────, 0, │periodic_argument(a, ∞)│ ≤ ─⎟
# ⎜            _______                                 2⎟
# ⎜  ___      ╱ a + p                                   ⎟
# ⎜╲╱ a ⋅p⋅  ╱  ─────                                   ⎟
# ⎝        ╲╱     a                                     ⎠

# %%
inverse_laplace_transform(_[0], p, t)
# Out:
#                        ⎛      1                  ⎞
# InverseLaplaceTransform⎜─────────────, p, t, None⎟
#                        ⎜      _______            ⎟
#                        ⎜     ╱     p             ⎟
#                        ⎜p⋅  ╱  1 + ─             ⎟
#                        ⎝  ╲╱       a             ⎠
# ──────────────────────────────────────────────────
#                         ___
#                       ╲╱ a

# %%
1/(p*sqrt(p+a))
# Out:
#      1
# ───────────
#     _______
# p⋅╲╱ a + p

# %%
inverse_laplace_transform(_, p, t)
# Out:
#                 ⎛  ___   ___⎞
# Heaviside(t)⋅erf⎝╲╱ a ⋅╲╱ t ⎠
# ─────────────────────────────
#               ___
#             ╲╱ a

# %% [markdown]
# 44

# %%
integrate(exp(-tau**2), (tau, 0, sqrt((b-1)*t)))
# Out:
#   ___    ⎛  ___________⎞
# ╲╱ π ⋅erf⎝╲╱ t⋅(b - 1) ⎠
# ────────────────────────
#            2

# %%
_*2*exp(-a*t)/sqrt(pi*(b-a))
# Out:
#  -a⋅t    ⎛  ___________⎞
# ℯ    ⋅erf⎝╲╱ t⋅(b - 1) ⎠
# ────────────────────────
#          ________
#        ╲╱ -a + b

# %%
laplace_transform(_, t, p)
# Out:
#                 ⎛ -a⋅t    ⎛  _________⎞      ⎞
# LaplaceTransform⎝ℯ    ⋅erf⎝╲╱ b⋅t - t ⎠, t, p⎠
# ──────────────────────────────────────────────
#                     ________
#                   ╲╱ -a + b

# %%
1/((p+a)*sqrt(p+b))
# Out:
#         1
# ─────────────────
#           _______
# (a + p)⋅╲╱ b + p

# %%
inverse_laplace_transform(_, p, t)
# Out:
#                        ⎛            1                        ⎞
# InverseLaplaceTransform⎜─────────────────────────, p, t, None⎟
#                        ⎜    _______       _______            ⎟
#                        ⎝a⋅╲╱ b + p  + p⋅╲╱ b + p             ⎠

# %% [markdown]
# 45

# %%
Integral(exp(-tau**2), (tau, 0, sqrt(a*t))).doit()
# Laplace transform should try the doit() on integrals.
# Out:
#   ___    ⎛  _____⎞
# ╲╱ π ⋅erf⎝╲╱ a⋅t ⎠
# ──────────────────
#         2

# %%
exp(-a*t)/sqrt(pi*t)+2*sqrt(a/pi)*_
# Out:
#                          -a⋅t
#   ___    ⎛  _____⎞      ℯ
# ╲╱ a ⋅erf⎝╲╱ a⋅t ⎠ + ───────────
#                        ___   ___
#                      ╲╱ π ⋅╲╱ t

# %%
laplace_transform(_, t, p)
# Out:
# ⎛          _______
# ⎜  ___    ╱ a + p
# ⎜╲╱ a ⋅  ╱  ─────
# ⎜      ╲╱     a        ⎛                            π
# ⎜─────────────────, 0, ⎜│periodic_argument(a, ∞)│ < ─ ∨ │periodic_argument(a,
# ⎝        p             ⎝                            2
#
#
#
#
#       π                               π⎞   ⎛                            π
# ∞)│ ≤ ─ ∨ │periodic_argument(p, ∞)│ = ─⎟ ∧ ⎜│periodic_argument(a, ∞)│ < ─ ∨ │p
#       2                               2⎠   ⎝                            2
#
#
#
#
#                           π⎞   ⎛                            π
# eriodic_argument(a, ∞)│ ≤ ─⎟ ∧ ⎜│periodic_argument(a, ∞)│ < ─ ∨ │periodic_argu
#                           2⎠   ⎝                            2
#
#
#
#
#               π                               π⎞   ⎛
# ment(a, ∞)│ ≤ ─ ∨ │periodic_argument(a, ∞)│ = ─⎟ ∧ ⎜│periodic_argument(a, ∞)│
#               2                               2⎠   ⎝
#
#                                              ⎞
# ...

# %%
_[0]
# Out:
#           _______
#   ___    ╱ a + p
# ╲╱ a ⋅  ╱  ─────
#       ╲╱     a
# ─────────────────
#         p

# %%
inverse_laplace_transform(_, p, t)
# Out:
#                              ⎛    _______            ⎞
#                              ⎜   ╱     p             ⎟
#                              ⎜  ╱  1 + ─             ⎟
#   ___                        ⎜╲╱       a             ⎟
# ╲╱ a ⋅InverseLaplaceTransform⎜───────────, p, t, None⎟
#                              ⎝     p                 ⎠

# %%
sqrt(p+a)/p
# Out:
#   _______
# ╲╱ a + p
# ─────────
#     p

# %%
inverse_laplace_transform(_, p, t)
# Out:
#                        ⎛  _______            ⎞
#                        ⎜╲╱ a + p             ⎟
# InverseLaplaceTransform⎜─────────, p, t, None⎟
#                        ⎝    p                ⎠

# %% [markdown]
# 46

# %%
besselj(0, a*t)
# Out:
# besselj(0, a⋅t)

# %%
laplace_transform(_, t, p)
# Out:
# ⎛       1             │                 ⎛          2      ⎞│    ⎞
# ⎜────────────────, 0, │periodic_argument⎝polar_lift (a), ∞⎠│ = 0⎟
# ⎜        ________                                               ⎟
# ⎜       ╱      2                                                ⎟
# ⎜      ╱      p                                                 ⎟
# ⎜a⋅   ╱   1 + ──                                                ⎟
# ⎜    ╱         2                                                ⎟
# ⎝  ╲╱         a                                                 ⎠

# %%
simplify(_[0])
# Out:
#        1
# ────────────────
#         ________
#        ╱      2
#       ╱      p
# a⋅   ╱   1 + ──
#     ╱         2
#   ╲╱         a

# %%
inverse_laplace_transform(_, p, t)
# Out:
# Heaviside(t)⋅besselj(0, a⋅t)

# %% [markdown]
# 47

# %%
besseli(0, a*t)
# Out:
# besseli(0, a⋅t)

# %%
laplace_transform(_, t, p)
# Out:
# ⎛⎧                                         │ 2│
# ⎜⎪                                         │p │
# ⎜⎪                 0                   for │──│ < 1, Max(0, cos(Abs(periodic_a
# ⎜⎪                                         │ 2│
# ⎜⎪                                         │a │
# ⎜⎪
# ⎜⎪                                         │ 2│
# ⎜⎪                1                        │a │
# ⎜⎪        ──────────────────           for │──│ < 1
# ⎜⎪                __________               │ 2│
# ⎜⎪               ╱    2                    │p │
# ⎜⎨              ╱    a
# ⎜⎪        p⋅   ╱   - ── + 1
# ⎜⎪            ╱       2
# ⎜⎪          ╲╱       p
# ⎜⎪
# ⎜⎪              ⎛               │  2⎞
# ⎜⎪  ___ ╭─╮2, 1 ⎜ 1/2    1/2, 0 │ p ⎟
# ⎜⎪╲╱ π ⋅│╶┐     ⎜               │ ──⎟
# ⎜⎪      ╰─╯3, 3 ⎜0, 1/2    0    │  2⎟
# ⎜⎪              ⎝               │ a ⎠
# ⎜⎪───────────────────────────────────   otherwise
# ⎝⎩                 a
#
#
# ...

# %%
1/sqrt(p**2-a**2)
# Out:
#       1
# ──────────────
#    ___________
#   ╱    2    2
# ╲╱  - a  + p

# %%
inverse_laplace_transform(_, p, t)
# Out:
# Heaviside(t)⋅besseli(0, -a⋅t)

# %% [markdown]
# 48

# %%
exp(-(a+b)/2*t)*besseli(0, (a-b)/2*t)
# Out:
#    ⎛  a   b⎞
#  t⋅⎜- ─ - ─⎟
#    ⎝  2   2⎠        ⎛     ⎛a   b⎞⎞
# ℯ           ⋅besseli⎜0, t⋅⎜─ - ─⎟⎟
#                     ⎝     ⎝2   2⎠⎠

# %%
laplace_transform(_, t, p)
# Out:
#                 ⎛   a⋅t   b⋅t                            ⎞
#                 ⎜ - ─── - ───                            ⎟
#                 ⎜    2     2         ⎛   a⋅t   b⋅t⎞      ⎟
# LaplaceTransform⎜ℯ           ⋅besseli⎜0, ─── - ───⎟, t, p⎟
#                 ⎝                    ⎝    2     2 ⎠      ⎠

# %%
1/sqrt((p+a)*(p+b))
# Out:
#          1
# ───────────────────
#   _________________
# ╲╱ (a + p)⋅(b + p)

# %%
inverse_laplace_transform(_, p, t)
# Out:
#                        ⎛            1                        ⎞
# InverseLaplaceTransform⎜─────────────────────────, p, t, None⎟
#                        ⎜   ______________________            ⎟
#                        ⎜  ╱                    2             ⎟
#                        ⎝╲╱  a⋅b + a⋅p + b⋅p + p              ⎠

# %% [markdown]
# 49

# %%
exp(-a*t)*besselj(0, sqrt(a**2-b**2)*t)
# Out:
#              ⎛        _________⎞
#  -a⋅t        ⎜       ╱  2    2 ⎟
# ℯ    ⋅besselj⎝0, t⋅╲╱  a  - b  ⎠

# %%
laplace_transform(_, t, p)
# Out:
#                 ⎛             ⎛        _________⎞      ⎞
#                 ⎜ -a⋅t        ⎜       ╱  2    2 ⎟      ⎟
# LaplaceTransform⎝ℯ    ⋅besselj⎝0, t⋅╲╱  a  - b  ⎠, t, p⎠

# %%
1/sqrt(p**2+2*a*p+b**2)
# Out:
#          1
# ────────────────────
#    _________________
#   ╱          2    2
# ╲╱  2⋅a⋅p + b  + p

# %%
inverse_laplace_transform(_, p, t)
# Out:
#                        ⎛         1                      ⎞
# InverseLaplaceTransform⎜────────────────────, p, t, None⎟
#                        ⎜   _________________            ⎟
#                        ⎜  ╱          2    2             ⎟
#                        ⎝╲╱  2⋅a⋅p + b  + p              ⎠

# %% [markdown]
# 50

# %%
sinh(2*sqrt(t))/sqrt(pi)
# Out:
#     ⎛    ___⎞
# sinh⎝2⋅╲╱ t ⎠
# ─────────────
#       ___
#     ╲╱ π

# %%
laplace_transform(_, t, p)
# Out:
# ⎛  1          ⎞
# ⎜  ─          ⎟
# ⎜  p          ⎟
# ⎜ ℯ           ⎟
# ⎜────, 0, True⎟
# ⎜ 3/2         ⎟
# ⎝p            ⎠

# %%
inverse_laplace_transform(_[0], p, t)
# Out:
#     ⎛    ___⎞
# sinh⎝2⋅╲╱ t ⎠⋅Heaviside(t)
# ──────────────────────────
#             ___
#           ╲╱ π

# %% [markdown]
# 51

# %%
sin(a*t)/t
# Out:
# sin(a⋅t)
# ────────
#    t

# %%
laplace_transform(_, t, p)
# Out:
# ⎛    ⎛a⎞     │                 ⎛          2      ⎞│    ⎞
# ⎜atan⎜─⎟, 0, │periodic_argument⎝polar_lift (a), ∞⎠│ = 0⎟
# ⎝    ⎝p⎠                                               ⎠

# %%
inverse_laplace_transform(_[0], p, t)
# Out:
#                        ⎛    ⎛a⎞            ⎞
# InverseLaplaceTransform⎜atan⎜─⎟, p, t, None⎟
#                        ⎝    ⎝p⎠            ⎠

# %% [markdown]
# 52

# %%
2/t*sin(a*t)*cos(b*t)
# Out:
# 2⋅sin(a⋅t)⋅cos(b⋅t)
# ───────────────────
#          t

# %%
#laplace_transform(_, t, p)
# Assertion error

# %% [markdown]
# 53

# %%
(exp(a*t)-1)/t*sin(b*t)
# Out:
# ⎛ a⋅t    ⎞
# ⎝ℯ    - 1⎠⋅sin(b⋅t)
# ───────────────────
#          t

# %%
laplace_transform(_, t, p)
# Out:
# ⎛⎧        ⎛    ⎛            ⎛    p⎞⎞    ⎞
# ⎜⎪        ⎜    ⎜a⋅polar_lift⎜1 - ─⎟⎟    ⎟                        │          2│
# ⎜⎪⎛    p⎞ ⎜    ⎜            ⎝    a⎠⎟    ⎟                        │ 2 ⎛    p⎞ │
# ⎜⎪⎜1 - ─⎟⋅⎜atan⎜───────────────────⎟ - π⎟                        │a ⋅⎜1 - ─⎟ │
# ⎜⎪⎝    a⎠ ⎝    ⎝         b         ⎠    ⎠       ⎛b⎞   π          │   ⎝    a⎠ │
# ⎜⎪─────────────────────────────────────── - atan⎜─⎟ + ─  for 1 < │───────────│
# ⎜⎪                     ⎛    p⎞                  ⎝p⎠   2          │      2    │
# ⎜⎪           polar_lift⎜1 - ─⎟                                   │     b     │
# ⎜⎪                     ⎝    a⎠
# ⎜⎨
# ⎜⎪               ⎛            ⎛    p⎞⎞
# ⎜⎪               ⎜a⋅polar_lift⎜1 - ─⎟⎟
# ⎜⎪   ⎛    p⎞     ⎜            ⎝    a⎠⎟
# ⎜⎪   ⎜1 - ─⎟⋅atan⎜───────────────────⎟
# ⎜⎪   ⎝    a⎠     ⎝         b         ⎠       ⎛b⎞   π
# ⎜⎪   ───────────────────────────────── - atan⎜─⎟ + ─           otherwise
# ⎜⎪                     ⎛    p⎞               ⎝p⎠   2
# ...

# %% [markdown]
# 54

# %%
-EulerGamma-log(t)
# Out:
# -log(t) - EulerGamma

# %%
laplace_transform(_, t, p)
# Out:
# ⎛log(p)         ⎞
# ⎜──────, 0, True⎟
# ⎝  p            ⎠

# %%
inverse_laplace_transform(_[0], p, t)
# Out:
# (-log(t) - EulerGamma)⋅Heaviside(t)

# %% [markdown]
# 55

# %%
k = Symbol("k")

# %%
phi = Sum(1/k, (k, 1, n))- EulerGamma
phi
# Out:
#                 n
#                ____
#                ╲
#                 ╲   1
#                  ╲  ─
# -EulerGamma +    ╱  k
#                 ╱
#                ╱
#                ‾‾‾‾
#               k = 1

# %%
t**n/factorial(n)*(phi-log(t))
# Out:
#    ⎛                         n    ⎞
#    ⎜                        ____  ⎟
#    ⎜                        ╲     ⎟
#    ⎜                         ╲   1⎟
#  n ⎜                          ╲  ─⎟
# t ⋅⎜-log(t) - EulerGamma +    ╱  k⎟
#    ⎜                         ╱    ⎟
#    ⎜                        ╱     ⎟
#    ⎜                        ‾‾‾‾  ⎟
#    ⎝                       k = 1  ⎠
# ───────────────────────────────────
#                  n!

# %%
laplace_transform(_, t, p)
# Out:
# ⎛  -n - 1
# ⎜-p      ⋅(-n⋅log(p) - n⋅harmonic(n) + n⋅polygamma(0, n) + EulerGamma⋅n + 1)
# ⎜───────────────────────────────────────────────────────────────────────────,
# ⎝                                     n
#
#
#                                                 ⎛
# 0, (-n < 1 ∨ 1 < -n + 1) ∧ 0 < n + 1 ∧ -n < 1 ∧ ⎜-n < 1 ∨ │periodic_argument(p
#                                                 ⎝
#
#                                                         ⎞
#         π⎞   ⎛                                        π⎞⎟
# , ∞)│ = ─⎟ ∧ ⎜0 < n + 1 ∨ │periodic_argument(p, ∞)│ = ─⎟⎟
#         2⎠   ⎝                                        2⎠⎠

# %%
simplify(_[0])
# Out:
#  -n - 1
# p      ⋅(n⋅log(p) + n⋅harmonic(n) - n⋅polygamma(0, n) - EulerGamma⋅n - 1)
# ─────────────────────────────────────────────────────────────────────────
#                                     n

# %%
log(p)/p**(n+1)
# Out:
#  -n - 1
# p      ⋅log(p)

# %%
inverse_laplace_transform(_, p, t)
# Out:
#   n
# -t ⋅(log(t) - polygamma(0, n + 1))⋅Heaviside(t)
# ───────────────────────────────────────────────
#                     Γ(n + 1)

# %% [markdown]
# 56

# %%
(log(t)+EulerGamma)**2-pi**2/6
# Out:
#                           2
#                      2   π
# (log(t) + EulerGamma)  - ──
#                          6

# %%
laplace_transform(_, t, p)
# Out:
# ⎛   2            ⎞
# ⎜log (p)         ⎟
# ⎜───────, 0, True⎟
# ⎝   p            ⎠

# %%
inverse_laplace_transform(_[0], p, t)
# Out:
# ⎛     2                              2               2⎞
# ⎝6⋅log (t) + 12⋅EulerGamma⋅log(t) - π  + 6⋅EulerGamma ⎠⋅Heaviside(t)
# ────────────────────────────────────────────────────────────────────
#                                  6

# %%
logcombine(_)
# Out:
#                                                            2
#    2                                                      π ⋅Heaviside(t)
# log (t)⋅Heaviside(t) + 2⋅EulerGamma⋅log(t)⋅Heaviside(t) - ─────────────── + Eu
#                                                                  6
#
#
#         2
# lerGamma ⋅Heaviside(t)

# %% [markdown]
# 57

# %%
1/t*(exp(b*t)-exp(a*t))
# Out:
#    a⋅t    b⋅t
# - ℯ    + ℯ
# ─────────────
#       t

# %%
laplace_transform(_, t, p)
# Out:
#                   ⎛ a⋅t      ⎞                   ⎛ b⋅t      ⎞
#                   ⎜ℯ         ⎟                   ⎜ℯ         ⎟
# - LaplaceTransform⎜────, t, p⎟ + LaplaceTransform⎜────, t, p⎟
#                   ⎝ t        ⎠                   ⎝ t        ⎠

# %%
log((p-a)/(p-b))
# Out:
#    ⎛-a + p⎞
# log⎜──────⎟
#    ⎝-b + p⎠

# %%
inverse_laplace_transform(_, p, t)
# Out:
#                        ⎛   ⎛    a        p   ⎞            ⎞
# InverseLaplaceTransform⎜log⎜- ────── + ──────⎟, p, t, None⎟
#                        ⎝   ⎝  -b + p   -b + p⎠            ⎠

# %% [markdown]
# 58

# %%
2/t*sinh(a*t)
# Out:
# 2⋅sinh(a⋅t)
# ───────────
#      t

# %%
laplace_transform(_, t, p)
# Out:
#                   ⎛sinh(a⋅t)      ⎞
# 2⋅LaplaceTransform⎜─────────, t, p⎟
#                   ⎝    t          ⎠

# %% [markdown]
# 59

# %%
2*(cos(b*t)-cos(a*t))/t
# Out:
# -2⋅cos(a⋅t) + 2⋅cos(b⋅t)
# ────────────────────────
#            t

# %%
laplace_transform(_, t, p)
# Out:
#                     ⎛cos(a⋅t)      ⎞                     ⎛cos(b⋅t)      ⎞
# - 2⋅LaplaceTransform⎜────────, t, p⎟ + 2⋅LaplaceTransform⎜────────, t, p⎟
#                     ⎝   t          ⎠                     ⎝   t          ⎠

# %% [markdown]
# 60

# %%
2*(cosh(b*t)-cosh(a*t))/t
# Out:
# -2⋅cosh(a⋅t) + 2⋅cosh(b⋅t)
# ──────────────────────────
#             t

# %%
laplace_transform(_, t, p)
# Out:
#                     ⎛cosh(a⋅t)      ⎞                     ⎛cosh(b⋅t)      ⎞
# - 2⋅LaplaceTransform⎜─────────, t, p⎟ + 2⋅LaplaceTransform⎜─────────, t, p⎟
#                     ⎝    t          ⎠                     ⎝    t          ⎠

# %%
log((p**2-a**2)/(p**2-b**2))
# Out:
#    ⎛   2    2⎞
#    ⎜- a  + p ⎟
# log⎜─────────⎟
#    ⎜   2    2⎟
#    ⎝- b  + p ⎠

# %%
inverse_laplace_transform(_, p, t)
# Out:
#                        ⎛   ⎛       2           2   ⎞            ⎞
#                        ⎜   ⎜      a           p    ⎟            ⎟
# InverseLaplaceTransform⎜log⎜- ───────── + ─────────⎟, p, t, None⎟
#                        ⎜   ⎜     2    2      2    2⎟            ⎟
#                        ⎝   ⎝  - b  + p    - b  + p ⎠            ⎠

# %% [markdown]
# 61

# %%
a/(2*sqrt(pi))*exp(-a**2/(4*t))/(t*sqrt(t))
# Out:
#         2
#       -a
#       ───
#       4⋅t
#    a⋅ℯ
# ────────────
#     ___  3/2
# 2⋅╲╱ π ⋅t

# %%
laplace_transform(_, t, p)
# Out:
# ⎛      ⎛    ___⎞       ⎛    ___⎞     │                 ⎛          2      ⎞│
# ⎜- sinh⎝a⋅╲╱ p ⎠ + cosh⎝a⋅╲╱ p ⎠, 0, │periodic_argument⎝polar_lift (a), ∞⎠│ <
# ⎝
#
# π⎞
# ─⎟
# 2⎠

# %%
inverse_laplace_transform(_[0], p, t)
# Out:
#                          ⎛    ⎛    ___⎞            ⎞
# - InverseLaplaceTransform⎝sinh⎝a⋅╲╱ p ⎠, p, t, None⎠ + InverseLaplaceTransform
#
# ⎛    ⎛    ___⎞            ⎞
# ⎝cosh⎝a⋅╲╱ p ⎠, p, t, None⎠

# %%
exp(-a*sqrt(p))
# Out:
#       ___
#  -a⋅╲╱ p
# ℯ

# %%
inverse_laplace_transform(_, p, t)
# Out:
#                                                  2        2
#                                                re (a)   im (a)
#                                              - ────── + ──────
#   ⎛       ⎛re(a)⋅im(a)⎞      ⎛re(a)⋅im(a)⎞⎞     4⋅t      4⋅t
# a⋅⎜- ⅈ⋅sin⎜───────────⎟ + cos⎜───────────⎟⎟⋅ℯ                 ⋅Heaviside(t)
#   ⎝       ⎝    2⋅t    ⎠      ⎝    2⋅t    ⎠⎠
# ───────────────────────────────────────────────────────────────────────────
#                                     ___  3/2
#                                 2⋅╲╱ π ⋅t

# %% [markdown]
# 62

# %%
exp(-a**2/(4*t))/sqrt(pi*t)
# Out:
#        2
#      -a
#      ───
#      4⋅t
#     ℯ
# ───────────
#   ___   ___
# ╲╱ π ⋅╲╱ t

# %%
laplace_transform(_, t, p)
# Out:
# ⎛      ⎛    ___⎞       ⎛    ___⎞
# ⎜- sinh⎝a⋅╲╱ p ⎠ + cosh⎝a⋅╲╱ p ⎠     │                 ⎛          2      ⎞│
# ⎜───────────────────────────────, 0, │periodic_argument⎝polar_lift (a), ∞⎠│ <
# ⎜               ___
# ⎝             ╲╱ p
#
#  ⎞
# π⎟
# ─⎟
# 2⎟
#  ⎠

# %%
inverse_laplace_transform(_[0], p, t)
# Out:
#                          ⎛    ⎛    ___⎞            ⎞
#                          ⎜sinh⎝a⋅╲╱ p ⎠            ⎟
# - InverseLaplaceTransform⎜─────────────, p, t, None⎟ + InverseLaplaceTransform
#                          ⎜      ___                ⎟
#                          ⎝    ╲╱ p                 ⎠
#
# ⎛    ⎛    ___⎞            ⎞
# ⎜cosh⎝a⋅╲╱ p ⎠            ⎟
# ⎜─────────────, p, t, None⎟
# ⎜      ___                ⎟
# ⎝    ╲╱ p                 ⎠

# %%
1/sqrt(p)*exp(-a*sqrt(p))
# Out:
#       ___
#  -a⋅╲╱ p
# ℯ
# ─────────
#     ___
#   ╲╱ p

# %%
inverse_laplace_transform(_, p, t)
# Out:
#                                                2        2
#                                              re (a)   im (a)
#                                            - ────── + ──────
# ⎛       ⎛re(a)⋅im(a)⎞      ⎛re(a)⋅im(a)⎞⎞     4⋅t      4⋅t
# ⎜- ⅈ⋅sin⎜───────────⎟ + cos⎜───────────⎟⎟⋅ℯ                 ⋅Heaviside(t)
# ⎝       ⎝    2⋅t    ⎠      ⎝    2⋅t    ⎠⎠
# ─────────────────────────────────────────────────────────────────────────
#                                  ___   ___
#                                ╲╱ π ⋅╲╱ t

# %% [markdown]
# 63

# %%
t**n*besselj(n, a*t)
# Out:
#  n
# t ⋅besselj(n, a⋅t)

# %%
laplace_transform(_, t, p)
# Out:
# ⎛                   -n - 1/2
# ⎜           ⎛     2⎞
# ⎜ n  -n - 1 ⎜    p ⎟
# ⎜2 ⋅a      ⋅⎜1 + ──⎟        ⋅Γ(n + 1/2)
# ⎜           ⎜     2⎟
# ⎜           ⎝    a ⎠                                    │                 ⎛
# ⎜──────────────────────────────────────, 0, 0 < n + 1 ∧ │periodic_argument⎝pol
# ⎜                  ___
# ⎝                ╲╱ π
#
#                                   ⎞
#                                   ⎟
#                                   ⎟
#                                   ⎟
#                                   ⎟
#        2      ⎞│                  ⎟
# ar_lift (a), ∞⎠│ = 0 ∧ 0 < n + 1/2⎟
#                                   ⎟
#                                   ⎠

# %%
simplify(_[0])
# Out:
#                    -n - 1/2
#            ⎛     2⎞
#  n  -n - 1 ⎜    p ⎟
# 2 ⋅a      ⋅⎜1 + ──⎟        ⋅Γ(n + 1/2)
#            ⎜     2⎟
#            ⎝    a ⎠
# ──────────────────────────────────────
#                   ___
#                 ╲╱ π

# %%
inverse_laplace_transform(_, p, t)
# Out:
#                                   ⎛        -n - 1/2            ⎞
#                                   ⎜⎛     2⎞                    ⎟
#  n  -n - 1                        ⎜⎜    p ⎟                    ⎟
# 2 ⋅a      ⋅InverseLaplaceTransform⎜⎜1 + ──⎟        , p, t, None⎟⋅Γ(n + 1/2)
#                                   ⎜⎜     2⎟                    ⎟
#                                   ⎝⎝    a ⎠                    ⎠
# ───────────────────────────────────────────────────────────────────────────
#                                      ___
#                                    ╲╱ π

# %% [markdown]
# 64

# %%
a**n*besseli(n, a*t)
# Out:
#  n
# a ⋅besseli(n, a⋅t)

# %%
laplace_transform(_, t, p)
# Out:
# ⎛⎧             ⎛
# ⎜⎪             ⎜
# ⎜⎪             ⎜
# ⎜⎪             ⎜
# ⎜⎪             ⎜
# ⎜⎪             ⎜
# ⎜⎪             ⎜
# ⎜⎪             ⎜
# ⎜⎪             ⎜
# ⎜⎪             ⎜
# ⎜⎪             ⎜
# ⎜⎪             ⎜
# ⎜⎪             ⎜
# ⎜⎪             ⎜
# ⎜⎪             ⎜      ⎛                            ⎛            ⎛p⎞⎞⎞
# ⎜⎪             ⎜      ⎜                       p⋅sin⎜(n - 1)⋅asin⎜─⎟⎟⎟
# ⎜⎪             ⎜  ___ ⎜   ⎛            ⎛p⎞⎞        ⎝            ⎝a⎠⎠⎟       __
# ⎜⎪             ⎜╲╱ π ⋅⎜cos⎜(n - 1)⋅asin⎜─⎟⎟ - ──────────────────────⎟   2⋅╲╱ π
# ⎜⎪             ⎜      ⎜   ⎝            ⎝a⎠⎠              ________   ⎟
# ⎜⎪             ⎜      ⎜                                 ╱      2    ⎟
# ⎜⎪             ⎜      ⎜                                ╱      p     ⎟
# ⎜⎪             ⎜      ⎜                          a⋅   ╱   1 - ──    ⎟
# ⎜⎪             ⎜      ⎜                              ╱         2    ⎟
# ...

# %% [markdown]
# what a mess ...!

# %% [markdown]
# 65

# %%
1/p*exp(-b*p)
# Out:
#  -b⋅p
# ℯ
# ─────
#   p

# %%
inverse_laplace_transform(_, p, t)
# Out:
# Heaviside(-b + t)

# %%
laplace_transform(_, t, p)
# Out:
# ⎛ -b⋅p                                              ⎞
# ⎜ℯ         ⎛    1   1    ⎞           ⎛    1        ⎞⎟
# ⎜─────, 0, ⎜0 < ─ ∨ ─ ≠ 0⎟ ∧ 0 < b ∧ ⎜0 < ─ ∨ 0 < b⎟⎟
# ⎝  p       ⎝    b   b    ⎠           ⎝    b        ⎠⎠

# %% [markdown]
# 66

# %%
exp(-b*sqrt(p**2+a**2))/sqrt(p**2+a**2)
# Out:
#        _________
#       ╱  2    2
#  -b⋅╲╱  a  + p
# ℯ
# ────────────────
#      _________
#     ╱  2    2
#   ╲╱  a  + p

# %%
inverse_laplace_transform(_, p, t)
# Out:
#                        ⎛       _________            ⎞
#                        ⎜      ╱  2    2             ⎟
#                        ⎜ -b⋅╲╱  a  + p              ⎟
#                        ⎜ℯ                           ⎟
# InverseLaplaceTransform⎜────────────────, p, t, None⎟
#                        ⎜     _________              ⎟
#                        ⎜    ╱  2    2               ⎟
#                        ⎝  ╲╱  a  + p                ⎠

# %% [markdown]
# 67

# %%
exp(-b*sqrt(p**2-a**2))/sqrt(p**2-a**2)
# Out:
#        ___________
#       ╱    2    2
#  -b⋅╲╱  - a  + p
# ℯ
# ──────────────────
#      ___________
#     ╱    2    2
#   ╲╱  - a  + p

# %%
inverse_laplace_transform(_, p, t)
# Out:
#                        ⎛       ___________            ⎞
#                        ⎜      ╱    2    2             ⎟
#                        ⎜ -b⋅╲╱  - a  + p              ⎟
#                        ⎜ℯ                             ⎟
# InverseLaplaceTransform⎜──────────────────, p, t, None⎟
#                        ⎜     ___________              ⎟
#                        ⎜    ╱    2    2               ⎟
#                        ⎝  ╲╱  - a  + p                ⎠

# %% [markdown]
# 68

# %%
exp(-b*sqrt((p+a)*(p+b)))/sqrt((p+a)*(p+b))
# Out:
#       _________________
#  -b⋅╲╱ (a + p)⋅(b + p)
# ℯ
# ───────────────────────
#     _________________
#   ╲╱ (a + p)⋅(b + p)

# %%
inverse_laplace_transform(_, p, t)
# Out:
#                        ⎛       ______________________            ⎞
#                        ⎜      ╱                    2             ⎟
#                        ⎜ -b⋅╲╱  a⋅b + a⋅p + b⋅p + p              ⎟
#                        ⎜ℯ                                        ⎟
# InverseLaplaceTransform⎜─────────────────────────────, p, t, None⎟
#                        ⎜     ______________________              ⎟
#                        ⎜    ╱                    2               ⎟
#                        ⎝  ╲╱  a⋅b + a⋅p + b⋅p + p                ⎠

# %% [markdown]
# 69

# %%
exp(-b*sqrt(p**2+a**2))/(p**2+a**2)*(b+1/sqrt(p**2+a**2))
# Out:
#                           _________
#                          ╱  2    2
# ⎛         1      ⎞  -b⋅╲╱  a  + p
# ⎜b + ────────────⎟⋅ℯ
# ⎜       _________⎟
# ⎜      ╱  2    2 ⎟
# ⎝    ╲╱  a  + p  ⎠
# ───────────────────────────────────
#                2    2
#               a  + p

# %%
inverse_laplace_transform(_, p, t)
# Out:
#                          ⎛                   1                               ⎞
# b⋅InverseLaplaceTransform⎜───────────────────────────────────────, p, t, None⎟
#                          ⎜         _________            _________            ⎟
#                          ⎜        ╱  2    2            ╱  2    2             ⎟
#                          ⎜ 2  b⋅╲╱  a  + p      2  b⋅╲╱  a  + p              ⎟
#                          ⎝a ⋅ℯ               + p ⋅ℯ                          ⎠
#
#                           ⎛                                1
#  + InverseLaplaceTransform⎜───────────────────────────────────────────────────
#                           ⎜                      _________
#                           ⎜      _________      ╱  2    2          _________
#                           ⎜ 2   ╱  2    2   b⋅╲╱  a  + p      2   ╱  2    2
#                           ⎝a ⋅╲╱  a  + p  ⋅ℯ               + p ⋅╲╱  a  + p  ⋅ℯ
#
#                           ⎞
# ──────────────, p, t, None⎟
# ...

# %% [markdown]
# 70

# %%
exp(-b*sqrt(p**2-a**2))/(p**2-a**2)*(b+1/sqrt(p**2-a**2))
# Out:
#                             ___________
#                            ╱    2    2
# ⎛          1       ⎞  -b⋅╲╱  - a  + p
# ⎜b + ──────────────⎟⋅ℯ
# ⎜       ___________⎟
# ⎜      ╱    2    2 ⎟
# ⎝    ╲╱  - a  + p  ⎠
# ───────────────────────────────────────
#                   2    2
#                - a  + p

# %%
inverse_laplace_transform(_, p, t)
# Out:
#                          ⎛                      1
# b⋅InverseLaplaceTransform⎜─────────────────────────────────────────────, p, t,
#                          ⎜           ___________            ___________
#                          ⎜          ╱    2    2            ╱    2    2
#                          ⎜   2  b⋅╲╱  - a  + p      2  b⋅╲╱  - a  + p
#                          ⎝- a ⋅ℯ                 + p ⋅ℯ
#
#      ⎞                          ⎛                                     1
#  None⎟ + InverseLaplaceTransform⎜─────────────────────────────────────────────
#      ⎟                          ⎜                          ___________
#      ⎟                          ⎜        ___________      ╱    2    2
#      ⎟                          ⎜   2   ╱    2    2   b⋅╲╱  - a  + p      2
#      ⎠                          ⎝- a ⋅╲╱  - a  + p  ⋅ℯ                 + p ⋅╲╱
#
#                                           ⎞
# ──────────────────────────────, p, t, None⎟
# ...

# %% [markdown]
# 71

# %%
exp(-b*p)-exp(-b*sqrt(p**2+a**2))
# Out:
#          _________
#         ╱  2    2
#    -b⋅╲╱  a  + p      -b⋅p
# - ℯ                + ℯ

# %%
inverse_laplace_transform(_, p, t)
# Out:
#                         ⎛       _________            ⎞
#                         ⎜      ╱  2    2             ⎟
#                         ⎜ -b⋅╲╱  a  + p              ⎟
# -InverseLaplaceTransform⎝ℯ               , p, t, None⎠

# %% [markdown]
# 72

# %%
exp(-b*sqrt(p**2-a**2))-exp(-b*p)
# Out:
#        ___________
#       ╱    2    2
#  -b⋅╲╱  - a  + p      -b⋅p
# ℯ                  - ℯ

# %%
inverse_laplace_transform(_, p, t)
# Out:
#                                                                       ⎛
#                                                                       ⎜      ╱
#                          ⎛ -b⋅p            ⎞                          ⎜ -b⋅╲╱
# - InverseLaplaceTransform⎝ℯ    , p, t, None⎠ + InverseLaplaceTransform⎝ℯ
#
# ___________            ⎞
#     2    2             ⎟
#  - a  + p              ⎟
#            , p, t, None⎠

# %% [markdown]
# 73

# %%
(1-exp(-a*p))/p
# Out:
#      -a⋅p
# 1 - ℯ
# ─────────
#     p

# %%
inverse_laplace_transform(_, p, t)
# Out:
# Heaviside(t) - Heaviside(-a + t)

# %% [markdown]
# 74

# %%
(exp(-a*p)-exp(-b*p))/p
# Out:
#    -b⋅p    -a⋅p
# - ℯ     + ℯ
# ───────────────
#        p

# %%
inverse_laplace_transform(_, p, t)
# Out:
# Heaviside(-a + t) - Heaviside(-b + t)

# %% [markdown]
# Other

# %%
besselj(n, a*t)
# Out:
# besselj(n, a⋅t)

# %%
laplace_transform(_, t, p)
# Out:
# ⎛                               -n - 1
# ⎜           ⎛      ________    ⎞       ⎛              ________     ⎞
# ⎜           ⎜     ╱  2         ⎟       ⎜             ╱  2          ⎟
# ⎜ n  -n - 1 ⎜    ╱  a          ⎟       ⎜ 2    2     ╱  a          2⎟
# ⎜a ⋅p      ⋅⎜   ╱   ── + 1  + 1⎟      ⋅⎜a  + p ⋅   ╱   ── + 1  + p ⎟
# ⎜           ⎜  ╱     2         ⎟       ⎜          ╱     2          ⎟
# ⎜           ⎝╲╱     p          ⎠       ⎝        ╲╱     p           ⎠         n
# ⎜───────────────────────────────────────────────────────────────────, 0, 0 < ─
# ⎜                               2    2                                       2
# ⎝                              a  + p
#
#                                                              ⎞
#                                                              ⎟
#                                                              ⎟
#                                                              ⎟
# ...

# %%
besseli(n, a*t)
# Out:
# besseli(n, a⋅t)

# %%
laplace_transform(_, t, p)
# Out:
# ⎛⎧      ⎛                                                                  ⎛
# ⎜⎪      ⎜                                                                  ⎜
# ⎜⎪      ⎜                                                                  ⎜
# ⎜⎪      ⎜                                                                  ⎜
# ⎜⎪      ⎜                                                                  ⎜
# ⎜⎪      ⎜                                                                  ⎜
# ⎜⎪      ⎜                                                                  ⎜
# ⎜⎪      ⎜                                                                  ⎜
# ⎜⎪      ⎜                                                                  ⎜
# ⎜⎪      ⎜                                                                  ⎜⎛
# ⎜⎪      ⎜                                                                  ⎜⎜
# ⎜⎪      ⎜                                                                  ⎜⎜
# ...

# %%
erf(a*t)
# Out:
# erf(a⋅t)

# %%
laplace_transform(_, t, p)
# Out:
# ⎛                    2                                                ⎞
# ⎜                   p                                                 ⎟
# ⎜                  ────                                               ⎟
# ⎜                     2                                               ⎟
# ⎜⎛     ⎛ p ⎞    ⎞  4⋅a                                                ⎟
# ⎜⎜- erf⎜───⎟ + 1⎟⋅ℯ                                                   ⎟
# ⎜⎝     ⎝2⋅a⎠    ⎠           │                 ⎛          2      ⎞│   π⎟
# ⎜──────────────────────, 0, │periodic_argument⎝polar_lift (a), ∞⎠│ < ─⎟
# ⎝          p                                                         2⎠

# %%
Chi(a*t)
# Out:
# Chi(a⋅t)

# %%
laplace_transform(_, t, p)
# Out:
# ⎛⎧                     ⎛ 2    2⎞
# ⎜⎪                     ⎜a  - p ⎟  ⅈ⋅π
# ⎜⎪                  log⎜───────⎟⋅ℯ
# ⎜⎪                     ⎜    2  ⎟                              │ 2│
# ⎜⎪                     ⎝   a   ⎠                              │p │
# ⎜⎪                  ─────────────────                     for │──│ < 1, Max(0,
# ⎜⎪                         2⋅p                                │ 2│
# ⎜⎪                                                            │a │
# ⎜⎪
# ⎜⎪          ⎛     ⎛ 2⎞      ⎛   2    2⎞⎞
# ⎜⎪          ⎜     ⎜a ⎟      ⎜- a  + p ⎟⎟  ⅈ⋅π
# ⎜⎪          ⎜- log⎜──⎟ + log⎜─────────⎟⎟⋅ℯ
# ⎜⎪          ⎜     ⎜ 2⎟      ⎜     2   ⎟⎟                      │ 2│
# ⎜⎪          ⎝     ⎝p ⎠      ⎝    p    ⎠⎠                      │a │
# ⎜⎪          ─────────────────────────────────             for │──│ < 1
# ⎜⎪                         2⋅p                                │ 2│
# ⎜⎪                                                            │p │
# ⎜⎪
# ⎜⎪  ⎧              ⎛     2⎞
# ...

# %%
_[0]
# Out:
# ⎧                     ⎛ 2    2⎞
# ⎪                     ⎜a  - p ⎟  ⅈ⋅π
# ⎪                  log⎜───────⎟⋅ℯ
# ⎪                     ⎜    2  ⎟                              │ 2│
# ⎪                     ⎝   a   ⎠                              │p │
# ⎪                  ─────────────────                     for │──│ < 1
# ⎪                         2⋅p                                │ 2│
# ⎪                                                            │a │
# ⎪
# ⎪          ⎛     ⎛ 2⎞      ⎛   2    2⎞⎞
# ⎪          ⎜     ⎜a ⎟      ⎜- a  + p ⎟⎟  ⅈ⋅π
# ⎪          ⎜- log⎜──⎟ + log⎜─────────⎟⎟⋅ℯ
# ⎪          ⎜     ⎜ 2⎟      ⎜     2   ⎟⎟                      │ 2│
# ⎪          ⎝     ⎝p ⎠      ⎝    p    ⎠⎠                      │a │
# ⎪          ─────────────────────────────────             for │──│ < 1
# ⎪                         2⋅p                                │ 2│
# ⎪                                                            │p │
# ⎪
# ⎪  ⎧              ⎛     2⎞
# ⎪  ⎪              ⎜    p ⎟
# ...
