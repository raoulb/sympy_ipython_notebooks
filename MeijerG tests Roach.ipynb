# %%
# %load_ext sympyprt

# %%
from sympy import *

# %%
z = Symbol("z")
n = Symbol("n", integer=True)
mu = Symbol("mu", integer=True)

# %% [markdown]
# Examples from the paper "Meijer G Function Representations" by Kelly Roach

# %% [markdown]
# Nr 1

# %%
integrate(z**n*besselj(mu,z), z, meijerg=True)
# Out:
#                                                 ⎛   μ   n   1     │    ⎞
#                                                 ⎜   ─ + ─ + ─     │   2⎟
#  n + 1  -μ - n - 2  μ + n + 1  ⎛μ   n   1⎞  ┌─  ⎜   2   2   2     │ -z ⎟
# 2     ⋅2          ⋅z         ⋅Γ⎜─ + ─ + ─⎟⋅ ├─  ⎜                 │ ───⎟
#                                ⎝2   2   2⎠ 1╵ 2 ⎜       μ   n   3 │  4 ⎟
#                                                 ⎜μ + 1, ─ + ─ + ─ │    ⎟
#                                                 ⎝       2   2   2 │    ⎠
# ────────────────────────────────────────────────────────────────────────
#                                    ⎛μ   n   3⎞
#                          Γ(μ + 1)⋅Γ⎜─ + ─ + ─⎟
#                                    ⎝2   2   2⎠

# %%
hyperexpand(_)
# Out:
#                                                 ⎛   μ   n   1     │    ⎞
#                                                 ⎜   ─ + ─ + ─     │   2⎟
#  n + 1  -μ - n - 2  μ + n + 1  ⎛μ   n   1⎞  ┌─  ⎜   2   2   2     │ -z ⎟
# 2     ⋅2          ⋅z         ⋅Γ⎜─ + ─ + ─⎟⋅ ├─  ⎜                 │ ───⎟
#                                ⎝2   2   2⎠ 1╵ 2 ⎜       μ   n   3 │  4 ⎟
#                                                 ⎜μ + 1, ─ + ─ + ─ │    ⎟
#                                                 ⎝       2   2   2 │    ⎠
# ────────────────────────────────────────────────────────────────────────
#                                    ⎛μ   n   3⎞
#                          Γ(μ + 1)⋅Γ⎜─ + ─ + ─⎟
#                                    ⎝2   2   2⎠

# %% [markdown]
# Nr 2

# %%
x = Symbol("x")
b = Symbol("b")
rho = Symbol("rho")

# %%
integrate(sin(b*x)/(x**2+z**2)**rho, (x,0,oo), meijerg=True)
# Out:
# ⎧                   ⎛
# ⎪                   ⎜
# ⎪                   ⎜
# ⎪  ___  2  -2⋅ρ - 1 ⎜ -ρ + 1/2  ρ - 1/2  ρ - 1/2
# ⎪╲╱ π ⋅z ⋅z        ⋅⎜2        ⋅b       ⋅z       ⋅besseli(ρ - 1/2, b⋅z)⋅Γ(ρ)⋅Γ(
# ⎪                   ⎜
# ⎪                   ⎝
# ⎪─────────────────────────────────────────────────────────────────────────────
# ⎪                                                             2⋅Γ(ρ)
# ⎨
# ⎪
# ⎪                                                   ∞
# ⎪                                                   ⌠
# ⎪                                                   ⎮          -ρ
# ⎪                                                   ⎮ ⎛ 2    2⎞
# ⎪                                                   ⎮ ⎝x  + z ⎠  ⋅sin(b⋅x) dx
# ⎪                                                   ⌡
# ⎪                                                   0
# ⎩
#
#                             ⎛            │  2  2⎞⎞
#                         ┌─  ⎜     1      │ b ⋅z ⎟⎟
# ...

# %%
hyperexpand(_)
# Out:
# ⎧                   ⎛
# ⎪                   ⎜
# ⎪                   ⎜
# ⎪  ___  2  -2⋅ρ - 1 ⎜ -ρ + 1/2  ρ - 1/2  ρ - 1/2
# ⎪╲╱ π ⋅z ⋅z        ⋅⎜2        ⋅b       ⋅z       ⋅besseli(ρ - 1/2, b⋅z)⋅Γ(ρ)⋅Γ(
# ⎪                   ⎜
# ⎪                   ⎝
# ⎪─────────────────────────────────────────────────────────────────────────────
# ⎪                                                             2⋅Γ(ρ)
# ⎨
# ⎪
# ⎪                                                   ∞
# ⎪                                                   ⌠
# ⎪                                                   ⎮          -ρ
# ⎪                                                   ⎮ ⎛ 2    2⎞
# ⎪                                                   ⎮ ⎝x  + z ⎠  ⋅sin(b⋅x) dx
# ⎪                                                   ⌡
# ⎪                                                   0
# ⎩
#
#                             ⎛            │  2  2⎞⎞
#                         ┌─  ⎜     1      │ b ⋅z ⎟⎟
# ...

# %% [markdown]
# Nr 3

# %%
a = Symbol("a", real=True)

# %%
integrate(cos(a*x**2+2*b*x), (x,0,oo), meijerg=True)
# Out:
# ∞
# ⌠
# ⎮    ⎛   2        ⎞
# ⎮ cos⎝a⋅x  + 2⋅b⋅x⎠ dx
# ⌡
# 0

# %% [markdown]
# Nr 4

# %%
integrate(cos(b*x)*atan(a/x**2), (x,0,oo), meijerg=True)
# Out:
# ∞
# ⌠
# ⎮              ⎛a ⎞
# ⎮ cos(b⋅x)⋅atan⎜──⎟ dx
# ⎮              ⎜ 2⎟
# ⎮              ⎝x ⎠
# ⌡
# 0

# %% [markdown]
# Nr 5

# %%
c = Symbol("c")

# %%
integrate(cos(b*sqrt(x)) * besselj(0, c*x) / sqrt(x), (x,0,oo), meijerg=True)
# Out:
# ∞
# ⌠
# ⎮    ⎛    ___⎞
# ⎮ cos⎝b⋅╲╱ x ⎠⋅besselj(0, c⋅x)
# ⎮ ──────────────────────────── dx
# ⎮              ___
# ⎮            ╲╱ x
# ⌡
# 0

# %% [markdown]
# Nr 6

# %%
integrate(besselj(1, b*x) * besselj(1, c*x) / x**2, (x,0,oo), meijerg=True)
# Out:
# ⎧          ⎛          │           2   ⎞
# ⎪  ╭─╮1, 1 ⎜ 1    2   │ polar_lift (c)⎟
# ⎪b⋅│╶┐     ⎜          │ ──────────────⎟
# ⎪  ╰─╯2, 2 ⎜1/2  -1/2 │           2   ⎟
# ⎪          ⎝          │ polar_lift (b)⎠      │                 ⎛          2
# ⎪──────────────────────────────────────  for │periodic_argument⎝polar_lift (b)
# ⎪                  4
# ⎪
# ⎨ ∞
# ⎪ ⌠
# ⎪ ⎮ besselj(1, b⋅x)⋅besselj(1, c⋅x)
# ⎪ ⎮ ─────────────────────────────── dx
# ⎪ ⎮                 2
# ⎪ ⎮                x
# ⎪ ⌡
# ⎪ 0
# ⎩
#
#
#
#
#
#    ⎞│       │                 ⎛          2      ⎞│
# , ∞⎠│ = 0 ∧ │periodic_argument⎝polar_lift (c), ∞⎠│ = 0
#
#
#
#
#
#     otherwise

# %%
hyperexpand(_)
# Out:
# ⎧          ⎛          │           2   ⎞
# ⎪  ╭─╮1, 1 ⎜ 1    2   │ polar_lift (c)⎟
# ⎪b⋅│╶┐     ⎜          │ ──────────────⎟
# ⎪  ╰─╯2, 2 ⎜1/2  -1/2 │           2   ⎟
# ⎪          ⎝          │ polar_lift (b)⎠      │                 ⎛          2
# ⎪──────────────────────────────────────  for │periodic_argument⎝polar_lift (b)
# ⎪                  4
# ⎪
# ⎨ ∞
# ⎪ ⌠
# ⎪ ⎮ besselj(1, b⋅x)⋅besselj(1, c⋅x)
# ⎪ ⎮ ─────────────────────────────── dx
# ⎪ ⎮                 2
# ⎪ ⎮                x
# ⎪ ⌡
# ⎪ 0
# ⎩
#
#
#
#
#
#    ⎞│       │                 ⎛          2      ⎞│
# , ∞⎠│ = 0 ∧ │periodic_argument⎝polar_lift (c), ∞⎠│ = 0
#
#
#
#
#
#     otherwise

# %% [markdown]
# Nr 7

# %%
nu = Symbol("nu")

# %%
integrate(x*besselj(nu/4,b*x**2)**2 * besselj(nu, c*x) , (x,0,oo), meijerg=True)
# Out:
# ∞
# ⌠
# ⎮          2
# ⎮           ⎛ν     2⎞
# ⎮ x⋅besselj ⎜─, b⋅x ⎟⋅besselj(ν, c⋅x) dx
# ⎮           ⎝4      ⎠
# ⌡
# 0

# %% [markdown]
# Nr 8

# %%
# What is H_0^(1)

# %% [markdown]
# Nr 9

# %%
integrate(exp(-rho*x) * besseli(1,c*x)**2, (x,0,oo), meijerg=True)
# Out:
# ∞
# ⌠
# ⎮  -ρ⋅x        2
# ⎮ ℯ    ⋅besseli (1, c⋅x) dx
# ⌡
# 0

# %% [markdown]
# Nr 10

# %%
integrate(exp(-rho*x) * besseli(1,c*x)**2 / x, (x,0,oo), meijerg=True)
# Out:
# ∞
# ⌠
# ⎮  -ρ⋅x        2
# ⎮ ℯ    ⋅besseli (1, c⋅x)
# ⎮ ────────────────────── dx
# ⎮           x
# ⌡
# 0

# %% [markdown]
# Nr 11

# %%
integrate(x**(nu+1) * sin(c*x**2/(2*a)) * besselk(nu, c*x), (x,0,oo), meijerg=True)
# Out:
# ⎧                    ⎛
# ⎪                    ⎜
# ⎪                    ⎜
# ⎪                    ⎜
# ⎪    2⋅ν - 4  -ν + 2 ⎜     -2⋅ν - 4   ___  ν + 1  ν + 1    ⎛a⋅c⎞  ⎛  ν   1⎞  ⎛
# ⎪16⋅2       ⋅c      ⋅⎜- 4⋅2        ⋅╲╱ π ⋅a     ⋅c     ⋅sin⎜───⎟⋅Γ⎜- ─ - ─⎟⋅Γ⎜
# ⎪                    ⎝                                     ⎝ 2 ⎠  ⎝  2   2⎠  ⎝
# ⎪─────────────────────────────────────────────────────────────────────────────
# ⎪
# ⎨
# ⎪
# ⎪
# ⎪
# ⎪
# ⎪
# ⎪
# ⎪
# ⎪
# ⎩
#
#
#                                                                       ⎛ν⎞  ⎛ν
#                                                                  a⋅c⋅Γ⎜─⎟⋅Γ⎜─
#                                                                       ⎝2⎠  ⎝2
# ν   3⎞    -2⋅ν - 2   ___  ν + 1  ν + 1    ⎛a⋅c⎞  ⎛-ν⎞  ⎛ν    ⎞
# ─ + ─⎟ + 2        ⋅╲╱ π ⋅a     ⋅c     ⋅cos⎜───⎟⋅Γ⎜──⎟⋅Γ⎜─ + 1⎟ + ─────────────
# 2   2⎠                                    ⎝ 2 ⎠  ⎝2 ⎠  ⎝2    ⎠
# ...

# %%
hyperexpand(_)
# Out:
# ⎧                    ⎛
# ⎪                    ⎜
# ⎪                    ⎜
# ⎪                    ⎜
# ⎪    2⋅ν - 4  -ν + 2 ⎜     -2⋅ν - 4   ___  ν + 1  ν + 1    ⎛a⋅c⎞  ⎛  ν   1⎞  ⎛
# ⎪16⋅2       ⋅c      ⋅⎜- 4⋅2        ⋅╲╱ π ⋅a     ⋅c     ⋅sin⎜───⎟⋅Γ⎜- ─ - ─⎟⋅Γ⎜
# ⎪                    ⎝                                     ⎝ 2 ⎠  ⎝  2   2⎠  ⎝
# ⎪─────────────────────────────────────────────────────────────────────────────
# ⎪
# ⎨
# ⎪
# ⎪
# ⎪
# ⎪
# ⎪
# ⎪
# ⎪
# ⎪
# ⎩
#
#
#                                                                       ⎛ν⎞  ⎛ν
#                                                                  a⋅c⋅Γ⎜─⎟⋅Γ⎜─
#                                                                       ⎝2⎠  ⎝2
# ν   3⎞    -2⋅ν - 2   ___  ν + 1  ν + 1    ⎛a⋅c⎞  ⎛-ν⎞  ⎛ν    ⎞
# ─ + ─⎟ + 2        ⋅╲╱ π ⋅a     ⋅c     ⋅cos⎜───⎟⋅Γ⎜──⎟⋅Γ⎜─ + 1⎟ + ─────────────
# 2   2⎠                                    ⎝ 2 ⎠  ⎝2 ⎠  ⎝2    ⎠
# ...

# %% [markdown]
# Nr 12

# %%
integrate(sin(b*x**2) * besselk(nu, c*x), (x,0,oo), meijerg=True)
# Out:
# ⎧                   ⎛ν   1⎞
# ⎪               ⅈ⋅π⋅⎜─ + ─⎟        ⎛          ⅈ⋅π⎞        ⎛        ⅈ⋅π⎞
# ⎪   ν   7           ⎝2   2⎠        ⎜          ───⎟        ⎜        ───⎟
# ⎪ - ─ - ─       ───────────        ⎜       2   2 ⎟        ⎜     2   2 ⎟
# ⎪   2   2    2       2             ⎜      c ⋅ℯ   ⎟        ⎜-ν  c ⋅ℯ   ⎟  ⎛ν⎞
# ⎪2       ⋅π⋅c ⋅ℯ           ⋅besseli⎜-1/2, ───────⎟⋅besseli⎜──, ───────⎟⋅Γ⎜─⎟⋅Γ
# ⎪                                  ⎝        8⋅b  ⎠        ⎝2     8⋅b  ⎠  ⎝2⎠
# ⎪─────────────────────────────────────────────────────────────────────────────
# ⎪                                                   ⎛ν   3⎞
# ⎪                                                b⋅Γ⎜─ + ─⎟
# ⎨                                                   ⎝4   4⎠
# ⎪─────────────────────────────────────────────────────────────────────────────
# ⎪
# ⎪
# ⎪
# ⎪
# ⎪
# ⎪
# ⎪
# ⎪
# ⎩
#
#                                                    ⎛ν   1⎞
# ...

# %%
hyperexpand(_.args[0].args[0])
# Out:
#                    ⎛ν   1⎞
#                ⅈ⋅π⋅⎜─ + ─⎟        ⎛          ⅈ⋅π⎞        ⎛        ⅈ⋅π⎞
#    ν   7           ⎝2   2⎠        ⎜          ───⎟        ⎜        ───⎟
#  - ─ - ─       ───────────        ⎜       2   2 ⎟        ⎜     2   2 ⎟
#    2   2    2       2             ⎜      c ⋅ℯ   ⎟        ⎜-ν  c ⋅ℯ   ⎟  ⎛ν⎞  ⎛
# 2       ⋅π⋅c ⋅ℯ           ⋅besseli⎜-1/2, ───────⎟⋅besseli⎜──, ───────⎟⋅Γ⎜─⎟⋅Γ⎜
#                                   ⎝        8⋅b  ⎠        ⎝2     8⋅b  ⎠  ⎝2⎠  ⎝
# ──────────────────────────────────────────────────────────────────────────────
#                                                    ⎛ν   3⎞
#                                                 b⋅Γ⎜─ + ─⎟
#                                                    ⎝4   4⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                                                   ⎛ν   1⎞
#                                               ⅈ⋅π⋅⎜─ - ─⎟        ⎛         ⅈ⋅π
# ...

# %%
expand_func(_)
# Out:
#                        ⎛ν   1⎞
#                    ⅈ⋅π⋅⎜─ + ─⎟        ⎛          ⅈ⋅π⎞        ⎛        ⅈ⋅π⎞
#      ν   7             ⎝2   2⎠        ⎜          ───⎟        ⎜        ───⎟
#    - ─ - ─         ───────────        ⎜       2   2 ⎟        ⎜     2   2 ⎟
#      2   2    2         2             ⎜      c ⋅ℯ   ⎟        ⎜-ν  c ⋅ℯ   ⎟  ⎛-
#   2       ⋅π⋅c ⋅ν⋅ℯ           ⋅besseli⎜-1/2, ───────⎟⋅besseli⎜──, ───────⎟⋅Γ⎜─
#                                       ⎝        8⋅b  ⎠        ⎝2     8⋅b  ⎠  ⎝2
# - ────────────────────────────────────────────────────────────────────────────
#                                                      ⎛ν   3⎞
#                                                 2⋅b⋅Γ⎜─ + ─⎟
#                                                      ⎝4   4⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                                                              ⎛ν   1⎞
# ...

# %%
besselsimp(_)
# Out:
#                                           ⎛ν   1⎞
#                                       ⅈ⋅π⋅⎜─ + ─⎟
#      ν   7               ⅈ⋅π  -ⅈ⋅π⋅ν      ⎝2   2⎠
#    - ─ - ─               ───  ──────  ───────────    ⎛  2⎞        ⎛      2⎞
#      2   2     ___  2     4     4          2         ⎜ c ⎟        ⎜-ν   c ⎟  ⎛
# 2⋅2       ⋅ⅈ⋅╲╱ π ⋅c ⋅ν⋅ℯ   ⋅ℯ      ⋅ℯ           ⋅cos⎜───⎟⋅besselj⎜──, ───⎟⋅Γ⎜
#                                                      ⎝8⋅b⎠        ⎝2   8⋅b⎠  ⎝
# ──────────────────────────────────────────────────────────────────────────────
#                                                   ____
#                                                  ╱  2
#                                                 ╱  c    ⎛ν   3⎞
#                                            b⋅  ╱   ── ⋅Γ⎜─ + ─⎟
#                                              ╲╱    b    ⎝4   4⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
# ...

# %%
expand(_)
# Out:
#          ν         -ⅈ⋅π
#          ─         ────    ⎛  2⎞        ⎛     2⎞
#     ___  2      2   4      ⎜ c ⎟        ⎜ν   c ⎟  ⎛-ν⎞  ⎛ν⎞  ⎛  ν   1⎞  ⎛ν   1
#   ╲╱ 2 ⋅2 ⋅ⅈ⋅c⋅ν ⋅ℯ    ⋅sin⎜───⎟⋅besselj⎜─, ───⎟⋅Γ⎜──⎟⋅Γ⎜─⎟⋅Γ⎜- ─ + ─⎟⋅Γ⎜─ + ─
#                            ⎝8⋅b⎠        ⎝2  8⋅b⎠  ⎝2 ⎠  ⎝2⎠  ⎝  2   2⎠  ⎝4   4
# - ────────────────────────────────────────────────────────────────────────────
#          ⎛             ____  ⅈ⋅π                       ____  ⅈ⋅π           ⎞
#          ⎜            ╱  2   ───                      ╱  2   ───           ⎟
#          ⎜           ╱  c     4   ⎛  ν   1⎞          ╱  c     4   ⎛  ν   1⎞⎟
#       16⋅⎜- 2⋅b⋅ν⋅  ╱   ── ⋅ℯ   ⋅Γ⎜- ─ + ─⎟ - 2⋅b⋅  ╱   ── ⋅ℯ   ⋅Γ⎜- ─ + ─⎟⎟
#          ⎝        ╲╱    b         ⎝  4   4⎠       ╲╱    b         ⎝  4   4⎠⎠
#
#            ν        -ⅈ⋅π
#            ─        ────    ⎛  2⎞        ⎛     2⎞
# ⎞     ___  2         4      ⎜ c ⎟        ⎜ν   c ⎟  ⎛-ν⎞  ⎛ν⎞  ⎛  ν   1⎞  ⎛ν
# ...

# %% [markdown]
# Nr 13

# %%
# What is H_v
