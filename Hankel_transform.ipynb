# %%
# %load_ext sympyprt

# %%
from sympy import *

# %%
r = Symbol("r")
k = Symbol("k")

nu = Symbol("nu")

# %% [markdown]
# Zero-th order

# %% [markdown]
# 1

# %%
1/r
# Out:
# 1
# ─
# r

# %%
hankel_transform(_, r, k, 0)
# Out:
# 1
# ─
# k

# %%
inverse_hankel_transform(_, k, r, 0)
# Out:
# 1
# ─
# r

# %% [markdown]
# 1b

# %%
m = Symbol("m")

# %%
1/r**m
# Out:
#  -m
# r

# %%
hankel_transform(_, r, k, 0)
# Out:
#  -m + 1  m - 2  ⎛  m    ⎞
# 2      ⋅k     ⋅Γ⎜- ─ + 1⎟
#                 ⎝  2    ⎠
# ─────────────────────────
#             ⎛m⎞
#            Γ⎜─⎟
#             ⎝2⎠

# %%
inverse_hankel_transform(_, k, r, 0)
# Out:
#  -m
# r

# %% [markdown]
# 2

# %%
r
# Out:
# r

# %%
HankelTransform(_, r, k, 0)
# Out:
# HankelTransform(r, r, k, 0)

# %%
_.as_integral
# Out:
# ∞
# ⌠
# ⎮  2
# ⎮ r ⋅besselj(0, k⋅r) dr
# ⌡
# 0

# %% [markdown]
# 3

# %%
r**3
# Out:
#  3
# r

# %%
#hankel_transform(_, r, k, 0)

# %% [markdown]
# 4

# %%
m = Symbol("m")

# %%
r**m
# Out:
#  m
# r

# %%
h = hankel_transform(_, r, k, 0)
h
# Out:
#  m + 1  -m - 2  ⎛m    ⎞
# 2     ⋅k      ⋅Γ⎜─ + 1⎟
#                 ⎝2    ⎠
# ───────────────────────
#           ⎛-m⎞
#          Γ⎜──⎟
#           ⎝2 ⎠

# %%
h.subs(m, 3)
# Out:
# 9
# ──
#  5
# k

# %%
inverse_hankel_transform(h, k, r, 0)
# Out:
#  m
# r

# %%
# Only the general case with symbolic 'm' does work!

# %% [markdown]
# 5

# %%
a = Symbol("a")

# %%
1/sqrt(r**2+a**2)
# Out:
#      1
# ────────────
#          1/2
# ⎛ 2    2⎞
# ⎝a  + r ⎠

# %%
hankel_transform(_, r, k, 0)
# Out:
# -sinh(a⋅k) + cosh(a⋅k)
# ──────────────────────
#           k

# %%
#inverse_hankel_transform(_, k, r, 0)

# %% [markdown]
# 6

# %%
a = Symbol("a")

# %%
1/(r**2+a**2)
# Out:
#    1
# ───────
#  2    2
# a  + r

# %%
hankel_transform(_, r, k, 0)
# Out:
#         ⎛        │  2  2⎞
# ╭─╮2, 1 ⎜ 0      │ a ⋅k ⎟
# │╶┐     ⎜        │ ─────⎟
# ╰─╯1, 3 ⎝0, 0  0 │   4  ⎠
# ─────────────────────────
#             2

# %%
hyperexpand(_)
# Out:
#         ⎛        │  2  2⎞
# ╭─╮2, 1 ⎜ 0      │ a ⋅k ⎟
# │╶┐     ⎜        │ ─────⎟
# ╰─╯1, 3 ⎝0, 0  0 │   4  ⎠
# ─────────────────────────
#             2

# %%
# Should be a besselk_0(k*z)

# %%
inverse_hankel_transform(_, k, r, 0)
# Out:
#    1
# ───────
#  2    2
# a  + r

# %% [markdown]
# 6b

# %%
a = Symbol("a")

# %%
1/sqrt(r**4+a**4)
# Out:
#      1
# ────────────
#          1/2
# ⎛ 4    4⎞
# ⎝a  + r ⎠

# %%
hankel_transform(_, r, k, 0)
# Out:
#         ⎛                  │  4  4⎞
# ╭─╮3, 1 ⎜   1/2            │ a ⋅k ⎟
# │╶┐     ⎜                  │ ─────⎟
# ╰─╯1, 5 ⎝0, 0, 1/2  0, 1/2 │  256 ⎠
# ───────────────────────────────────
#                   ___
#               4⋅╲╱ π

# %%
# Should be a product of K_0 and J_0

# %%
inverse_hankel_transform(_, k, r, 0)
# Out:
#         1
# ─────────────────
#          ________
#         ╱  4
#  2     ╱  a
# r ⋅   ╱   ── + 1
#      ╱     4
#    ╲╱     r

# %% [markdown]
# 6c

# %%
f = 1/(r*(r+a))
f
# Out:
#     1
# ─────────
# r⋅(a + r)

# %%
hankel_transform(f, r, k, 0)
# Out:
#         ⎛             │  2  2⎞
# ╭─╮3, 2 ⎜ 1/2, 0      │ a ⋅k ⎟
# │╶┐     ⎜             │ ─────⎟
# ╰─╯2, 4 ⎝1/2, 0, 0  0 │   4  ⎠
# ──────────────────────────────
#              2⋅π

# %%
# Expressible in Kelvin functions

# %%
inverse_hankel_transform(_, k, r, 0)
# Out:
#     1
# ─────────
# r⋅(a + r)

# %%
hankel_transform(f, r, k, nu)
# Out:
#         ⎛ 1/2, 0       │  2  2⎞
# ╭─╮3, 2 ⎜              │ a ⋅k ⎟
# │╶┐     ⎜        ν  -ν │ ─────⎟
# ╰─╯2, 4 ⎜1/2, 0, ─  ── │   4  ⎟
#         ⎝        2  2  │      ⎠
# ───────────────────────────────
#               2⋅π

# %% [markdown]
# 6d

# %%
f = 1/(1+r**4)
f
# Out:
#   1
# ──────
#  4
# r  + 1

# %%
hankel_transform(f, r, k, 0)
# Out:
#         ⎛                    │   4⎞
# ╭─╮3, 1 ⎜    1/2             │  k ⎟
# │╶┐     ⎜                    │ ───⎟
# ╰─╯1, 5 ⎝1/2, 0, 1/2  0, 1/2 │ 256⎠
# ───────────────────────────────────
#                  4

# %%
inverse_hankel_transform(_, k, r, 0)
# Out:
#   1
# ──────
#  4
# r  + 1

# %%
#hankel_transform(f, k, r, nu)

# %% [markdown]
# 6e

# %%
a = Symbol("a")

# %%
f = 1 / (a**4+r**4)
f
# Out:
#    1
# ───────
#  4    4
# a  + r

# %%
hankel_transform(f, r, k, 0)
# Out:
#         ⎛                    │  4  4⎞
# ╭─╮3, 1 ⎜    1/2             │ a ⋅k ⎟
# │╶┐     ⎜                    │ ─────⎟
# ╰─╯1, 5 ⎝1/2, 0, 1/2  0, 1/2 │  256 ⎠
# ─────────────────────────────────────
#                     2
#                  4⋅a

# %%
inverse_hankel_transform(_, k, r, 0)
# Out:
#    1
# ───────
#  4    4
# a  + r

# %%
hankel_transform(f, r, k, nu)
# Out:
# ⎛       ⅈ⋅π⋅(2⋅ν + 1)
# ⎜       ─────────────                                 ⎛              1
# ⎜ 3  3        4          ⎛π⋅ν⎞    ⎛π⋅ν⎞  ⎛ν   1⎞  ┌─  ⎜
# ⎜a ⋅k ⋅ℯ             ⋅sin⎜───⎟⋅cos⎜───⎟⋅Γ⎜─ - ─⎟⋅ ├─  ⎜  ν      ν        ν   3
# ⎜                        ⎝ 4 ⎠    ⎝ 4 ⎠  ⎝4   2⎠ 1╵ 4 ⎜- ─ + 1, ─ + 1, - ─ + ─
# ⎜                                                     ⎝  4      4        4   2
# ⎜─────────────────────────────────────────────────────────────────────────────
# ⎝                                              16
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#         │   4  4⎞            ⅈ⋅π⋅(ν + 1)                 ⎛        ⅈ⋅π⎞
#         │ -a ⋅k ⎟            ───────────                 ⎜        ───⎟
#   ν   3 │ ──────⎟                 4         ⎛π⋅ν⎞        ⎜         4 ⎟  ⎛ν   3
# , ─ + ─ │  256  ⎟   π⋅a⋅k⋅ν⋅ℯ           ⋅sin⎜───⎟⋅besseli⎝ν, a⋅k⋅ℯ   ⎠⋅Γ⎜─ + ─
# ...

# %%
#inverse_hankel_transform(_, k, r, nu)

# %% [markdown]
# 7

# %%
a = Symbol("a", positive=True)

# %%
exp(I*a*r)/r
# Out:
#  ⅈ⋅a⋅r
# ℯ
# ──────
#   r

# %%
h = hankel_transform(_, r, k, 0)
h
# Out:
# ⎧        ⅈ⋅π
# ⎪        ───
# ⎪         2
# ⎪       ℯ                 2 │1 │
# ⎪ ────────────────   for a ⋅│──│ > 1
# ⎪         ________          │ 2│
# ⎪        ╱  2               │k │
# ⎪       ╱  a
# ⎪ k⋅   ╱   ── - 1
# ⎪     ╱     2
# ⎨   ╲╱     k
# ⎪
# ⎪        1
# ⎪──────────────────     otherwise
# ⎪        __________
# ⎪       ╱    2
# ⎪      ╱    a
# ⎪k⋅   ╱   - ── + 1
# ⎪    ╱       2
# ⎪  ╲╱       k
# ⎩

# %%
# Could be correct but should be simplified to nicer form
# - Put the k into the roots
# - simplify exp to I

# %%
h.args[0].args[0]
# Out:
#        ⅈ⋅π
#        ───
#         2
#       ℯ
# ────────────────
#         ________
#        ╱  2
#       ╱  a
# k⋅   ╱   ── - 1
#     ╱     2
#   ╲╱     k

# %%
#inverse_hankel_transform(_, k, r, 0)
# Takes forever

# %% [markdown]
# 8

# %%
a = Symbol("a")

# %%
exp(-a**2*r**2/2)
# Out:
#    2  2
#  -a ⋅r
#  ──────
#    2
# ℯ

# %%
hankel_transform(_, r, k, 0)
# Out:
#    2
#  -k
#  ────
#     2
#  2⋅a
# ℯ
# ─────
#    2
#   a

# %%
inverse_hankel_transform(_, k, r, 0)
# Out:
#    2  2
#  -a ⋅r
#  ──────
#    2
# ℯ

# %% [markdown]
# 9

# %%
f = Function("f")

# %%
-r**2*f(r)
# Out:
#   2
# -r ⋅f(r)

# %%
#hankel_transform(_, r, k, 0)

# %% [markdown]
# 10

# %%
a = Symbol("a")

# %%
sin(2*pi*a*r)/r
# Out:
# sin(2⋅π⋅a⋅r)
# ────────────
#      r

# %%
hankel_transform(_, r, k, 0)
# Out:
# ⎧                                                                 │ 2│
# ⎪                                                               2 │a │
# ⎪                          0                             for 4⋅π ⋅│──│ < 1
# ⎪                                                                 │ 2│
# ⎪                                                                 │k │
# ⎪
# ⎪                                                              │ 2│
# ⎪                                                              │k │
# ⎪                                                              │──│
# ⎪                                                              │ 2│
# ⎪                          1                                   │a │
# ⎪                ──────────────────────                    for ──── < 1
# ⎪                        ______________                           2
# ⎪                       ╱    2  2    2                         4⋅π
# ⎪                      ╱  4⋅π ⋅a  - k
# ...

# %% [markdown]
# 10b

# %%
a = Symbol("a")

# %%
cos(2*pi*a*r)/r
# Out:
# cos(2⋅π⋅a⋅r)
# ────────────
#      r

# %%
hankel_transform(_, r, k, 0)
# Out:
# ⎧                                                                 │ 2│
# ⎪                          1                                    2 │a │
# ⎪               ───────────────────────                  for 4⋅π ⋅│──│ < 1
# ⎪                       _______________                           │ 2│
# ⎪                      ╱      2  2                                │k │
# ⎪                     ╱    4⋅π ⋅a
# ⎪               k⋅   ╱   - ─────── + 1
# ⎪                   ╱          2
# ⎪                 ╲╱          k
# ⎪
# ⎪                                                              │ 2│
# ⎪                                                              │k │
# ⎪                                                              │──│
# ⎪                                                              │ 2│
# ⎪                                                              │a │
# ⎪                          0                               for ──── < 1
# ...

# %% [markdown]
# 11

# %%
a = Symbol("a")

# %%
(a**2+r**2)**(-Rational(3,2))
# Out:
#      1
# ────────────
#          3/2
# ⎛ 2    2⎞
# ⎝a  + r ⎠

# %%
hankel_transform(_, r, k, 0)
# Out:
# -sinh(a⋅k) + cosh(a⋅k)
# ──────────────────────
#           a

# %%
#inverse_hankel_transform(_, k, r, 0)

# %% [markdown]
# 12

# %%
a = Symbol("a")

# %%
2*a**2/(a**2+r**2)**2
# Out:
#       2
#    2⋅a
# ──────────
#          2
# ⎛ 2    2⎞
# ⎝a  + r ⎠

# %%
hankel_transform(_, r, k, 0)
# Out:
#         ⎛        │  2  2⎞
# ╭─╮2, 1 ⎜ 0      │ a ⋅k ⎟
# │╶┐     ⎜        │ ─────⎟
# ╰─╯1, 3 ⎝1, 0  0 │   4  ⎠

# %%
# Should be a besselk of order 1

# %%
inverse_hankel_transform(_, k, r, 0)
# Out:
#      2
# ────────────
#            2
#    ⎛     2⎞
#  2 ⎜    r ⎟
# a ⋅⎜1 + ──⎟
#    ⎜     2⎟
#    ⎝    a ⎠

# %% [markdown]
# 13

# %%
a = Symbol("a")

# %%
4*a**4/(a**2+r**2)**3
# Out:
#       4
#    4⋅a
# ──────────
#          3
# ⎛ 2    2⎞
# ⎝a  + r ⎠

# %%
hankel_transform(_, r, k, 0)
# Out:
#         ⎛        │  2  2⎞
# ╭─╮2, 1 ⎜ 0      │ a ⋅k ⎟
# │╶┐     ⎜        │ ─────⎟
# ╰─╯1, 3 ⎝2, 0  0 │   4  ⎠

# %%
# Should be a besselk of order 2

# %%
inverse_hankel_transform(_, k, r, 0)
# Out:
#      4
# ────────────
#            3
#    ⎛     2⎞
#  2 ⎜    r ⎟
# a ⋅⎜1 + ──⎟
#    ⎜     2⎟
#    ⎝    a ⎠

# %% [markdown]
# 14

# %%
a = Symbol("a")

# %%
exp(-a*r)
# Out:
#  -a⋅r
# ℯ

# %%
hankel_transform(_, r, k, 0)
# Out:
#       a
# ──────────────
#            3/2
#    ⎛ 2    ⎞
#  3 ⎜a     ⎟
# k ⋅⎜── + 1⎟
#    ⎜ 2    ⎟
#    ⎝k     ⎠

# %%
inverse_hankel_transform(_, k, r, 0)
# Out:
# -sinh(a⋅r) + cosh(a⋅r)

# %% [markdown]
# 15

# %%
a = Symbol("a")

# %%
r**2*exp(-pi*r**2)
# Out:
#         2
#  2  -π⋅r
# r ⋅ℯ

# %%
hankel_transform(_, r, k, 0)
# Out:
#                 2
#               -k
#               ───
# ⎛   2      ⎞  4⋅π
# ⎝- k  + 4⋅π⎠⋅ℯ
# ─────────────────
#           3
#        8⋅π

# %%
inverse_hankel_transform(_, k, r, 0)
# Out:
#         2
#  2  -π⋅r
# r ⋅ℯ

# %% [markdown]
# Arbitrary order

# %% [markdown]
# 1

# %%
a = Symbol("a")

# %%
exp(-a**2*r**2/2)
# Out:
#    2  2
#  -a ⋅r
#  ──────
#    2
# ℯ

# %%
hankel_transform(_, r, k, nu)
# Out:
#             ⎛                                                                ⎛
#             ⎜                                                       2        ⎜
#             ⎜                                                      k ⋅besseli⎜
#             ⎜            ⎛         2 ⎞             ⎛         2 ⎞             ⎜
#   ___   ___ ⎜ 2          ⎜ν   1   k  ⎟    2        ⎜ν   1   k  ⎟             ⎝
# ╲╱ 2 ⋅╲╱ π ⋅⎜a ⋅ν⋅besseli⎜─ + ─, ────⎟ + a ⋅besseli⎜─ + ─, ────⎟ - ───────────
#             ⎜            ⎜2   2     2⎟             ⎜2   2     2⎟
#             ⎝            ⎝       4⋅a ⎠             ⎝       4⋅a ⎠
# ──────────────────────────────────────────────────────────────────────────────
#                                                              3
#                                                             a ⋅k
#
#          2 ⎞             ⎛         2 ⎞⎞    2
# ν   1   k  ⎟    2        ⎜ν   3   k  ⎟⎟  -k
# ─ + ─, ────⎟   k ⋅besseli⎜─ + ─, ────⎟⎟  ────
# ...

# %%
#inverse_hankel_transform(_, k, r, nu)

# %% [markdown]
# 2

# %%
s = Symbol("s")

# %%
r**s
# Out:
#  s
# r

# %%
hankel_transform(_, r, k, nu)
# Out:
#  s + 1  -s - 2  ⎛ν   s    ⎞
# 2     ⋅k      ⋅Γ⎜─ + ─ + 1⎟
#                 ⎝2   2    ⎠
# ───────────────────────────
#            ⎛ν   s⎞
#           Γ⎜─ - ─⎟
#            ⎝2   2⎠

# %% [markdown]
# 3

# %%
s = Symbol("s")
h = Symbol("h")

# %% [markdown]
# Can not express $r^{\nu-2s}\Gamma\left(s,r^2 h\right)$

# %% [markdown]
# 4

# %% [markdown]
# Can not express $e^{-r^2}r^\nu U\left(a,b,r^2\right)$

# %% [markdown]
# 5

# %%
a = Symbol("a")

# %%
4*a**4/(a**2+r**2)**3
# Out:
#       4
#    4⋅a
# ──────────
#          3
# ⎛ 2    2⎞
# ⎝a  + r ⎠

# %%
hankel_transform(_, r, k, nu)
# Out:
#                     ⎛      3        │  2  2⎞             ⎛           ⎛  2  2
#  4  4  ⎛ν    ⎞  ┌─  ⎜               │ a ⋅k ⎟    -ν  ν  ν ⎜ ν  -ν  -ν ⎜ a ⋅k
# a ⋅k ⋅Γ⎜─ - 2⎟⋅ ├─  ⎜ν        ν     │ ─────⎟   2  ⋅a ⋅k ⋅⎜2 ⋅a  ⋅k  ⋅⎜────────
#        ⎝2    ⎠ 1╵ 2 ⎜─ + 3, - ─ + 3 │   4  ⎟             ⎜           ⎜ 2
#                     ⎝2        2     │      ⎠             ⎝           ⎝ν  - 2⋅ν
# ──────────────────────────────────────────── + ───────────────────────────────
#                     ⎛ν    ⎞
#                  8⋅Γ⎜─ + 3⎟
#                     ⎝2    ⎠
#
#     ⎞
#     ⎟                             ν - 1  -ν + 1  -ν + 1 ⎛    4⋅ν      4⋅ν - 4
#  + 1⎟⋅besseli(ν, a⋅k)⋅Γ(ν + 1) + 2     ⋅a      ⋅k      ⋅⎜- ──────── + ────────
#     ⎟                                                   ⎜   2          2
#     ⎠                                                   ⎝  ν  - 2⋅ν   ν  - 2⋅ν
# ──────────────────────────────────────────────────────────────────────────────
# ...

# %%
hyperexpand(_)
# Out:
#                     ⎛      3        │  2  2⎞             ⎛           ⎛  2  2
#  4  4  ⎛ν    ⎞  ┌─  ⎜               │ a ⋅k ⎟    -ν  ν  ν ⎜ ν  -ν  -ν ⎜ a ⋅k
# a ⋅k ⋅Γ⎜─ - 2⎟⋅ ├─  ⎜ν        ν     │ ─────⎟   2  ⋅a ⋅k ⋅⎜2 ⋅a  ⋅k  ⋅⎜────────
#        ⎝2    ⎠ 1╵ 2 ⎜─ + 3, - ─ + 3 │   4  ⎟             ⎜           ⎜ 2
#                     ⎝2        2     │      ⎠             ⎝           ⎝ν  - 2⋅ν
# ──────────────────────────────────────────── + ───────────────────────────────
#                     ⎛ν    ⎞
#                  8⋅Γ⎜─ + 3⎟
#                     ⎝2    ⎠
#
#     ⎞
#     ⎟                             ν - 1  -ν + 1  -ν + 1 ⎛    4⋅ν      4⋅ν - 4
#  + 1⎟⋅besseli(ν, a⋅k)⋅Γ(ν + 1) + 2     ⋅a      ⋅k      ⋅⎜- ──────── + ────────
#     ⎟                                                   ⎜   2          2
#     ⎠                                                   ⎝  ν  - 2⋅ν   ν  - 2⋅ν
# ──────────────────────────────────────────────────────────────────────────────
# ...

# %% [markdown]
# 6

# %%
1/r
# Out:
# 1
# ─
# r

# %%
hankel_transform(_, r, k, nu)
# Out:
# 1
# ─
# k

# %%
inverse_hankel_transform(_, k, r, nu)
# Out:
# 1
# ─
# r

# %% [markdown]
# 7

# %%
r
# Out:
# r

# %%
#hankel_transform(_, r, k, nu)

# %% [markdown]
# 7b

# %%
m = Symbol("m")

# %%
1/r**m
# Out:
#  -m
# r

# %%
hankel_transform(_, r, k, nu)
# Out:
#  -m + 1  m - 2  ⎛  m   ν    ⎞
# 2      ⋅k     ⋅Γ⎜- ─ + ─ + 1⎟
#                 ⎝  2   2    ⎠
# ─────────────────────────────
#             ⎛m   ν⎞
#            Γ⎜─ + ─⎟
#             ⎝2   2⎠

# %%
inverse_hankel_transform(_, k, r, nu)
# Out:
#  -m
# r

# %% [markdown]
# 8

# %%
a = Symbol("a")

# %%
1/sqrt(r**2+a**2)
# Out:
#      1
# ────────────
#          1/2
# ⎛ 2    2⎞
# ⎝a  + r ⎠

# %%
hankel_transform(_, r, k, nu)
# Out:
#   ⎛
#   ⎜ 2  2        ⎛  ν   1  a⋅k⎞        ⎛ν   1  a⋅k⎞             2  2        ⎛
# π⋅⎜a ⋅k ⋅besseli⎜- ─ - ─, ───⎟⋅besseli⎜─ - ─, ───⎟⋅Γ(ν + 1) + a ⋅k ⋅besseli⎜-
#   ⎝             ⎝  2   2   2 ⎠        ⎝2   2   2 ⎠                         ⎝
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
# ν   1  a⋅k⎞        ⎛ν   1  a⋅k⎞               2  2        ⎛ν   1  a⋅k⎞
# ─ + ─, ───⎟⋅besseli⎜─ + ─, ───⎟⋅Γ(ν + 1) - 2⋅a ⋅k ⋅besseli⎜─ - ─, ───⎟⋅besseli
# 2   2   2 ⎠        ⎝2   2   2 ⎠                           ⎝2   2   2 ⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#                                       2                                      2
# ⎛ν   1  a⋅k⎞                 2         ⎛ν   1  a⋅k⎞                 2
# ⎜─ + ─, ───⎟⋅Γ(ν + 1) - a⋅k⋅ν ⋅besseli ⎜─ - ─, ───⎟⋅Γ(ν + 1) + a⋅k⋅ν ⋅besseli
# ⎝2   2   2 ⎠                           ⎝2   2   2 ⎠
# ...

# %% [markdown]
# 9

# %%
a = Symbol("a")

# %%
1/(r**2+a**2)
# Out:
#    1
# ───────
#  2    2
# a  + r

# %%
hankel_transform(_, r, k, nu)
# Out:
#  ⎛                     ⎛      1        │  2  2⎞                             ⎞
#  ⎜     ⎛π⋅ν⎞  ⎛ν⎞  ┌─  ⎜               │ a ⋅k ⎟                      ⎛ν    ⎞⎟
# -⎜- sin⎜───⎟⋅Γ⎜─⎟⋅ ├─  ⎜ν        ν     │ ─────⎟ + π⋅besseli(ν, a⋅k)⋅Γ⎜─ + 1⎟⎟
#  ⎜     ⎝ 2 ⎠  ⎝2⎠ 1╵ 2 ⎜─ + 1, - ─ + 1 │   4  ⎟                      ⎝2    ⎠⎟
#  ⎝                     ⎝2        2     │      ⎠                             ⎠
# ─────────────────────────────────────────────────────────────────────────────
#                                   ⎛π⋅ν⎞  ⎛ν    ⎞
#                              2⋅sin⎜───⎟⋅Γ⎜─ + 1⎟
#                                   ⎝ 2 ⎠  ⎝2    ⎠

# %%
hyperexpand(_)
# Out:
#  ⎛                     ⎛      1        │  2  2⎞                             ⎞
#  ⎜     ⎛π⋅ν⎞  ⎛ν⎞  ┌─  ⎜               │ a ⋅k ⎟                      ⎛ν    ⎞⎟
# -⎜- sin⎜───⎟⋅Γ⎜─⎟⋅ ├─  ⎜ν        ν     │ ─────⎟ + π⋅besseli(ν, a⋅k)⋅Γ⎜─ + 1⎟⎟
#  ⎜     ⎝ 2 ⎠  ⎝2⎠ 1╵ 2 ⎜─ + 1, - ─ + 1 │   4  ⎟                      ⎝2    ⎠⎟
#  ⎝                     ⎝2        2     │      ⎠                             ⎠
# ─────────────────────────────────────────────────────────────────────────────
#                                   ⎛π⋅ν⎞  ⎛ν    ⎞
#                              2⋅sin⎜───⎟⋅Γ⎜─ + 1⎟
#                                   ⎝ 2 ⎠  ⎝2    ⎠

# %% [markdown]
# Bessel functions

# %% [markdown]
# 1

# %%
a = Symbol("a", positive=True)

# %%
besselj(nu-1, a*r)/r
# Out:
# besselj(ν - 1, a⋅r)
# ───────────────────
#          r

# %%
hankel_transform(_, r, k, 0)
# Out:
#         ⎛ 1/2     1/2   │  2⎞
# ╭─╮1, 1 ⎜               │ a ⎟
# │╶┐     ⎜ν   1    ν   1 │ ──⎟
# ╰─╯2, 2 ⎜─ - ─  - ─ + ─ │  2⎟
#         ⎝2   2    2   2 │ k ⎠
# ─────────────────────────────
#               k

# %%
inverse_hankel_transform(_, k, r, 0)
# Out:
# besselj(ν - 1, a⋅r)
# ───────────────────
#          r

# %% [markdown]
# 2

# %%
a = Symbol("a", positive=True)

# %%
besselj(nu, a*r)/r**2
# Out:
# besselj(ν, a⋅r)
# ───────────────
#         2
#        r

# %%
hankel_transform(_, r, k, 0)
# Out:
#         ⎛1  1  │  2⎞
# ╭─╮1, 1 ⎜      │ a ⎟
# │╶┐     ⎜ν  -ν │ ──⎟
# ╰─╯2, 2 ⎜─  ── │  2⎟
#         ⎝2  2  │ k ⎠
# ────────────────────
#          2

# %%
hyperexpand(_)
# Out:
#         ⎛1  1  │  2⎞
# ╭─╮1, 1 ⎜      │ a ⎟
# │╶┐     ⎜ν  -ν │ ──⎟
# ╰─╯2, 2 ⎜─  ── │  2⎟
#         ⎝2  2  │ k ⎠
# ────────────────────
#          2

# %%
inverse_hankel_transform(_, k, r, 0)
# Out:
# besselj(ν, a⋅r)
# ───────────────
#         2
#        r

# %% [markdown]
# 3

# %%
a = Symbol("a", positive=True)

# %%
besselj(nu+1, a*r)/r
# Out:
# besselj(ν + 1, a⋅r)
# ───────────────────
#          r

# %%
hankel_transform(_, r, k, 0)
# Out:
#         ⎛ 1/2     1/2   │  2⎞
# ╭─╮1, 1 ⎜               │ a ⎟
# │╶┐     ⎜ν   1    ν   1 │ ──⎟
# ╰─╯2, 2 ⎜─ + ─  - ─ - ─ │  2⎟
#         ⎝2   2    2   2 │ k ⎠
# ─────────────────────────────
#               k

# %%
inverse_hankel_transform(_, k, r, 0)
# Out:
# besselj(ν + 1, a⋅r)
# ───────────────────
#          r

# %% [markdown]
# Trigonometric functions

# %%
a = Symbol("a", positive=True)

# %% [markdown]
# 1

# %%
sin(a*r)/r
# Out:
# sin(a⋅r)
# ────────
#    r

# %%
hankel_transform(_, r, k, 0)
# Out:
# ⎧                                                      2 │1 │
# ⎪                       0                         for a ⋅│──│ < 1
# ⎪                                                        │ 2│
# ⎪                                                        │k │
# ⎪
# ⎪                                                      │ 2│
# ⎪                      1                               │k │
# ⎪                 ────────────                     for ──── < 1
# ⎪                          1/2                           2
# ⎪                 ⎛ 2    2⎞                             a
# ⎪                 ⎝a  - k ⎠
# ⎪
# ⎪  ___ ⎧                              2 │1 │
# ⎪╲╱ π ⋅⎪           0             for a ⋅│──│ < 1
# ⎪      ⎪                                │ 2│
# ⎪      ⎪                                │k │
# ⎪      ⎪
# ⎨      ⎪                              │ 2│
# ⎪      ⎪          k                   │k │
# ⎪      ⎪──────────────────────    for ──── < 1
# ⎪      ⎪              ________          2
# ...

# %% [markdown]
# 2

# %%
sin(a*r)/r**2
# Out:
# sin(a⋅r)
# ────────
#     2
#    r

# %%
hankel_transform(_, r, k, 0)
# Out:
# ⎧              ⎛a⎞                 2 │1 │
# ⎪          asin⎜─⎟            for a ⋅│──│ < 1
# ⎪              ⎝k⎠                   │ 2│
# ⎪                                    │k │
# ⎪
# ⎪                                  │ 2│
# ⎪             π                    │k │
# ⎪             ─                for ──── < 1
# ⎪             2                      2
# ⎨                                   a
# ⎪
# ⎪              ⎛       │  2⎞
# ⎪  ___ ╭─╮1, 1 ⎜ 1   1 │ a ⎟
# ⎪╲╱ π ⋅│╶┐     ⎜       │ ──⎟
# ⎪      ╰─╯2, 2 ⎜1/2  0 │  2⎟
# ⎪              ⎝       │ k ⎠
# ⎪───────────────────────────     otherwise
# ⎪             2
# ⎩

# %% [markdown]
# 3

# %%
b = Symbol("b")

# %%
sin(a*r)/(b**2+r**2)
# Out:
# sin(a⋅r)
# ────────
#  2    2
# b  + r

# %%
#hankel_transform(_, r, k, 0)

# %% [markdown]
# 4

# %%
cos(a*r)/r
# Out:
# cos(a⋅r)
# ────────
#    r

# %%
hankel_transform(_, r, k, 0)
# Out:
# ⎧                      1                               2 │1 │
# ⎪              ──────────────────                 for a ⋅│──│ < 1
# ⎪                      __________                        │ 2│
# ⎪                     ╱    2                             │k │
# ⎪                    ╱    a
# ⎪              k⋅   ╱   - ── + 1
# ⎪                  ╱       2
# ⎪                ╲╱       k
# ⎪
# ⎪                                                      │ 2│
# ⎪                                                      │k │
# ⎪                       0                          for ──── < 1
# ⎪                                                        2
# ⎪                                                       a
# ⎪
# ⎪  ___ ⎧          1                   2 │1 │
# ⎪╲╱ π ⋅⎪──────────────────────   for a ⋅│──│ < 1
# ⎪      ⎪            __________          │ 2│
# ⎪      ⎪           ╱    2               │k │
# ⎨      ⎪  ___     ╱    a
# ⎪      ⎪╲╱ π ⋅   ╱   - ── + 1
# ⎪      ⎪        ╱       2
# ...

# %% [markdown]
# 5

# %%
(1-cos(a*r))/r**2
# Out:
# -cos(a⋅r) + 1
# ─────────────
#        2
#       r

# %%
#hankel_transform(_, r, k, 0)

# %% [markdown]
# 6

# %%
cos(a*r)/(b**2+r**2)
# Out:
# cos(a⋅r)
# ────────
#  2    2
# b  + r

# %%
#hankel_transform(_, r, k, 0)

# %% [markdown]
# 7

# %%
cos(a**2*r**2/2)
# Out:
#    ⎛ 2  2⎞
#    ⎜a ⋅r ⎟
# cos⎜─────⎟
#    ⎝  2  ⎠

# %%
#hankel_transform(_, r, k, 0)

# %% [markdown]
# Exponential functions

# %% [markdown]
# 1

# %%
a = Symbol("a")
n = Symbol("n")

# %%
r**(n-Rational(1,2))*exp(-a*r)
# Out:
#  n - 1/2  -a⋅r
# r       ⋅ℯ

# %%
hankel_transform(_, r, k, 0)
# Out:
#                           ⎛n   3  n   5 │  2  ⅈ⋅π⎞
#  -n - 3/2             ┌─  ⎜─ + ─, ─ + ─ │ k ⋅ℯ   ⎟
# a        ⋅Γ(n + 3/2)⋅ ├─  ⎜2   4  2   4 │ ───────⎟
#                      2╵ 1 ⎜             │     2  ⎟
#                           ⎝     1       │    a   ⎠

# %%
#inverse_hankel_transform(_, k, r, 0)

# %% [markdown]
# 2

# %%
a = Symbol("a")

# %%
(1-exp(-a*r))*r**(-2)
# Out:
#      -a⋅r
# 1 - ℯ
# ─────────
#      2
#     r

# %%
h = hankel_transform(_, r, k, nu)
h
# Out:
#     ⎛                       ν                     ⎞                     -ν
#     ⎜   ⎛      ________    ⎞                      ⎟ ⎛      ________    ⎞
#     ⎜   ⎜     ╱      2     ⎟                      ⎟ ⎜     ╱      2     ⎟
#  -ν ⎜ ν ⎜    ╱      k      ⎟              ν       ⎟ ⎜    ╱      k      ⎟
# a  ⋅⎜a ⋅⎜   ╱   1 + ──  + 1⎟ ⋅Γ(ν + 1) - k ⋅ν⋅Γ(ν)⎟⋅⎜   ╱   1 + ──  + 1⎟
#     ⎜   ⎜  ╱         2     ⎟                      ⎟ ⎜  ╱         2     ⎟
#     ⎝   ⎝╲╱         a      ⎠                      ⎠ ⎝╲╱         a      ⎠
# ──────────────────────────────────────────────────────────────────────────
#                                 ν⋅Γ(ν + 1)

# %%
h.subs(nu, 0)
# Out:
# nan

# %%
# Too bad, the solution for nu = 0 is very simple: asinh( a / k )

# %%
#inverse_hankel_transform(h, k, r, nu)

# %% [markdown]
# Bessel functions

# %% [markdown]
# 1

# %%
a = Symbol("a", positive=True)

# %%
(1-besselj(0, a*r))/r**2
# Out:
# -besselj(0, a⋅r) + 1
# ────────────────────
#           2
#          r

# %%
hankel_transform(_, r, k, nu)
# Out:
#  ⎛          ⎛1  1  │  2⎞    ⎞
#  ⎜  ╭─╮1, 1 ⎜      │ k ⎟    ⎟
# -⎜ν⋅│╶┐     ⎜ν  -ν │ ──⎟ - 2⎟
#  ⎜  ╰─╯2, 2 ⎜─  ── │  2⎟    ⎟
#  ⎝          ⎝2  2  │ a ⎠    ⎠
# ─────────────────────────────
#              2⋅ν

# %%
#inverse_hankel_transform(_, k, r, nu)

# %%
f = besselj(1, a*r)/r
f
# Out:
# besselj(1, a⋅r)
# ───────────────
#        r

# %%
hankel_transform(f, r, k, 0)
# Out:
# ⎧                                                 2 │1 │
# ⎪                    0                       for a ⋅│──│ < 1
# ⎪                                                   │ 2│
# ⎪                                                   │k │
# ⎪
# ⎪                                                 │ 2│
# ⎪                    1                            │k │
# ⎪                    ─                        for ──── < 1
# ⎪                    a                              2
# ⎪                                                  a
# ⎪
# ⎪⎧                               2 │1 │
# ⎪⎪           0              for a ⋅│──│ < 1
# ⎪⎪                                 │ 2│
# ⎪⎪                                 │k │
# ⎨⎪
# ⎪⎪                               │ 2│
# ⎪⎪           k                   │k │
# ⎪⎪           ─               for ──── < 1
# ⎪⎨           a                     2
# ⎪⎪                                a
# ⎪⎪
# ⎪⎪        ⎛          │  2⎞
# ⎪⎪╭─╮1, 1 ⎜1/2  1/2  │ a ⎟
# ...

# %%
hankel_transform(f, r, k, nu)
# Out:
#         ⎛0  1  │  2⎞
# ╭─╮1, 1 ⎜      │ k ⎟
# │╶┐     ⎜ν  -ν │ ──⎟
# ╰─╯2, 2 ⎜─  ── │  2⎟
#         ⎝2  2  │ a ⎠
# ────────────────────
#          a

# %%
inverse_hankel_transform(_, k, r, nu)
# Out:
# besselj(1, a⋅r)
# ───────────────
#        r

# %% [markdown]
# Algebraic functions

# %% [markdown]
# 1

# %%
a = Symbol("a")

# %%
r**nu/(r**4+4*a**4)**(nu+Rational(1,2))
# Out:
#               -ν - 1/2
#  ν ⎛   4    4⎞
# r ⋅⎝4⋅a  + r ⎠

# %%
hankel_transform(_, r, k, nu)
# Out:
#  -3⋅ν               ⎛     ν   1                 │      ⎞
#  ────               ⎜   - ─ + ─                 │  4  4⎟
#   2    -3⋅ν ╭─╮3, 1 ⎜     4   2                 │ a ⋅k ⎟
# 2    ⋅a    ⋅│╶┐     ⎜                           │ ─────⎟
#             ╰─╯1, 5 ⎜3⋅ν  ν  ν   1  -ν    ν   1 │   64 ⎟
#                     ⎜───, ─, ─ + ─  ──, - ─ + ─ │      ⎟
#                     ⎝ 4   4  4   2  4     4   2 │      ⎠
# ────────────────────────────────────────────────────────
#                       4⋅Γ(ν + 1/2)

# %%
simplify(_)
# Out:
#  -3⋅ν               ⎛     ν   1                 │      ⎞
#  ────               ⎜   - ─ + ─                 │  4  4⎟
#   2    -3⋅ν ╭─╮3, 1 ⎜     4   2                 │ a ⋅k ⎟
# 2    ⋅a    ⋅│╶┐     ⎜                           │ ─────⎟
#             ╰─╯1, 5 ⎜3⋅ν  ν  ν   1  -ν    ν   1 │   64 ⎟
#                     ⎜───, ─, ─ + ─  ──, - ─ + ─ │      ⎟
#                     ⎝ 4   4  4   2  4     4   2 │      ⎠
# ────────────────────────────────────────────────────────
#                       4⋅Γ(ν + 1/2)

# %%
inverse_hankel_transform(_, k, r, nu)
# Out:
#                     -ν - 1/2
#           ⎛   4    ⎞
#  -3⋅ν - 2 ⎜4⋅a     ⎟
# r        ⋅⎜──── + 1⎟
#           ⎜  4     ⎟
#           ⎝ r      ⎠

# %% [markdown]
# 2

# %%
r**(nu+2) / (r**4+4*a**4)**(nu+Rational(1,2))
# Out:
#                   -ν - 1/2
#  ν + 2 ⎛   4    4⎞
# r     ⋅⎝4⋅a  + r ⎠

# %%
hankel_transform(_, r, k, nu)
# Out:
#    3⋅ν                       ⎛       -ν                      │      ⎞
#  - ─── - 1                   ⎜       ──                      │  4  4⎟
#     2       -3⋅ν + 2 ╭─╮3, 1 ⎜       4                       │ a ⋅k ⎟
# 2         ⋅a        ⋅│╶┐     ⎜                               │ ─────⎟
#                      ╰─╯1, 5 ⎜3⋅ν   1  ν  ν   1  -ν    ν   1 │   64 ⎟
#                              ⎜─── - ─, ─, ─ + ─  ──, - ─ + ─ │      ⎟
#                              ⎝ 4    2  4  4   2  4     4   2 │      ⎠
# ─────────────────────────────────────────────────────────────────────
#                               Γ(ν + 1/2)

# %%
inverse_hankel_transform(_, k, r, nu)
# Out:
#                                -ν - 1/2
#                      ⎛      4 ⎞
#  -ν  -4⋅ν - 2  ν + 2 ⎜     r  ⎟
# 4  ⋅a        ⋅r     ⋅⎜1 + ────⎟
#                      ⎜       4⎟
#                      ⎝    4⋅a ⎠
# ───────────────────────────────────────
#                    2

# %%
simplify(_)
# Out:
#                                -ν - 1/2
#                      ⎛      4 ⎞
#  -ν  -4⋅ν - 2  ν + 2 ⎜     r  ⎟
# 4  ⋅a        ⋅r     ⋅⎜1 + ────⎟
#                      ⎜       4⎟
#                      ⎝    4⋅a ⎠
# ───────────────────────────────────────
#                    2

# %%
expand(_)
# Out:
#                           -ν
#                 ⎛      4 ⎞
#  -ν  -4⋅ν  2  ν ⎜     r  ⎟
# 4  ⋅a    ⋅r ⋅r ⋅⎜1 + ────⎟
#                 ⎜       4⎟
#                 ⎝    4⋅a ⎠
# ────────────────────────────
#               __________
#              ╱       4
#       2     ╱       r
#    2⋅a ⋅   ╱   1 + ────
#           ╱           4
#         ╲╱         4⋅a

# %% [markdown]
# Exponential functions

# %% [markdown]
# 1

# %%
a = Symbol("a")

# %%
exp(-a*r)/r
# Out:
#  -a⋅r
# ℯ
# ─────
#   r

# %%
hankel_transform(_, r, k, nu)
# Out:
#                                -ν - 1
#            ⎛      ________    ⎞       ⎛         ________          ⎞
#            ⎜     ╱      2     ⎟       ⎜        ╱      2           ⎟
#  -ν - 1  ν ⎜    ╱      k      ⎟       ⎜ 2     ╱      k      2    2⎟
# a      ⋅k ⋅⎜   ╱   1 + ──  + 1⎟      ⋅⎜a ⋅   ╱   1 + ──  + a  + k ⎟
#            ⎜  ╱         2     ⎟       ⎜     ╱         2           ⎟
#            ⎝╲╱         a      ⎠       ⎝   ╲╱         a            ⎠
# ───────────────────────────────────────────────────────────────────
#                                2    2
#                               a  + k

# %%
#inverse_hankel_transform(_, k, r, nu)

# %% [markdown]
# 2

# %%
exp(-a*r)/r**2
# Out:
#  -a⋅r
# ℯ
# ─────
#    2
#   r

# %%
hankel_transform(_, r, k, nu)
# Out:
#                            -ν
#        ⎛      ________    ⎞
#        ⎜     ╱      2     ⎟
#  -ν  ν ⎜    ╱      k      ⎟
# a  ⋅k ⋅⎜   ╱   1 + ──  + 1⎟  ⋅Γ(ν)
#        ⎜  ╱         2     ⎟
#        ⎝╲╱         a      ⎠
# ──────────────────────────────────
#              Γ(ν + 1)

# %%
#inverse_hankel_transform(_, k, r, nu)

# %% [markdown]
# 3

# %%
a = Symbol("a")

# %%
r**nu*exp(-a*r)
# Out:
#  ν  -a⋅r
# r ⋅ℯ

# %%
hankel_transform(_, r, k, nu)
# Out:
#                          -ν - 3/2
#                  ⎛ 2    ⎞
#  ν + 1    -ν - 3 ⎜a     ⎟
# 2     ⋅a⋅k      ⋅⎜── + 1⎟        ⋅Γ(ν + 3/2)
#                  ⎜ 2    ⎟
#                  ⎝k     ⎠
# ────────────────────────────────────────────
#                      ___
#                    ╲╱ π

# %%
inverse_hankel_transform(_, k, r, nu)
# Out:
#  ν
# r ⋅(-sinh(a⋅r) + cosh(a⋅r))

# %% [markdown]
# 4

# %%
r**(nu-1)*exp(-a*r)
# Out:
#  ν - 1  -a⋅r
# r     ⋅ℯ

# %%
hankel_transform(_, r, k, nu)
# Out:
#                    -ν - 1/2
#            ⎛ 2    ⎞
#  ν  -ν - 1 ⎜a     ⎟
# 2 ⋅k      ⋅⎜── + 1⎟        ⋅Γ(ν + 1/2)
#            ⎜ 2    ⎟
#            ⎝k     ⎠
# ──────────────────────────────────────
#                   ___
#                 ╲╱ π

# %%
inverse_hankel_transform(_, k, r, nu)
# Out:
#  ν - 1
# r     ⋅(-sinh(a⋅r) + cosh(a⋅r))

# %% [markdown]
# 5

# %%
j = Symbol("j", integer=True)

# %%
r**(nu-j)*exp(-a*r)
# Out:
#  -j + ν  -a⋅r
# r      ⋅ℯ

# %%
hankel_transform(_, r, k, nu)
# Out:
#                 ν                      ⎛  j            j       3 │  2  ⅈ⋅π⎞
#  j - 2⋅ν - 2 ⎛k⎞                   ┌─  ⎜- ─ + ν + 1, - ─ + ν + ─ │ k ⋅ℯ   ⎟
# a           ⋅⎜─⎟ ⋅Γ(-j + 2⋅ν + 2)⋅ ├─  ⎜  2            2       2 │ ───────⎟
#              ⎝2⎠                  2╵ 1 ⎜                         │     2  ⎟
#                                        ⎝         ν + 1           │    a   ⎠
# ───────────────────────────────────────────────────────────────────────────
#                                   Γ(ν + 1)

# %%
#inverse_hankel_transform(_, k, r, nu)

# %% [markdown]
# 6

# %%
r**nu*exp(-a*r**2)
# Out:
#         2
#  ν  -a⋅r
# r ⋅ℯ

# %%
hankel_transform(_, r, k, nu)
# Out:
#                   2
#                 -k
#                 ───
#  ν      -ν - 1  4⋅a
# k ⋅(2⋅a)      ⋅ℯ

# %%
inverse_hankel_transform(_, k, r, nu)
# Out:
#         2
#  ν  -a⋅r
# r ⋅ℯ

# %% [markdown]
# Trigonometric functions

# %%
a = Symbol("a", positive=True)

# %% [markdown]
# 1

# %%
sin(a*r)/r
# Out:
# sin(a⋅r)
# ────────
#    r

# %%
hankel_transform(_, r, k, nu)
# Out:
# ⎧          ___________
# ⎪         ╱    2    2
# ⎪        ╱  - a  + k   ⎛                               ⎛ 2          ⎞
# ⎪a⋅k⋅   ╱   ───────── ⋅⎝-ν⋅(ν - 2)⋅(ν - 1) + ν⋅(ν - 1)⋅⎝ν  - 4⋅ν + 4⎠ + (ν - 2
# ⎪      ╱         2
# ⎪    ╲╱         k
# ⎪─────────────────────────────────────────────────────────────────────────────
# ⎪
# ⎪
# ⎪
# ⎪
# ⎪
# ⎪
# ⎪
# ⎪
# ⎪
# ⎪
# ⎪
# ⎪
# ⎪
# ⎪
# ⎪
# ⎪
# ⎪
# ⎪
# ⎪
# ⎪
# ⎪                 ⎧    ⎛  ⎛           ⎛ 2    ⎞         ⎛ 2                ⎞
# ⎪                 ⎪    ⎜  ⎜           ⎜a     ⎟       2 ⎜a ⋅(ν - 2)        ⎟
# ⎪                 ⎪    ⎜  ⎜  (-ν + 2)⋅⎜── - 1⎟      k ⋅⎜────────── - ν + 2⎟
# ⎪                 ⎪    ⎜  ⎜           ⎜ 2    ⎟         ⎜     2            ⎟
# ⎪                 ⎪    ⎜  ⎜           ⎝k     ⎠         ⎝    k             ⎠
# ⎪                 ⎪    ⎜a⋅⎜───────────────────── + ───────────────────────── +
# ⎪                 ⎪    ⎜  ⎜ 2  2      2        2    2         ⎛ 2          ⎞
# ...

# %% [markdown]
# 2

# %%
sin(a*r)/r**2
# Out:
# sin(a⋅r)
# ────────
#     2
#    r

# %%
hankel_transform(_, r, k, nu)
# Out:
# ⎧                                ___________
# ⎪                               ╱    2    2
# ⎪                              ╱  - a  + k   ⎛   2          ⎞    ⎛
# ⎪                    - a⋅k⋅   ╱   ───────── ⋅⎝- ν  + 3⋅ν - 2⎠⋅cos⎜(ν - 1)⋅asin
# ⎪                            ╱         2                         ⎝
# ⎪                          ╲╱         k
# ⎪                    ─────────────────────────────────────────────────────────
# ⎪
# ⎪                                                                            ╱
# ⎪                                                                   2       ╱
# ⎪                                                                  k ⋅ν⋅   ╱
# ⎪                                                                         ╱
# ⎪                                                                       ╲╱
# ⎪
# ⎪
# ⎪
# ⎪
# ⎪                                                                          -ν
# ...

# %% [markdown]
# 3

# %%
r**nu*sin(a*r)
# Out:
#  ν
# r ⋅sin(a⋅r)

# %%
hankel_transform(_, r, k, nu)
# Out:
# ⎧                                                   -ν - 3/2
# ⎪                                         ⎛   2    ⎞
# ⎪                         ν + 1    -ν - 3 ⎜  a     ⎟          ⅈ⋅π
# ⎪                        2     ⋅a⋅k      ⋅⎜- ── + 1⎟        ⋅ℯ   ⋅Γ(ν + 3/2)
# ⎪                                         ⎜   2    ⎟
# ⎪                                         ⎝  k     ⎠
# ⎪                        ───────────────────────────────────────────────────
# ⎪                                                 ___
# ⎪                                               ╲╱ π
# ⎪
# ⎪                                               -ν - 3/2
# ⎪                                       ⎛     2⎞
# ⎪                    ν + 1  -2⋅ν - 2  ν ⎜    k ⎟
# ⎪                   2     ⋅a        ⋅k ⋅⎜1 - ──⎟        ⋅sin(π⋅(ν + 1))⋅Γ(ν +
# ⎪                                       ⎜     2⎟
# ⎪                                       ⎝    a ⎠
# ⎪                   ──────────────────────────────────────────────────────────
# ...

# %% [markdown]
# 4

# %%
r**(nu-1)*sin(a*r)
# Out:
#  ν - 1
# r     ⋅sin(a⋅r)

# %%
hankel_transform(_, r, k, nu)
# Out:
# ⎧
# ⎪                                  0                                     for a
# ⎪
# ⎪
# ⎪
# ⎪                                              -ν - 1/2
# ⎪                                      ⎛     2⎞
# ⎪                 ν   ___  -2⋅ν - 1  ν ⎜    k ⎟
# ⎪                2 ⋅╲╱ π ⋅a        ⋅k ⋅⎜1 - ──⎟
# ⎪                                      ⎜     2⎟
# ⎪                                      ⎝    a ⎠
# ⎪                ──────────────────────────────────────                   for
# ⎪                             Γ(-ν + 1/2)
# ⎪
# ⎪
# ⎪ ν   ___  -ν - 1 ⎧                                          2 │1 │
# ⎪2 ⋅╲╱ π ⋅k      ⋅⎪                 0                   for a ⋅│──│ < 1     ot
# ⎪                 ⎪                                            │ 2│
# ⎨                 ⎪                                            │k │
# ⎪                 ⎪
# ⎪                 ⎪                           -ν - 1/2
# ⎪                 ⎪                   ⎛     2⎞
# ...

# %% [markdown]
# 5

# %%
r**nu*cos(a*r)
# Out:
#  ν
# r ⋅cos(a⋅r)

# %%
hankel_transform(_, r, k, nu)
# Out:
# ⎧
# ⎪                                    0                                       f
# ⎪
# ⎪
# ⎪
# ⎪                                                  -ν - 3/2
# ⎪                                          ⎛     2⎞
# ⎪                 ν + 1   ___  -2⋅ν - 2  ν ⎜    k ⎟
# ⎪                2     ⋅╲╱ π ⋅a        ⋅k ⋅⎜1 - ──⎟
# ⎪                                          ⎜     2⎟
# ⎪                                          ⎝    a ⎠
# ⎪                ──────────────────────────────────────────
# ⎪                               Γ(-ν - 1/2)
# ⎪
# ⎪
# ⎪ ν + 1   ___  -ν - 2 ⎧                                          2 │1 │
# ⎪2     ⋅╲╱ π ⋅k      ⋅⎪                 0                   for a ⋅│──│ < 1
# ⎪                     ⎪                                            │ 2│
# ⎨                     ⎪                                            │k │
# ⎪                     ⎪
# ⎪                     ⎪                           -ν - 3/2
# ⎪                     ⎪                   ⎛     2⎞
# ...
