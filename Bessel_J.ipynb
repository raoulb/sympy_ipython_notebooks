# %%
# %load_ext sympyprt

# %%
from sympy import *

# %%
x = Symbol("x")
y = Symbol("y")
w = Symbol("w")

# %%
n = Symbol("n", integer=True)
m = Symbol("m", integer=True)
k = Symbol("k", integer=True)

# %%
a = Symbol("a")
b = Symbol("b")
c = Symbol("c")

# %%
besselj(Rational(3,2), x)
# Out:
# besselj(3/2, x)

# %%
besselsimp(_)
# Out:
#     ___            ___
#   ╲╱ 2 ⋅cos(x)   ╲╱ 2 ⋅sin(x)
# - ──────────── + ────────────
#     ___   ___       ___  3/2
#   ╲╱ π ⋅╲╱ x      ╲╱ π ⋅x

# %%
simplify(_)
# Out:
#   ___
# ╲╱ 2 ⋅(-x⋅cos(x) + sin(x))
# ──────────────────────────
#           ___  3/2
#         ╲╱ π ⋅x

# %%
besselj(Rational(-9,2), x)
# Out:
# besselj(-9/2, x)

# %%
besselsimp(_)
# Out:
#   ___               ___               ___                ___                __
# ╲╱ 2 ⋅cos(x)   10⋅╲╱ 2 ⋅sin(x)   45⋅╲╱ 2 ⋅cos(x)   105⋅╲╱ 2 ⋅sin(x)   105⋅╲╱ 2
# ──────────── - ─────────────── - ─────────────── + ──────────────── + ────────
#   ___   ___         ___  3/2          ___  5/2          ___  7/2           ___
# ╲╱ π ⋅╲╱ x        ╲╱ π ⋅x           ╲╱ π ⋅x           ╲╱ π ⋅x            ╲╱ π
#
# _
#  ⋅cos(x)
# ────────
#   9/2
# ⋅x

# %%
besselj(Rational(-7,2), x)
# Out:
# besselj(-7/2, x)

# %%
besselsimp(_)
# Out:
#   ___              ___               ___               ___
# ╲╱ 2 ⋅sin(x)   6⋅╲╱ 2 ⋅cos(x)   15⋅╲╱ 2 ⋅sin(x)   15⋅╲╱ 2 ⋅cos(x)
# ──────────── + ────────────── - ─────────────── - ───────────────
#   ___   ___        ___  3/2          ___  5/2          ___  7/2
# ╲╱ π ⋅╲╱ x       ╲╱ π ⋅x           ╲╱ π ⋅x           ╲╱ π ⋅x

# %%
besselj(Rational(-5,2), x)
# Out:
# besselj(-5/2, x)

# %%
besselsimp(_)
# Out:
#     ___              ___              ___
#   ╲╱ 2 ⋅cos(x)   3⋅╲╱ 2 ⋅sin(x)   3⋅╲╱ 2 ⋅cos(x)
# - ──────────── + ────────────── + ──────────────
#     ___   ___        ___  3/2         ___  5/2
#   ╲╱ π ⋅╲╱ x       ╲╱ π ⋅x          ╲╱ π ⋅x

# %%
besselj(Rational(-3,2), x)
# Out:
# besselj(-3/2, x)

# %%
besselsimp(_)
# Out:
#     ___            ___
#   ╲╱ 2 ⋅sin(x)   ╲╱ 2 ⋅cos(x)
# - ──────────── - ────────────
#     ___   ___       ___  3/2
#   ╲╱ π ⋅╲╱ x      ╲╱ π ⋅x

# %%
besselj(Rational(-1,2), x)
# Out:
# besselj(-1/2, x)

# %%
besselsimp(_)
# Out:
#   ___
# ╲╱ 2 ⋅cos(x)
# ────────────
#   ___   ___
# ╲╱ π ⋅╲╱ x

# %%
besselj(Rational(1,2), x)
# Out:
# besselj(1/2, x)

# %%
besselsimp(_)
# Out:
#   ___
# ╲╱ 2 ⋅sin(x)
# ────────────
#   ___   ___
# ╲╱ π ⋅╲╱ x

# %%
besselj(Rational(3,2), x)
# Out:
# besselj(3/2, x)

# %%
besselsimp(_)
# Out:
#     ___            ___
#   ╲╱ 2 ⋅cos(x)   ╲╱ 2 ⋅sin(x)
# - ──────────── + ────────────
#     ___   ___       ___  3/2
#   ╲╱ π ⋅╲╱ x      ╲╱ π ⋅x

# %%
besselj(Rational(5,2), x)
# Out:
# besselj(5/2, x)

# %%
besselsimp(_)
# Out:
#     ___              ___              ___
#   ╲╱ 2 ⋅sin(x)   3⋅╲╱ 2 ⋅cos(x)   3⋅╲╱ 2 ⋅sin(x)
# - ──────────── - ────────────── + ──────────────
#     ___   ___        ___  3/2         ___  5/2
#   ╲╱ π ⋅╲╱ x       ╲╱ π ⋅x          ╲╱ π ⋅x

# %%
besselj(Rational(7,2), x)
# Out:
# besselj(7/2, x)

# %%
besselsimp(_)
# Out:
#   ___              ___               ___               ___
# ╲╱ 2 ⋅cos(x)   6⋅╲╱ 2 ⋅sin(x)   15⋅╲╱ 2 ⋅cos(x)   15⋅╲╱ 2 ⋅sin(x)
# ──────────── - ────────────── - ─────────────── + ───────────────
#   ___   ___        ___  3/2          ___  5/2          ___  7/2
# ╲╱ π ⋅╲╱ x       ╲╱ π ⋅x           ╲╱ π ⋅x           ╲╱ π ⋅x

# %%
besselj(Rational(9,2), x)
# Out:
# besselj(9/2, x)

# %%
besselsimp(_)
# Out:
#   ___               ___               ___                ___                __
# ╲╱ 2 ⋅sin(x)   10⋅╲╱ 2 ⋅cos(x)   45⋅╲╱ 2 ⋅sin(x)   105⋅╲╱ 2 ⋅cos(x)   105⋅╲╱ 2
# ──────────── + ─────────────── - ─────────────── - ──────────────── + ────────
#   ___   ___         ___  3/2          ___  5/2          ___  7/2           ___
# ╲╱ π ⋅╲╱ x        ╲╱ π ⋅x           ╲╱ π ⋅x           ╲╱ π ⋅x            ╲╱ π
#
# _
#  ⋅sin(x)
# ────────
#   9/2
# ⋅x

# %%
besselj(1/n, x)
# Out:
#        ⎛1   ⎞
# besselj⎜─, x⎟
#        ⎝n   ⎠

# %%
besselsimp(_)
# Out:
#        ⎛1   ⎞
# besselj⎜─, x⎟
#        ⎝n   ⎠

# %%
besselj(Rational(1,3), x)
# Out:
# besselj(1/3, x)

# %%
besselsimp(_)
# Out:
# besselj(1/3, x)

# %%
expand_func(_)
# Out:
# besselj(1/3, x)

# %%
besselj(Rational(2,3), x)
# Out:
# besselj(2/3, x)

# %%
besselsimp(_)
# Out:
# besselj(2/3, x)

# %%
limit(besselj(n, x), x, oo)
# Out:
#        ⎛   1⎞
# besselj⎜n, ─⎟
#        ⎝   x⎠

# %%
limit(besselj(n, x), x, -oo)
# Out:
# besselj(n, x)

# %%
besselj(n, oo)
# Out:
# besselj(n, ∞)

# %%
besselj(n, -oo)
# Out:
# besselj(n, -∞)

# %%
besselj(n, -x)
# Out:
# besselj(n, -x)

# %%
expand_func(_)
# Out:
# besselj(n, -x)

# %%
besselsimp(_)
# Out:
# besselj(n, -x)

# %%
besselj(-n, x)
# Out:
# besselj(-n, x)

# %%
expand_func(_)
# Out:
# besselj(-n, x)

# %%
besselsimp(_)
# Out:
# besselj(-n, x)

# %%
besselj(n, I*x)
# Out:
# besselj(n, ⅈ⋅x)

# %%
besselj(n, -I*x)
# Out:
# besselj(n, -ⅈ⋅x)

# %%
besselj(n, x+y)
# Out:
# besselj(n, x + y)

# %%
besselj(n, x-y)
# Out:
# besselj(n, x - y)

# %%
besselj(n, x*y)
# Out:
# besselj(n, x⋅y)

# %%
expand_func(_, deep=True)
# Out:
# besselj(n, x⋅y)

# %%
besselsimp(_)
# Out:
# besselj(n, x⋅y)

# %%
expand_func(_, deep=True)
# Out:
# besselj(n, x⋅y)

# %%
besselsimp(_)
# Out:
# besselj(n, x⋅y)

# %% [markdown]
# Recurrence relations

# %%
2*(n+1)/x*besselj(n+1, x) - besselj(n+2, x)
# Out:
#                      (2⋅n + 2)⋅besselj(n + 1, x)
# -besselj(n + 2, x) + ───────────────────────────
#                                   x

# %%
besselsimp(_)
# Out:
#                      (2⋅n + 2)⋅besselj(n + 1, x)
# -besselj(n + 2, x) + ───────────────────────────
#                                   x

# %%
2*(n-1)/x*besselj(n-1, x) - besselj(n-2, x)
# Out:
#                      (2⋅n - 2)⋅besselj(n - 1, x)
# -besselj(n - 2, x) + ───────────────────────────
#                                   x

# %%
besselsimp(_)
# Out:
#                      (2⋅n - 2)⋅besselj(n - 1, x)
# -besselj(n - 2, x) + ───────────────────────────
#                                   x

# %%
x*(besselj(n-1,x)+besselj(n+1,x))/(2*n)
# Out:
# x⋅(besselj(n - 1, x) + besselj(n + 1, x))
# ─────────────────────────────────────────
#                    2⋅n

# %%
besselsimp(_)
# Out:
# x⋅(besselj(n - 1, x) + besselj(n + 1, x))
# ─────────────────────────────────────────
#                    2⋅n

# %%
besseli(n-1,x)*besselj(-n,x) + besseli(1-n,x)*besselj(n,x)
# Out:
# besseli(-n + 1, x)⋅besselj(n, x) + besseli(n - 1, x)⋅besselj(-n, x)

# %%
besselsimp(_)
# Out:
# besseli(-n + 1, x)⋅besselj(n, x) + besseli(n - 1, x)⋅besselj(-n, x)

# %%
expand_func(_)
# Out:
# besseli(-n + 1, x)⋅besselj(n, x) + besseli(n - 1, x)⋅besselj(-n, x)

# %%
diff(besselj(n,x),x)
# Out:
# besselj(n - 1, x)   besselj(n + 1, x)
# ───────────────── - ─────────────────
#         2                   2

# %%
diff(besselj(n,x),n)
# Out:
# d
# ──(besselj(n, x))
# dn

# %% [markdown]
# Some integrals

# %%
integrate(besselj(n,a*x), x, meijerg=True)
# Out:
#                                 ⎛   n   1     │       ⎞
#                                 ⎜   ─ + ─     │   2  2⎟
#  -n - 1  n  n + 1  ⎛n   1⎞  ┌─  ⎜   2   2     │ -a ⋅x ⎟
# 2      ⋅a ⋅x     ⋅Γ⎜─ + ─⎟⋅ ├─  ⎜             │ ──────⎟
#                    ⎝2   2⎠ 1╵ 2 ⎜       n   3 │   4   ⎟
#                                 ⎜n + 1, ─ + ─ │       ⎟
#                                 ⎝       2   2 │       ⎠
# ───────────────────────────────────────────────────────
#                     ⎛n   3⎞
#                    Γ⎜─ + ─⎟⋅Γ(n + 1)
#                     ⎝2   2⎠

# %%
hyperexpand(_)
# Out:
#                                 ⎛   n   1     │       ⎞
#                                 ⎜   ─ + ─     │   2  2⎟
#  -n - 1  n  n + 1  ⎛n   1⎞  ┌─  ⎜   2   2     │ -a ⋅x ⎟
# 2      ⋅a ⋅x     ⋅Γ⎜─ + ─⎟⋅ ├─  ⎜             │ ──────⎟
#                    ⎝2   2⎠ 1╵ 2 ⎜       n   3 │   4   ⎟
#                                 ⎜n + 1, ─ + ─ │       ⎟
#                                 ⎝       2   2 │       ⎠
# ───────────────────────────────────────────────────────
#                     ⎛n   3⎞
#                    Γ⎜─ + ─⎟⋅Γ(n + 1)
#                     ⎝2   2⎠

# %%
combsimp(_)
# Out:
#                                  ⎛   n   1     │       ⎞
#                                  ⎜   ─ + ─     │   2  2⎟
#  -n  -n - 1   ___  n  n + 1  ┌─  ⎜   2   2     │ -a ⋅x ⎟
# 2  ⋅2      ⋅╲╱ π ⋅a ⋅x     ⋅ ├─  ⎜             │ ──────⎟
#                             1╵ 2 ⎜       n   3 │   4   ⎟
#                                  ⎜n + 1, ─ + ─ │       ⎟
#                                  ⎝       2   2 │       ⎠
# ────────────────────────────────────────────────────────
#                     ⎛n    ⎞  ⎛n   3⎞
#                    Γ⎜─ + 1⎟⋅Γ⎜─ + ─⎟
#                     ⎝2    ⎠  ⎝2   2⎠

# %%
simplify(_)
# Out:
#                        ⎛   n   1     │       ⎞
#                        ⎜   ─ + ─     │   2  2⎟
#  -n + 2  n  n + 1  ┌─  ⎜   2   2     │ -a ⋅x ⎟
# 2      ⋅a ⋅x     ⋅ ├─  ⎜             │ ──────⎟
#                   1╵ 2 ⎜       n   3 │   4   ⎟
#                        ⎜n + 1, ─ + ─ │       ⎟
#                        ⎝       2   2 │       ⎠
# ──────────────────────────────────────────────
#                   4⋅Γ(n + 2)

# %%
integrate(besselj(n,x), x, meijerg=True)
# Out:
#                              ⎛   n   1     │    ⎞
#                              ⎜   ─ + ─     │   2⎟
#  -n - 1  n + 1  ⎛n   1⎞  ┌─  ⎜   2   2     │ -x ⎟
# 2      ⋅x     ⋅Γ⎜─ + ─⎟⋅ ├─  ⎜             │ ───⎟
#                 ⎝2   2⎠ 1╵ 2 ⎜       n   3 │  4 ⎟
#                              ⎜n + 1, ─ + ─ │    ⎟
#                              ⎝       2   2 │    ⎠
# ─────────────────────────────────────────────────
#                  ⎛n   3⎞
#                 Γ⎜─ + ─⎟⋅Γ(n + 1)
#                  ⎝2   2⎠

# %%
simplify(_)
# Out:
#                             ⎛   n   1     │    ⎞
#                             ⎜   ─ + ─     │   2⎟
#  -2⋅n - 1   ___  n + 1  ┌─  ⎜   2   2     │ -x ⎟
# 2        ⋅╲╱ π ⋅x     ⋅ ├─  ⎜             │ ───⎟
#                        1╵ 2 ⎜       n   3 │  4 ⎟
#                             ⎜n + 1, ─ + ─ │    ⎟
#                             ⎝       2   2 │    ⎠
# ────────────────────────────────────────────────
#                 ⎛n    ⎞  ⎛n   3⎞
#                Γ⎜─ + 1⎟⋅Γ⎜─ + ─⎟
#                 ⎝2    ⎠  ⎝2   2⎠

# %%
simplify(_)
# Out:
#                     ⎛   n   1     │    ⎞
#                     ⎜   ─ + ─     │   2⎟
#  -n + 2  n + 1  ┌─  ⎜   2   2     │ -x ⎟
# 2      ⋅x     ⋅ ├─  ⎜             │ ───⎟
#                1╵ 2 ⎜       n   3 │  4 ⎟
#                     ⎜n + 1, ─ + ─ │    ⎟
#                     ⎝       2   2 │    ⎠
# ────────────────────────────────────────
#                4⋅Γ(n + 2)

# %%
integrate(besselj(0,x), x, meijerg=True)
# Out:
#        ⎛       │   2⎞
#    ┌─  ⎜ 1/2   │ -x ⎟
# x⋅ ├─  ⎜       │ ───⎟
#   1╵ 2 ⎝1, 3/2 │  4 ⎠

# %%
hyperexpand(_)
# Out:
#        ⎛       │   2⎞
#    ┌─  ⎜ 1/2   │ -x ⎟
# x⋅ ├─  ⎜       │ ───⎟
#   1╵ 2 ⎝1, 3/2 │  4 ⎠

# %%
integrate(besselj(1,x), x, meijerg=True)
# Out:
# -besselj(0, x)

# %%
integrate(besselj(n, a*x**b), x, meijerg=True)
# Out:
#                 1  -1      1                          ⎛     n    1        │
#        -n - 1 - ─  ──  n + ─                          ⎜     ─ + ───       │
# b ___           b  b       b  b⋅n + 1  ⎛n    1 ⎞  ┌─  ⎜     2   2⋅b       │ -a
# ╲╱ 2 ⋅2          ⋅a  ⋅a     ⋅x       ⋅Γ⎜─ + ───⎟⋅ ├─  ⎜                   │ ──
#                                        ⎝2   2⋅b⎠ 1╵ 2 ⎜       n        1  │
#                                                       ⎜n + 1, ─ + 1 + ─── │
#                                                       ⎝       2       2⋅b │
# ──────────────────────────────────────────────────────────────────────────────
#                                           ⎛n        1 ⎞
#                               b⋅Γ(n + 1)⋅Γ⎜─ + 1 + ───⎟
#                                           ⎝2       2⋅b⎠
#
#       ⎞
# 2  2⋅b⎟
#  ⋅x   ⎟
# ──────⎟
#  4    ⎟
#       ⎟
#       ⎠
# ───────

# %%
simplify(_)
# Out:
#                      ⎛     n    1        │         ⎞
#                      ⎜     ─ + ───       │   2  2⋅b⎟
#  -n  n  b⋅n + 1  ┌─  ⎜     2   2⋅b       │ -a ⋅x   ⎟
# 2  ⋅a ⋅x       ⋅ ├─  ⎜                   │ ────────⎟
#                 1╵ 2 ⎜       n        1  │    4    ⎟
#                      ⎜n + 1, ─ + 1 + ─── │         ⎟
#                      ⎝       2       2⋅b │         ⎠
# ────────────────────────────────────────────────────
#                  (b⋅n + 1)⋅Γ(n + 1)

# %%
integrate(besselj(n, a*x**b)**2, x, meijerg=True)
# Out:
# ⌠
# ⎮        2
# ⎮         ⎛      b⎞
# ⎮ besselj ⎝n, a⋅x ⎠ dx
# ⌡

# %%
integrate(besselj(n, a*x)*besselj(m, a*x), x, meijerg=True)
# Out:
# ⌠
# ⎮ besselj(m, a⋅x)⋅besselj(n, a⋅x) dx
# ⌡

# %%
integrate(besselj(n, a*x)*besselj(n+1, a*x), x, meijerg=True)
# Out:
# ⌠
# ⎮ besselj(n, a⋅x)⋅besselj(n + 1, a⋅x) dx
# ⌡

# %%
integrate(besselj(1, a*x)*besselj(0, a*x), x, meijerg=True)
# Out:
# ⌠
# ⎮ besselj(0, a⋅x)⋅besselj(1, a⋅x) dx
# ⌡

# %%
integrate(besselj(1, x)*besselj(0, x), x, meijerg=True)
# Out:
#         2
# -besselj (0, x)
# ───────────────
#        2

# %%
integrate(besselj(n, x)*besselj(n+1, x), x, meijerg=True)
# Out:
#  2⋅n + 2                      ┌─  ⎛    n + 1, n + 3/2    │   2⎞
# x       ⋅Γ(n + 1)⋅Γ(n + 3/2)⋅ ├─  ⎜                      │ -x ⎟
#                              2╵ 3 ⎝n + 2, n + 2, 2⋅n + 2 │    ⎠
# ───────────────────────────────────────────────────────────────
#                       ___         2
#                   2⋅╲╱ π ⋅Γ(n + 2) ⋅Γ(2⋅n + 2)

# %%
simplify(_)
# Out:
#  -2⋅n - 2  2⋅n + 2  ┌─  ⎛    n + 1, n + 3/2    │   2⎞
# 2        ⋅x       ⋅ ├─  ⎜                      │ -x ⎟
#                    2╵ 3 ⎝n + 2, n + 2, 2⋅n + 2 │    ⎠
# ─────────────────────────────────────────────────────
#                               2
#                       Γ(n + 2)

# %%
integrate(besselj(n, x)*besselj(m, x), x, meijerg=True)
# Out:
#                                            ⎛ m   n   1  m   n   1  m   n
#                        2                   ⎜ ─ + ─ + ─, ─ + ─ + ─, ─ + ─ + 1
#  m + n + 1  ⎛m   n   1⎞   ⎛m   n    ⎞  ┌─  ⎜ 2   2   2  2   2   2  2   2
# x         ⋅Γ⎜─ + ─ + ─⎟ ⋅Γ⎜─ + ─ + 1⎟⋅ ├─  ⎜
#             ⎝2   2   2⎠   ⎝2   2    ⎠ 3╵ 4 ⎜                         m   n   3
#                                            ⎜m + 1, n + 1, m + n + 1, ─ + ─ + ─
#                                            ⎝                         2   2   2
# ──────────────────────────────────────────────────────────────────────────────
#                      ___                    ⎛m   n   3⎞
#                  2⋅╲╱ π ⋅Γ(m + 1)⋅Γ(n + 1)⋅Γ⎜─ + ─ + ─⎟⋅Γ(m + n + 1)
#                                             ⎝2   2   2⎠
#
#  │    ⎞
#  │    ⎟
#  │   2⎟
#  │ -x ⎟
#  │    ⎟
#  │    ⎟
#  │    ⎠
# ───────

# %%
simplify(_)
# Out:
#                             ⎛ m   n   1  m   n   1  m   n       │    ⎞
#                             ⎜ ─ + ─ + ─, ─ + ─ + ─, ─ + ─ + 1   │    ⎟
#  -m - n + 2  m + n + 1  ┌─  ⎜ 2   2   2  2   2   2  2   2       │   2⎟
# 2          ⋅x         ⋅ ├─  ⎜                                   │ -x ⎟
#                        3╵ 4 ⎜                         m   n   3 │    ⎟
#                             ⎜m + 1, n + 1, m + n + 1, ─ + ─ + ─ │    ⎟
#                             ⎝                         2   2   2 │    ⎠
# ──────────────────────────────────────────────────────────────────────
#                    4⋅(m + n + 1)⋅Γ(m + 1)⋅Γ(n + 1)

# %%
integrate(besselj(n, x**a)*besselj(m, x**a), x, meijerg=True)
# Out:
# ⌠
# ⎮        ⎛    a⎞        ⎛    a⎞
# ⎮ besselj⎝m, x ⎠⋅besselj⎝n, x ⎠ dx
# ⌡

# %%
integrate(x**(-n)*besselj(n,x), x, meijerg=True)
# Expected: -x**(1-n) * besselj(n-1,x)
# Out:
#                ⎛           │   2⎞
#  -n + 1    ┌─  ⎜   1/2     │ -x ⎟
# 2      ⋅x⋅ ├─  ⎜           │ ───⎟
#           1╵ 2 ⎝3/2, n + 1 │  4 ⎠
# ─────────────────────────────────
#             2⋅Γ(n + 1)

# %%
hyperexpand(_)
# Out:
#                ⎛           │   2⎞
#  -n + 1    ┌─  ⎜   1/2     │ -x ⎟
# 2      ⋅x⋅ ├─  ⎜           │ ───⎟
#           1╵ 2 ⎝3/2, n + 1 │  4 ⎠
# ─────────────────────────────────
#             2⋅Γ(n + 1)

# %%
integrate(x*besselj(0,x), x)
# Out:
# x⋅besselj(1, x)

# %% [markdown]
# Definite integration examples

# %%
integrate(besselj(n,x),(x,0,oo))
# Out:
# ⎧                          n   1
# ⎪        1           for - ─ + ─ < 1
# ⎪                          2   2
# ⎪
# ⎨∞
# ⎪⌠
# ⎪⎮ besselj(n, x) dx     otherwise
# ⎪⌡
# ⎩0

# %%
integrate(x**(a-1)*besselj(n,x),(x,0,oo))
# Out:
# ⎧       a
# ⎪       ─ - 1
# ⎪       2      ⎛a   n⎞
# ⎪    2⋅4     ⋅Γ⎜─ + ─⎟
# ⎪              ⎝2   2⎠            n     ⎛a⎞
# ⎪    ─────────────────      for - ─ - re⎜─⎟ + 1 < 1 ∧ -re(a) + 7/2 > 2
# ⎪       ⎛  a   n    ⎞             2     ⎝2⎠
# ⎪      Γ⎜- ─ + ─ + 1⎟
# ⎨       ⎝  2   2    ⎠
# ⎪
# ⎪∞
# ⎪⌠
# ⎪⎮  a - 1
# ⎪⎮ x     ⋅besselj(n, x) dx                  otherwise
# ⎪⌡
# ⎪0
# ⎩

# %%
_.args[0].args[0]
# Out:
#    a
#    ─ - 1
#    2      ⎛a   n⎞
# 2⋅4     ⋅Γ⎜─ + ─⎟
#           ⎝2   2⎠
# ─────────────────
#    ⎛  a   n    ⎞
#   Γ⎜- ─ + ─ + 1⎟
#    ⎝  2   2    ⎠

# %%
combsimp(_)
# Out:
#    a
#    ─ - 1
#    2      ⎛a   n⎞
# 2⋅4     ⋅Γ⎜─ + ─⎟
#           ⎝2   2⎠
# ─────────────────
#    ⎛  a   n    ⎞
#   Γ⎜- ─ + ─ + 1⎟
#    ⎝  2   2    ⎠

# %%
simplify(_)
# Hmm, how get rid off 4/2
# Out:
#    a
#    ─
#    2  ⎛a   n⎞
#   4 ⋅Γ⎜─ + ─⎟
#       ⎝2   2⎠
# ────────────────
#    ⎛  a   n    ⎞
# 2⋅Γ⎜- ─ + ─ + 1⎟
#    ⎝  2   2    ⎠

# %%
# Stress tests

# %%
integrate(x**(k-1)*besselj(m, a*x)*besselj(n, b*x), (x,0,oo))
# Out:
# ⎧                         ⎛  k   m        k   m     │               ⎞
# ⎪                         ⎜- ─ - ─ + 1  - ─ + ─ + 1 │           2   ⎟
# ⎪   k - 2  -k + 2 ╭─╮1, 1 ⎜  2   2        2   2     │ polar_lift (b)⎟
# ⎪2⋅2     ⋅a      ⋅│╶┐     ⎜                         │ ──────────────⎟
# ⎪                 ╰─╯2, 2 ⎜     n           -n      │           2   ⎟
# ⎪                         ⎜     ─           ──      │ polar_lift (a)⎟
# ⎪                         ⎝     2           2       │               ⎠      k
# ⎪────────────────────────────────────────────────────────────────────  for ─ +
# ⎨                                  2                                       2
# ⎪                                 a
# ⎪
# ⎪            ∞
# ⎪            ⌠
# ⎪            ⎮  k - 1
# ⎪            ⎮ x     ⋅besselj(m, a⋅x)⋅besselj(n, b⋅x) dx
# ⎪            ⌡
# ⎩            0
#
#
#
#
#
#
#
#  m   n       │                 ⎛          2      ⎞│                      │
# ...

# %%
_.args[0].args[0]
# Out:
#                          ⎛  k   m        k   m     │               ⎞
#                          ⎜- ─ - ─ + 1  - ─ + ─ + 1 │           2   ⎟
#    k - 2  -k + 2 ╭─╮1, 1 ⎜  2   2        2   2     │ polar_lift (b)⎟
# 2⋅2     ⋅a      ⋅│╶┐     ⎜                         │ ──────────────⎟
#                  ╰─╯2, 2 ⎜     n           -n      │           2   ⎟
#                          ⎜     ─           ──      │ polar_lift (a)⎟
#                          ⎝     2           2       │               ⎠
# ────────────────────────────────────────────────────────────────────
#                                   2
#                                  a

# %%
hyperexpand(_)
# Out:
#                          ⎛  k   m        k   m     │               ⎞
#                          ⎜- ─ - ─ + 1  - ─ + ─ + 1 │           2   ⎟
#    k - 2  -k + 2 ╭─╮1, 1 ⎜  2   2        2   2     │ polar_lift (b)⎟
# 2⋅2     ⋅a      ⋅│╶┐     ⎜                         │ ──────────────⎟
#                  ╰─╯2, 2 ⎜     n           -n      │           2   ⎟
#                          ⎜     ─           ──      │ polar_lift (a)⎟
#                          ⎝     2           2       │               ⎠
# ────────────────────────────────────────────────────────────────────
#                                   2
#                                  a

# %%
integrate(besselj(m, a*x)*besselj(n, b*x), (x,0,oo))
# Out:
# ⎧        ⎛  m   1  m   1 │               ⎞
# ⎪        ⎜- ─ + ─  ─ + ─ │           2   ⎟
# ⎪╭─╮1, 1 ⎜  2   2  2   2 │ polar_lift (b)⎟
# ⎪│╶┐     ⎜               │ ──────────────⎟
# ⎪╰─╯2, 2 ⎜   n      -n   │           2   ⎟
# ⎪        ⎜   ─      ──   │ polar_lift (a)⎟
# ⎪        ⎝   2      2    │               ⎠      m   n   1       │
# ⎪─────────────────────────────────────────  for ─ + ─ + ─ > 0 ∧ │periodic_argu
# ⎨                    a                          2   2   2
# ⎪
# ⎪
# ⎪  ∞
# ⎪  ⌠
# ⎪  ⎮ besselj(m, a⋅x)⋅besselj(n, b⋅x) dx
# ⎪  ⌡
# ⎪  0
# ⎩
#
#
#
#
#
#
#                                 2
#     ⎛          2      ⎞│       b        │                 ⎛          2      ⎞│
# ment⎝polar_lift (a), ∞⎠│ = 0 ∧ ── ≠ 1 ∧ │periodic_argument⎝polar_lift (b), ∞⎠│
#                                 2
#                                a
#
#
#
#                    otherwise
#
#
#
#
#
#
#
#
#
#
#
#  = 0

# %%
_.args[0].args[0]
# Out:
#         ⎛  m   1  m   1 │               ⎞
#         ⎜- ─ + ─  ─ + ─ │           2   ⎟
# ╭─╮1, 1 ⎜  2   2  2   2 │ polar_lift (b)⎟
# │╶┐     ⎜               │ ──────────────⎟
# ╰─╯2, 2 ⎜   n      -n   │           2   ⎟
#         ⎜   ─      ──   │ polar_lift (a)⎟
#         ⎝   2      2    │               ⎠
# ─────────────────────────────────────────
#                     a

# %%
hyperexpand(_)
# Out:
#         ⎛  m   1  m   1 │               ⎞
#         ⎜- ─ + ─  ─ + ─ │           2   ⎟
# ╭─╮1, 1 ⎜  2   2  2   2 │ polar_lift (b)⎟
# │╶┐     ⎜               │ ──────────────⎟
# ╰─╯2, 2 ⎜   n      -n   │           2   ⎟
#         ⎜   ─      ──   │ polar_lift (a)⎟
#         ⎝   2      2    │               ⎠
# ─────────────────────────────────────────
#                     a

# %%
integrate(1/x*besselj(m, a*x)*besselj(m, b*x), (x,0,oo))
# Out:
# ⎧⎧                -m  m                          │ 2│
# ⎪⎪               a  ⋅b ⋅Γ(m)                     │b │
# ⎪⎪               ───────────                 for │──│ < 1
# ⎪⎪                 Γ(m + 1)                      │ 2│
# ⎪⎪                                               │a │
# ⎪⎪
# ⎪⎪                m  -m                          │ 2│
# ⎪⎪               a ⋅b  ⋅Γ(m)                     │a │
# ⎪⎪               ───────────                 for │──│ < 1
# ⎪⎨                 Γ(m + 1)                      │ 2│
# ⎪⎪                                               │b │
# ⎪⎪
# ⎪⎪        ⎛  m      m     │               ⎞
# ⎪⎪        ⎜- ─ + 1  ─ + 1 │           2   ⎟
# ⎨⎪╭─╮1, 1 ⎜  2      2     │ polar_lift (b)⎟
# ⎪⎪│╶┐     ⎜               │ ──────────────⎟   otherwise
# ⎪⎪╰─╯2, 2 ⎜   m      -m   │           2   ⎟
# ⎪⎪        ⎜   ─      ──   │ polar_lift (a)⎟
# ⎪⎩        ⎝   2      2    │               ⎠                    │
# ...

# %%
_.args[0].args[0].args[1].args[0].args[0] / 2
# Out:
#  -m  m
# a  ⋅b ⋅Γ(m)
# ───────────
#  2⋅Γ(m + 1)

# %%
combsimp(_)
# Out:
#  -m  m
# a  ⋅b
# ──────
#  2⋅m

# %%
integrate(1/x*besselj(n,x)**2, (x,0,oo))
# Out:
# ⎧       Γ(n)
# ⎪    ──────────       for n > 0
# ⎪    2⋅Γ(n + 1)
# ⎪
# ⎪∞
# ⎪⌠
# ⎨⎮        2
# ⎪⎮ besselj (n, x)
# ⎪⎮ ────────────── dx  otherwise
# ⎪⎮       x
# ⎪⌡
# ⎪0
# ⎩

# %%
_.args[0].args[0]
# Out:
#    Γ(n)
# ──────────
# 2⋅Γ(n + 1)

# %%
combsimp(_)
# Out:
#  1
# ───
# 2⋅n

# %%
integrate(x**(a-1)*besselj(n, x)**2, (x,0,oo))
# Out:
# ⎧   a - 2            ⎛a    ⎞
# ⎪2⋅2     ⋅Γ(-a + 1)⋅Γ⎜─ + n⎟
# ⎪                    ⎝2    ⎠                                             ⎛a⎞
# ⎪───────────────────────────  for -2⋅re(2⋅a) + 8 > 0 ∧ re(a) < 1 ∧ n + re⎜─⎟ >
# ⎪           2                                                            ⎝2⎠
# ⎪  ⎛  a    ⎞   ⎛  a        ⎞
# ⎪ Γ⎜- ─ + 1⎟ ⋅Γ⎜- ─ + n + 1⎟
# ⎨  ⎝  2    ⎠   ⎝  2        ⎠
# ⎪
# ⎪∞
# ⎪⌠
# ⎪⎮  a - 1        2
# ⎪⎮ x     ⋅besselj (n, x) dx                       otherwise
# ⎪⌡
# ⎩0
#
#
#
#
#  0

# %%
_.args[0].args[0]
# Out:
#    a - 2            ⎛a    ⎞
# 2⋅2     ⋅Γ(-a + 1)⋅Γ⎜─ + n⎟
#                     ⎝2    ⎠
# ───────────────────────────
#            2
#   ⎛  a    ⎞   ⎛  a        ⎞
#  Γ⎜- ─ + 1⎟ ⋅Γ⎜- ─ + n + 1⎟
#   ⎝  2    ⎠   ⎝  2        ⎠

# %%
simplify(_)
# Out:
#         ⎛  a   1⎞  ⎛a    ⎞
#        Γ⎜- ─ + ─⎟⋅Γ⎜─ + n⎟
#         ⎝  2   2⎠  ⎝2    ⎠
# ─────────────────────────────────
#     ___  ⎛  a    ⎞  ⎛  a        ⎞
# 2⋅╲╱ π ⋅Γ⎜- ─ + 1⎟⋅Γ⎜- ─ + n + 1⎟
#          ⎝  2    ⎠  ⎝  2        ⎠

# %%
#integrate(x*besselj(n, a*x)*besselj(n, b*x), (x,0,oo))

# %%
#integrate(x**(w-1)*besselj(m, a*x)*besselj(n, b*x)*besselj(k, c*x), (x,0,oo))

# %% [markdown]
# Some hypergeometric functions

# %%
hyper([],[n+1],-x**2/4)
# Out:
#      ⎛      │   2⎞
#  ┌─  ⎜      │ -x ⎟
#  ├─  ⎜      │ ───⎟
# 0╵ 1 ⎝n + 1 │  4 ⎠

# %%
hyperexpand(_)
# Out:
#         -ⅈ⋅π⋅n
#         ──────
#  n  -n    2
# 2 ⋅x  ⋅ℯ      ⋅besseli(n, ⅈ⋅x)⋅Γ(n + 1)

# %%
hyper([n+Rational(1,2)],[2*n+1],2*I*x)
# Out:
#  ┌─  ⎛n + 1/2 │      ⎞
#  ├─  ⎜        │ 2⋅ⅈ⋅x⎟
# 1╵ 1 ⎝2⋅n + 1 │      ⎠

# %%
hyperexpand(_)
# Out:
#              -ⅈ⋅π⋅n
#              ──────
#  n  -n  ⅈ⋅x    2
# 2 ⋅x  ⋅ℯ   ⋅ℯ      ⋅besseli(n, ⅈ⋅x)⋅Γ(n + 1)

# %% [markdown]
# Transformation examples

# %%
mellin_transform(besselj(n,x), x, y)
# Out:
# ⎛ y - 1  ⎛n   y⎞                 ⎞
# ⎜2     ⋅Γ⎜─ + ─⎟                 ⎟
# ⎜        ⎝2   2⎠                 ⎟
# ⎜───────────────, (-n, 3/2), True⎟
# ⎜   ⎛n   y    ⎞                  ⎟
# ⎜  Γ⎜─ - ─ + 1⎟                  ⎟
# ⎝   ⎝2   2    ⎠                  ⎠

# %%
laplace_transform(besselj(n,x), x, y)[0]
# Out:
#                            -n - 1
#         ⎛     ________    ⎞       ⎛        ________         ⎞
#  -n - 1 ⎜    ╱     1      ⎟       ⎜ 2     ╱     1      2    ⎟
# y      ⋅⎜   ╱  1 + ──  + 1⎟      ⋅⎜y ⋅   ╱  1 + ──  + y  + 1⎟
#         ⎜  ╱        2     ⎟       ⎜     ╱        2          ⎟
#         ⎝╲╱        y      ⎠       ⎝   ╲╱        y           ⎠
# ─────────────────────────────────────────────────────────────
#                              2
#                             y  + 1

# %%
sine_transform(besselj(n,x), x, y)
# Out:
# ⎧          ⎛  ⎛
# ⎪          ⎜  ⎜
# ⎪          ⎜  ⎜
# ⎪          ⎜  ⎜
# ⎪          ⎜  ⎜⎛   2    ⎞ ⎛   2    4 ⎛   2          ⎞    2 ⎛     2      ⎞    ⎞
# ⎪          ⎜  ⎜⎝2⋅y  - 2⎠⋅⎝- n  - y ⋅⎝2⋅n  - 6⋅n + 4⎠ - y ⋅⎝- 3⋅n  + 6⋅n⎠ + 1⎠
# ⎪          ⎜y⋅⎜───────────────────────────────────────────────────────────────
# ⎪          ⎜  ⎜              ⎛ 2  2    2⎞ ⎛     4        2      ⎞
# ⎪    ___   ⎜  ⎝              ⎝n ⋅y  - y ⎠⋅⎝2⋅n⋅y  - 4⋅n⋅y  + 2⋅n⎠
# ⎪2⋅╲╱ 2 ⋅y⋅⎜──────────────────────────────────────────────────────────────────
# ⎪          ⎜                                                              ____
# ⎪          ⎜                                                             ╱
# ⎪          ⎝                                                           ╲╱  - y
# ⎪─────────────────────────────────────────────────────────────────────────────
# ⎪
# ⎪
# ⎪
# ⎪
# ⎪
# ⎨
# ⎪
# ⎪
# ⎪
# ⎪
# ⎪
# ⎪
# ⎪
# ⎪
# ⎪
# ⎪
# ⎪
# ⎪
# ⎪
# ⎪
# ⎪
# ⎪
# ⎪
# ⎪
# ⎩
#
# ...

# %%
cosine_transform(besselj(n,x), x, y)
# Out:
# ⎧                          ___ ⎛  y⋅sin((n - 1)⋅asin(y))
# ⎪                        ╲╱ 2 ⋅⎜- ────────────────────── + cos((n - 1)⋅asin(y)
# ⎪                              ⎜         __________
# ⎪                              ⎜        ╱    2
# ⎪                              ⎝      ╲╱  - y  + 1
# ⎪                        ─────────────────────────────────────────────────────
# ⎪                                                   ___
# ⎪                                                 ╲╱ π
# ⎪
# ⎪              ⎛
# ⎪              ⎜                                                     ⎛     ___
# ⎪              ⎜                                               n + 1 ⎜    ╱
# ⎪              ⎜                                         -n   2     ⋅⎜   ╱  1
# ⎪              ⎜                      ⎛     ________    ⎞            ⎜  ╱
# ⎪  ___  -n - 1 ⎜ n ⎛         2      ⎞ ⎜    ╱     1      ⎟            ⎝╲╱
# ⎨╲╱ 2 ⋅y      ⋅⎜2 ⋅⎜1 - ────────────⎟⋅⎜   ╱  1 - ──  + 1⎟   + ────────────────
# ...
